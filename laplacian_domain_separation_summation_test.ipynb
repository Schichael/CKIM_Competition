# %%
from federatedscope.register import register_data
from federatedscope.register import register_trainer
from federatedscope.register import register_metric
from federatedscope.register import register_model

# %%
from federatedscope.contrib.data.cikm_cup import call_cikm_cup_data

register_data("cikm_cup", call_cikm_cup_data)

# %% [markdown]
# ### Register model

# %%
#from federatedscope.contrib.model.mnist_model import call_my_net
#register_model("mynet", call_my_net)

# %% [markdown]
# ### Register trainer

# %%
from federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation import call_laplacian_trainer

register_trainer('laplacian_trainer', call_laplacian_trainer)
# Out:
# /home/michael/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/imports.py:14: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# /home/michael/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/logger.py:23: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "

# %% [markdown]
# ### Register metric

# %% [markdown]
# ### Create the config

# %% [markdown]
# #### Set data, model, trainer and metric

# %%
from federatedscope.core.configs.config import global_cfg, CN
cfg = global_cfg.clone()

cfg.merge_from_file("federatedscope/gfl/baseline/laplacian_gine_on_cikmcup.yaml")
#cfg.data.type = 'cikm_cup'
#cfg.data.root = 'data'
#cfg.data.shuffle=True
#cfg.data.transform = [['ToTensor'], ['Normalize', {'mean': [0.], 'std': [1]}]]
#cfg.model.type = 'gin'
#cfg.model.out_channels = 10
#cfg.model.hidden = 64
#cfg.model.task='graph'
#cfg.model.dropout = 0.5
#cfg.personalization.local_param = ['encoder_atom', 'encoder', 'clf']#['node_encoder', 'clf']
#cfg.train.batch_or_epoch = "epoch"
cfg.trainer.type = 'laplacian_trainer_with_domain_separation'
cfg.data.batch_size = 64
# cfg.eval.metric = ['mymetric']
cfg.params = CN()
cfg.params.alpha=0.1
cfg.params.csd_importance= 1e2
cfg.params.eps=1e-20
cfg.params.p=0.
cfg.params.diff_importance = 1
cfg.params.lam = 0

# %% [markdown]
# #### configure other options

# %%
#cfg.use_gpu = True
#cfg.best_res_update_round_wise_key = "test_loss"

#cfg.federate.mode = 'standalone'
cfg.federate.method = \
    f'Laplacian_domain_sep_sum_csd{cfg.params.csd_importance}_lam{cfg.params.lam}_diff{cfg.params.diff_importance}'
#cfg.federate.local_update_steps = 20000000
#cfg.personalization.local_update_steps = 20000000
#cfg.finetune.local_update_steps = 20000000
#cfg.train.local_update_steps = 1

cfg.federate.total_round_num = 2000

cfg.federate.client_num = 13
cfg.early_stop.patience = 10000
#cfg.train.optimizer.lr = 0.001
#cfg.train.optimizer.weight_decay = 0.0005
#cfg.grad.grad_clip = 2.0
cfg.criterion.type = 'CrossEntropyLoss'
#cfg.seed = 123
cfg.eval.freq = 1
cfg.eval.metrics = ['imp_ratio']
cfg.eval.report = ['avg']
cfg.eval.best_res_update_round_wise_key = 'val_imp_ratio'
cfg.eval.count_flops = False
cfg.data.type = "cikm_cup"

# %%
import torch
#torch.manual_seed(0)
#torch.backends.cudnn.benchmark = False
#torch.use_deterministic_algorithms(F/home/michael/Desktop/backup files/FederatedScope/data/CIKM22Competitionalse)
#import random
#random.seed(0)
#import numpy as np
#np.random.seed(0)

# %%
from yacs.config import CfgNode
client_cfg_file = "federatedscope/gfl/baseline/laplacian_gine_on_cikmcup_per_client.yaml"
client_cfg = CfgNode.load_cfg(open(client_cfg_file,
                                       'r')) if client_cfg_file else None

# %% [markdown]
# ### Start the FL prosess

# %%
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.fed_runner import FedRunner
from federatedscope.core.auxiliaries.worker_builder import get_server_cls, get_client_cls
# Out:
# 2022-12-03 22:31:30,712 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
from federatedscope.contrib.workers.laplacian_with_domain_separation_client import LaplacianDomainSeparationClient
from federatedscope.contrib.workers.laplacian_server_dom_sep import LaplacianServerDomSep

setup_seed(cfg.seed)
update_logger(cfg)
data, modified_cfg = get_data(cfg)
cfg.merge_from_other_cfg(modified_cfg)
# Out:
# 2022-12-03 22:31:30,889 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-12-03 22:31:30,890 (utils:131)INFO: the current dir is /home/michael/Master-Thesis/CKIM_Competition
# 2022-12-03 22:31:30,890 (utils:132)INFO: the output dir is exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# 2022-12-03 22:31:30,891 (cikm_cup:58)INFO: Loading CIKMCUP data from /home/michael/Master-Thesis/CKIM_Competition/data/CIKM22Competition.
# 2022-12-03 22:31:30,892 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #1.
# 2022-12-03 22:31:31,152 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #2.
# 2022-12-03 22:31:31,184 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #3.
# 2022-12-03 22:31:31,484 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #4.
# 2022-12-03 22:31:31,495 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #5.
# 2022-12-03 22:31:31,515 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #6.
# 2022-12-03 22:31:31,755 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #7.
# 2022-12-03 22:31:32,049 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #8.
# 2022-12-03 22:31:32,135 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #9.
# 2022-12-03 22:31:56,656 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #10.
# 2022-12-03 22:32:22,159 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #11.
# 2022-12-03 22:32:22,438 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #12.
# 2022-12-03 22:32:22,506 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #13.

# %%
Fed_runner = FedRunner(data=data,
                       server_class=LaplacianServerDomSep,
                       client_class=LaplacianDomainSeparationClient,
                       config=cfg.clone(),
                       client_config=client_cfg)
Fed_runner.run()
# Out:
# server params:
# encoder_atom.atom_embedding_list.0.weight
# 2022-12-03 22:32:39,868 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-12-03 22:32:39,881 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.263789
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:39,950 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:39,951 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-12-03 22:32:39,962 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.289617
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# encoder_atom.atom_embedding_list.1.weight
# encoder_atom.atom_embedding_list.2.weight
# encoder_atom.atom_embedding_list.3.weight
# encoder_atom.atom_embedding_list.4.weight
# encoder_atom.atom_embedding_list.5.weight
# encoder_atom.atom_embedding_list.6.weight
# encoder_atom.atom_embedding_list.7.weight
# encoder_atom.atom_embedding_list.8.weight
# encoder_atom.atom_embedding_list.9.weight
# encoder_atom.atom_embedding_list.10.weight
# encoder_atom.atom_embedding_list.11.weight
# encoder_atom.atom_embedding_list.12.weight
# encoder_atom.atom_embedding_list.13.weight
# encoder_atom.atom_embedding_list.14.weight
# encoder_atom.atom_embedding_list.15.weight
# encoder_atom.atom_embedding_list.16.weight
# encoder_atom.atom_embedding_list.17.weight
# encoder_atom.atom_embedding_list.18.weight
# encoder_atom.atom_embedding_list.19.weight
# encoder_atom.atom_embedding_list.20.weight
# encoder_atom.atom_embedding_list.21.weight
# encoder.weight
# encoder.bias
# local_gnn.convs.0.nn.linears.0.weight
# local_gnn.convs.0.nn.linears.0.bias
# local_gnn.convs.0.nn.linears.1.weight
# local_gnn.convs.0.nn.linears.1.bias
# local_gnn.convs.0.nn.norms.0.weight
# local_gnn.convs.0.nn.norms.0.bias
# local_gnn.convs.0.nn.norms.1.weight
# local_gnn.convs.0.nn.norms.1.bias
# local_gnn.convs.1.nn.linears.0.weight
# local_gnn.convs.1.nn.linears.0.bias
# local_gnn.convs.1.nn.linears.1.weight
# local_gnn.convs.1.nn.linears.1.bias
# local_gnn.convs.1.nn.norms.0.weight
# local_gnn.convs.1.nn.norms.0.bias
# local_gnn.convs.1.nn.norms.1.weight
# local_gnn.convs.1.nn.norms.1.bias
# global_gnn.convs.0.nn.linears.0.weight
# global_gnn.convs.0.nn.linears.0.bias
# global_gnn.convs.0.nn.linears.1.weight
# global_gnn.convs.0.nn.linears.1.bias
# global_gnn.convs.0.nn.norms.0.weight
# global_gnn.convs.0.nn.norms.0.bias
# global_gnn.convs.0.nn.norms.1.weight
# global_gnn.convs.0.nn.norms.1.bias
# global_gnn.convs.1.nn.linears.0.weight
# global_gnn.convs.1.nn.linears.0.bias
# global_gnn.convs.1.nn.linears.1.weight
# global_gnn.convs.1.nn.linears.1.bias
# global_gnn.convs.1.nn.norms.0.weight
# global_gnn.convs.1.nn.norms.0.bias
# global_gnn.convs.1.nn.norms.1.weight
# global_gnn.convs.1.nn.norms.1.bias
# bn_edge.weight
# bn_edge.bias
# bn_node.weight
# bn_node.bias
# global_linear_out1.weight
# global_linear_out1.bias
# bn_linear0_glob.weight
# bn_linear0_glob.bias
# bn_linear1_glob.weight
# bn_linear1_glob.bias
# local_linear_out1.weight
# local_linear_out1.bias
# bn_linear0_loc.weight
# bn_linear0_loc.bias
# bn_linear1_loc.weight
# bn_linear1_loc.bias
# linear_out2.0.weight
# linear_out2.0.bias
# bn_linear2.weight
# bn_linear2.bias
# clf.weight
# clf.bias
# emb.weight
# emb.bias
# 2022-12-03 22:32:40,036 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,037 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-12-03 22:32:40,055 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.355404
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,151 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,152 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-12-03 22:32:40,162 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.176471
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,209 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,210 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-12-03 22:32:40,221 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.396825
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,280 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,281 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-12-03 22:32:40,293 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.26158
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0005
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,362 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,363 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-12-03 22:32:40,376 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.302378
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,462 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,463 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-12-03 22:32:40,478 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.211538
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,537 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,538 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-12-03 22:32:40,549 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.059199
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,628 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,630 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-12-03 22:32:40,645 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.007083
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 10
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:32:40,698 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:32:40,699 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-12-03 22:32:40,711 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.734011
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam0_diff1
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 0
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
# ...
# 2022-12-04 12:59:37,179 (monitor:512)INFO: current_best=75.26842, should_save=False
# 2022-12-04 13:01:10,189 (client:410)INFO: {'Role': 'Client #10', 'Round': 71, 'Results_raw': {'test_avg_loss': 0.171701, 'test_total': 36465, 'test_loss': 6261.088185, 'test_imp_ratio': -2324.1326, 'val_avg_loss': 0.000954, 'val_total': 36464, 'val_loss': 34.78541, 'val_imp_ratio': 86.531611}}
# 2022-12-04 13:01:10,190 (monitor:512)INFO: current_best=87.165972, should_save=False
# 2022-12-04 13:01:23,427 (client:410)INFO: {'Role': 'Client #11', 'Round': 71, 'Results_raw': {'test_avg_loss': 5.016165, 'test_total': 756, 'test_loss': 3792.220835, 'test_imp_ratio': -583.390955, 'val_avg_loss': 0.448905, 'val_total': 756, 'val_loss': 339.372116, 'val_imp_ratio': 38.842207}}
# 2022-12-04 13:01:23,429 (monitor:512)INFO: current_best=43.428902, should_save=False
# 2022-12-04 13:01:26,928 (client:410)INFO: {'Role': 'Client #12', 'Round': 71, 'Results_raw': {'test_avg_loss': 12.031576, 'test_total': 203, 'test_loss': 2442.40992, 'test_imp_ratio': -783.813, 'val_avg_loss': 0.568332, 'val_total': 203, 'val_loss': 115.371426, 'val_imp_ratio': 58.251581}}
# 2022-12-04 13:01:26,929 (monitor:512)INFO: current_best=59.951203, should_save=False
# 2022-12-04 13:02:30,115 (client:410)INFO: {'Role': 'Client #13', 'Round': 71, 'Results_raw': {'test_avg_loss': 0.264416, 'test_total': 23550, 'test_loss': 6227.00626, 'test_imp_ratio': -5924.524872, 'val_avg_loss': 0.000732, 'val_total': 23549, 'val_loss': 17.240846, 'val_imp_ratio': 83.319058}}
# 2022-12-04 13:02:30,116 (monitor:512)INFO: current_best=83.319058, should_save=True
# 2022-12-04 13:02:30,116 (client:431)INFO: Client: #13, val_imp_ratio: 83.319058. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_/model13.pth
# 2022-12-04 13:03:36,204 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #13', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.000942, 'train_total': 70648, 'train_loss': 66.526435, 'train_imp_ratio': 78.544986}}
# 2022-12-04 13:03:37,962 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #2', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.111447, 'train_loss': 201.718684, 'train_total': 1810, 'train_imp_ratio': 97.901591}}
# 2022-12-04 13:04:00,659 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #3', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.117915, 'train_loss': 2616.533284, 'train_total': 22190, 'train_imp_ratio': 90.363175}}
# 2022-12-04 13:04:14,810 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #1', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.018295, 'train_loss': 228.504409, 'train_total': 12490, 'train_imp_ratio': 97.84504}}
# 2022-12-04 13:06:26,385 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #9', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.01366, 'train_total': 134706, 'train_loss': 1840.072249, 'train_imp_ratio': 76.925433}}
# 2022-12-04 13:06:32,295 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #12', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.106134, 'train_total': 6080, 'train_loss': 645.292697, 'train_imp_ratio': 92.203655}}
# 2022-12-04 13:08:04,356 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #10', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.001121, 'train_total': 109392, 'train_loss': 122.591669, 'train_imp_ratio': 84.178119}}
# 2022-12-04 13:08:06,080 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #5', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.116266, 'train_loss': 218.580154, 'train_total': 1880, 'train_imp_ratio': 97.453189}}
# 2022-12-04 13:08:16,731 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #6', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.061444, 'train_loss': 676.499817, 'train_total': 11010, 'train_imp_ratio': 98.055553}}
# 2022-12-04 13:08:17,870 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #4', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.052242, 'train_loss': 52.763936, 'train_total': 1010, 'train_imp_ratio': 97.755781}}
# 2022-12-04 13:08:40,678 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #7', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.015893, 'train_loss': 354.102068, 'train_total': 22280, 'train_imp_ratio': 98.307848}}
# 2022-12-04 13:08:48,995 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #8', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.002142, 'train_loss': 16.640241, 'train_total': 7770, 'train_imp_ratio': 99.756639}}
# 2022-12-04 13:09:25,437 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #11', 'Round': 71, 'Results_raw': {'train_avg_loss': 0.037694, 'train_total': 22680, 'train_loss': 854.907692, 'train_imp_ratio': 94.864608}}
# 2022-12-04 13:09:25,439 (server:480)INFO: {'Role': 'Server #', 'Round': 71, 'Results_avg': {'test_avg_loss': 3.37569, 'test_loss': 10305.284599, 'test_total': 8350.846154, 'test_imp_ratio': -1104.225157, 'val_avg_loss': 0.526291, 'val_loss': 225.935557, 'val_total': 8350.461538, 'val_imp_ratio': 47.562951}}
# 2022-12-04 13:09:25,440 (monitor:512)INFO: current_best=48.042094, should_save=False
# 2022-12-04 13:09:25,441 (monitor:512)INFO: current_best=48.042094, should_save=False
# 2022-12-04 13:09:25,552 (laplacian_server:168)INFO: Server #0: Starting evaluation at the end of round 71.
# 2022-12-04 13:09:25,555 (laplacian_server:175)INFO: ----------- Starting a new training round (Round #72) -------------
# 2022-12-04 13:09:34,594 (client:410)INFO: {'Role': 'Client #1', 'Round': 72, 'Results_raw': {'test_avg_loss': 3.80793, 'test_loss': 1587.906715, 'test_total': 417, 'test_imp_ratio': -42.727256, 'val_avg_loss': 0.22876, 'val_loss': 95.163975, 'val_total': 416, 'val_imp_ratio': 87.242134}}
# 2022-12-04 13:09:34,595 (monitor:512)INFO: current_best=89.064687, should_save=False
# 2022-12-04 13:09:35,998 (client:410)INFO: {'Role': 'Client #2', 'Round': 72, 'Results_raw': {'test_avg_loss': 1.158009, 'test_loss': 70.638545, 'test_total': 61, 'test_imp_ratio': -35.849285, 'val_avg_loss': 1.026841, 'val_loss': 61.610434, 'val_total': 60, 'val_imp_ratio': -26.603986}}
# 2022-12-04 13:09:35,999 (monitor:512)INFO: current_best=-26.603986, should_save=True
# 2022-12-04 13:09:36,000 (client:431)INFO: Client: #2, val_imp_ratio: -26.603986. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_/model2.pth
# 2022-12-04 13:09:51,246 (client:410)INFO: {'Role': 'Client #3', 'Round': 72, 'Results_raw': {'test_avg_loss': 1.704757, 'test_loss': 1261.520487, 'test_total': 740, 'test_imp_ratio': -25.856011, 'val_avg_loss': 0.502493, 'val_loss': 371.844907, 'val_total': 740, 'val_imp_ratio': 48.668999}}
# 2022-12-04 13:09:51,247 (monitor:512)INFO: current_best=53.231754, should_save=False
# 2022-12-04 13:09:52,004 (client:410)INFO: {'Role': 'Client #4', 'Round': 72, 'Results_raw': {'test_avg_loss': 1.565158, 'test_loss': 53.215364, 'test_total': 34, 'test_imp_ratio': -183.332672, 'val_avg_loss': 1.185603, 'val_loss': 40.310519, 'val_total': 34, 'val_imp_ratio': 0.000233}}
# 2022-12-04 13:09:52,005 (monitor:512)INFO: current_best=16.666861, should_save=False
# 2022-12-04 13:09:53,249 (client:410)INFO: {'Role': 'Client #5', 'Round': 72, 'Results_raw': {'test_avg_loss': 1.030205, 'test_loss': 64.902931, 'test_total': 63, 'test_imp_ratio': -12.000112, 'val_avg_loss': 0.78368, 'val_loss': 49.371826, 'val_total': 63, 'val_imp_ratio': 11.999912}}
# 2022-12-04 13:09:53,250 (monitor:512)INFO: current_best=11.999912, should_save=True
# 2022-12-04 13:09:53,251 (client:431)INFO: Client: #5, val_imp_ratio: 11.999912. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_/model5.pth
# 2022-12-04 13:09:59,934 (client:410)INFO: {'Role': 'Client #6', 'Round': 72, 'Results_raw': {'test_avg_loss': 2.203487, 'test_loss': 808.679643, 'test_total': 367, 'test_imp_ratio': -186.458751, 'val_avg_loss': 0.422865, 'val_loss': 155.19137, 'val_total': 367, 'val_imp_ratio': 46.874923}}
# 2022-12-04 13:09:59,935 (monitor:512)INFO: current_best=48.958259, should_save=False
# 2022-12-04 13:10:13,365 (client:410)INFO: {'Role': 'Client #7', 'Round': 72, 'Results_raw': {'test_avg_loss': 3.687626, 'test_loss': 2739.905885, 'test_total': 743, 'test_imp_ratio': -51.780289, 'val_avg_loss': 1.156115, 'val_loss': 858.993771, 'val_total': 743, 'val_imp_ratio': 29.673649}}
# 2022-12-04 13:10:13,366 (monitor:512)INFO: current_best=38.575719, should_save=False
# 2022-12-04 13:10:17,979 (client:410)INFO: {'Role': 'Client #8', 'Round': 72, 'Results_raw': {'test_avg_loss': 8.877569, 'test_loss': 2308.167877, 'test_total': 260, 'test_imp_ratio': -312.728173, 'val_avg_loss': 0.323974, 'val_loss': 83.909328, 'val_total': 259, 'val_imp_ratio': 87.223559}}
# 2022-12-04 13:10:17,981 (monitor:512)INFO: current_best=87.223559, should_save=True
# 2022-12-04 13:10:17,981 (client:431)INFO: Client: #8, val_imp_ratio: 87.223559. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_/model8.pth
# 2022-12-04 13:12:42,406 (client:410)INFO: {'Role': 'Client #9', 'Round': 72, 'Results_raw': {'test_avg_loss': 2.518764, 'test_total': 44902, 'test_loss': 113097.552507, 'test_imp_ratio': -4154.740822, 'val_avg_loss': 0.018074, 'val_total': 44902, 'val_loss': 811.55091, 'val_imp_ratio': 69.469374}}
# 2022-12-04 13:12:42,407 (monitor:512)INFO: current_best=75.26842, should_save=False
# 2022-12-04 13:14:22,398 (client:410)INFO: {'Role': 'Client #10', 'Round': 72, 'Results_raw': {'test_avg_loss': 0.169536, 'test_total': 36465, 'test_loss': 6182.129616, 'test_imp_ratio': -2293.561552, 'val_avg_loss': 0.000908, 'val_total': 36464, 'val_loss': 33.113248, 'val_imp_ratio': 87.179051}}
# 2022-12-04 13:14:22,399 (monitor:512)INFO: current_best=87.179051, should_save=True
# 2022-12-04 13:14:22,400 (client:431)INFO: Client: #10, val_imp_ratio: 87.179051. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam0_diff1_gin_on_cikm_cup_lr0.1_lstep10_/model10.pth
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 6
#       1 Fed_runner = FedRunner(data=data,
#       2                        server_class=LaplacianServer,
#       3                        client_class=LaplacianDomainSeparationClient,
#       4                        config=cfg.clone(),
#       5                        client_config=client_cfg)
# ----> 6 Fed_runner.run()
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/fed_runner.py:186, in FedRunner.run(self)
#     184     while len(self.shared_comm_queue) > 0:
#     185         msg = self.shared_comm_queue.popleft()
# --> 186         self._handle_msg(msg)
#     188 self.server._monitor.finish_fed_runner(fl_mode=self.mode)
#     190 return self.server.best_results
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/fed_runner.py:325, in FedRunner._handle_msg(self, msg, rcv)
#     323     self.server._monitor.track_download_bytes(download_bytes)
#     324 else:
# --> 325     self.client[each_receiver].msg_handlers[msg.msg_type](msg)
#     326     self.client[each_receiver]._monitor.track_download_bytes(
#     327         download_bytes)
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/workers/client.py:389, in Client.callback_funcs_for_evaluate(self, message)
#     387 metrics = {}
#     388 if self._cfg.finetune.before_eval:
# --> 389     self.trainer.finetune()
#     390 for split in self._cfg.eval.split:
#     391     eval_metrics = self.trainer.evaluate(
#     392         target_data_split_name=split)
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/trainers/trainer.py:239, in Trainer.finetune(self, target_data_split_name, hooks_set)
#     235 hooks_set = hooks_set or self.hooks_in_ft
#     237 self.ctx.check_data_split(target_data_split_name)
# --> 239 self._run_routine(MODE.FINETUNE, hooks_set, target_data_split_name)
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/trainers/trainer.py:276, in Trainer._run_routine(self, mode, hooks_set, dataset_name)
#     274     hook(self.ctx)
#     275 for hook in hooks_set["on_batch_forward"]:
# --> 276     hook(self.ctx)
#     277 if self.ctx.cur_mode == 'train':
#     278     for hook in hooks_set["on_batch_backward"]:
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_separation_with_summation.py:150, in LaplacianDomainSeparationWithSummationTrainer._hook_on_batch_forward(self, ctx)
#     145 # record the index of the ${MODE} samples
#     146 if hasattr(ctx.data_batch, 'data_index'):
#     147     setattr(
#     148         ctx,
#     149         f'{ctx.cur_data_split}_y_inds',
# --> 150         ctx.get(f'{ctx.cur_data_split}_y_inds') + [batch[_].data_index.item() for _ in range(len(label))]
#     151     )
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_separation_with_summation.py:150, in <listcomp>(.0)
#     145 # record the index of the ${MODE} samples
#     146 if hasattr(ctx.data_batch, 'data_index'):
#     147     setattr(
#     148         ctx,
#     149         f'{ctx.cur_data_split}_y_inds',
# --> 150         ctx.get(f'{ctx.cur_data_split}_y_inds') + [batch[_].data_index.item() for _ in range(len(label))]
#     151     )
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/data/batch.py:154, in Batch.__getitem__(self, idx)
#     150 def __getitem__(self, idx: Union[int, np.integer, str, IndexType]) -> Any:
#     151     if (isinstance(idx, (int, np.integer))
#     152             or (isinstance(idx, Tensor) and idx.dim() == 0)
#     153             or (isinstance(idx, np.ndarray) and np.isscalar(idx))):
# --> 154         return self.get_example(idx)
#     155     elif isinstance(idx, str) or (isinstance(idx, tuple)
#     156                                   and isinstance(idx[0], str)):
#     157         # Accessing attributes or node/edge types:
#     158         return super().__getitem__(idx)
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/data/batch.py:103, in Batch.get_example(self, idx)
#      98 if not hasattr(self, '_slice_dict'):
#      99     raise RuntimeError(
#     100         ("Cannot reconstruct 'Data' object from 'Batch' because "
#     101          "'Batch' was not created via 'Batch.from_data_list()'"))
# --> 103 data = separate(
#     104     cls=self.__class__.__bases__[-1],
#     105     batch=self,
#     106     idx=idx,
#     107     slice_dict=self._slice_dict,
#     108     inc_dict=self._inc_dict,
#     109     decrement=True,
#     110 )
#     112 return data
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/data/separate.py:37, in separate(cls, batch, idx, slice_dict, inc_dict, decrement)
#      35         slices = slice_dict[attr]
#      36         incs = inc_dict[attr] if decrement else None
# ---> 37     data_store[attr] = _separate(attr, batch_store[attr], idx, slices,
#      38                                  incs, batch, batch_store, decrement)
#      40 # The `num_nodes` attribute needs special treatment, as we cannot infer
#      41 # the real number of nodes from the total number of nodes alone:
#      42 if hasattr(batch_store, '_num_nodes'):
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/data/separate.py:67, in _separate(key, value, idx, slices, incs, batch, store, decrement)
#      65 value = value.narrow(cat_dim or 0, start, end - start)
#      66 value = value.squeeze(0) if cat_dim is None else value
# ---> 67 if decrement and (incs.dim() > 1 or int(incs[idx]) != 0):
#      68     value = value - incs[idx].to(value.device)
#      69 return value
#
# KeyboardInterrupt:

# %% [markdown]
# -+/896*-Difference train_avg_loss: 125 -> 174
# 1: 0.539109 -> 0.540
# 2: 0.614181 -> 0.60414
# 3: 0.680621 -> 0.675371
# 4: 0.466614 -> 0.405735
# 5: 0.64907 -> 0.648837
# 6: 0.479263 -> 0.470293
# 7: 0.668663 -> 0.662036
# 8: 0.438008 -> 0.433998
# 9: 0.107733 -> 0.118945
# 10: 0.009074 -> 0.009043
# 11: 1.128238 -> 1.126667
# 12: 2.657362 -> 2.661828
# 13: -> 0.007134

# %% [markdown]
# +

# %%
data

# %%
import os

# %% [markdown]
# ,,0After 10 rounds:
#
# diff: 0, csd: 0:
# server: -8
# c1 t/val: 0.375 /0.37
# c2 t/val: 0.678 /0.606
# c3 t/val: 0.699 /0.608
# c4 t/val: 0.599 /0.537
#
# diff: 0, csd: 0:
# server: -4.5
# c1 t/val: 0.372879 /0.328
# c2 t/val: 0.678992 /0.605809
# c3 t/val: 0.70166 /0.608609
# c4 t/val: 0.597455 /0.534253
#
#
#
# diff: 10, csd: 0:
# server: -35
# c1 t/val: 0.482/0.52
# c2 t/val: 0.694/0.65
# c3 t/val: 0.724/0.65
# c4 t/val: 0.674/0.575
#
# diff: 1, csd: 0:
# server: -9.6
# c1 t/val: 0.378194/0.319349
# c2 t/val: 0.67461/0.609163
# c3 t/val: 0.705559/0.615019
# c4 t/val: 0.605581/0.572086
#
# diff: 0, csd: 1e4:
# server: -18
# c1 t/val: 0.280962/0.23074
# c2 t/val: 0.682652/0.603175
# c3 t/val: 0.699094/0.67027
# c4 t/val: 0.594985/0.609611
#
# diff: 0 csd: 1e8
# server: -18
# c1 t/val: 0.2606/0.348(0.197)
# c2 t/val: 0.653/0.0.602
# c3 t/val: 0.691/0.597
# c4 t/val: 0.581/0.629
#
# diff: 0 csd: 1e8
# server: -12.7
# c1 t/val: 0.262647/0.249875
# c2 t/val: 0.649273/0.0.600435
# c3 t/val: 0.696132/0.615158
# c4 t/val: 0.586597/0.656992
#
#
# diff: 0.1 csd: 0
# server: -11
# c1 t/val: 0.2606/0.332837
# c2 t/val: 0.678326/0.0.610099
# c3 t/val: 0.704083/0.616179
# c4 t/val: 0.604177/0.559658

# %%
os.environ['CUBLAS_WORKSPACE_CONFIG']
