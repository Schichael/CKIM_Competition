# %%
20

# %%
from federatedscope.register import register_data
from federatedscope.register import register_trainer
from federatedscope.register import register_metric
from federatedscope.register import register_model

# %%
from federatedscope.contrib.data.cikm_cup import call_cikm_cup_data

register_data("cikm_cup", call_cikm_cup_data)

# %% [markdown]
# ### Register model

# %%
#from federatedscope.contrib.model.mnist_model import call_my_net
#register_model("mynet", call_my_net)

# %% [markdown]
# ### Register trainer

# %%
from federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation import call_laplacian_trainer

register_trainer('laplacian_trainer', call_laplacian_trainer)
# Out:
# /home/michael/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/imports.py:14: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# /home/michael/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/logger.py:23: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "

# %% [markdown]
# ### Register metric

# %% [markdown]
# ### Create the config

# %% [markdown]
# #### Set data, model, trainer and metric

# %%
from federatedscope.core.configs.config import global_cfg, CN
cfg = global_cfg.clone()

cfg.merge_from_file("federatedscope/gfl/baseline/laplacian_gine_on_cikmcup.yaml")
#cfg.data.type = 'cikm_cup'
#cfg.data.root = 'data'
#cfg.data.shuffle=True
#cfg.data.transform = [['ToTensor'], ['Normalize', {'mean': [0.], 'std': [1]}]]
#cfg.model.type = 'gin'
#cfg.model.out_channels = 10
#cfg.model.hidden = 64
#cfg.model.task='graph'
#cfg.model.dropout = 0.5
#cfg.personalization.local_param = ['encoder_atom', 'encoder', 'clf']#['node_encoder', 'clf']
#cfg.train.batch_or_epoch = "epoch"
cfg.trainer.type = 'laplacian_trainer_with_domain_separation'
cfg.data.batch_size = 64
# cfg.eval.metric = ['mymetric']
cfg.params = CN()
cfg.params.alpha=0.1
cfg.params.csd_importance= 1e2
cfg.params.eps=1e-20
cfg.params.p=0.
cfg.params.diff_importance = 10
cfg.params.lam = 1

# %% [markdown]
# #### configure other options

# %%
#cfg.use_gpu = True
#cfg.best_res_update_round_wise_key = "test_loss"

#cfg.federate.mode = 'standalone'
cfg.federate.method = \
    f'Laplacian_domain_sep_sum_csd{cfg.params.csd_importance}_lam{cfg.params.lam}_diff{cfg.params.diff_importance}'
#cfg.federate.local_update_steps = 20000000
#cfg.personalization.local_update_steps = 20000000
#cfg.finetune.local_update_steps = 20000000
#cfg.train.local_update_steps = 1

cfg.federate.total_round_num = 2000

cfg.federate.client_num = 13
cfg.early_stop.patience = 10000
#cfg.train.optimizer.lr = 0.001
#cfg.train.optimizer.weight_decay = 0.0005
#cfg.grad.grad_clip = 2.0
cfg.criterion.type = 'CrossEntropyLoss'
#cfg.seed = 123
cfg.eval.freq = 1
cfg.eval.metrics = ['imp_ratio']
cfg.eval.report = ['avg']
cfg.eval.best_res_update_round_wise_key = 'val_imp_ratio'
cfg.eval.count_flops = False
cfg.data.type = "cikm_cup"

# %%
import torch
#torch.manual_seed(0)
#torch.backends.cudnn.benchmark = False
#torch.use_deterministic_algorithms(F/home/michael/Desktop/backup files/FederatedScope/data/CIKM22Competitionalse)
#import random
#random.seed(0)
#import numpy as np
#np.random.seed(0)

# %%
from yacs.config import CfgNode
client_cfg_file = "federatedscope/gfl/baseline/laplacian_gine_on_cikmcup_per_client.yaml"
client_cfg = CfgNode.load_cfg(open(client_cfg_file,
                                       'r')) if client_cfg_file else None

# %% [markdown]
# ### Start the FL prosess

# %%
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.fed_runner import FedRunner
from federatedscope.core.auxiliaries.worker_builder import get_server_cls, get_client_cls
# Out:
# 2022-12-05 10:13:12,581 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
from federatedscope.contrib.workers.laplacian_with_domain_separation_client import LaplacianDomainSeparationClient
from federatedscope.contrib.workers.laplacian_server_dom_sep import LaplacianServerDomSep

setup_seed(cfg.seed)
update_logger(cfg)
data, modified_cfg = get_data(cfg)
cfg.merge_from_other_cfg(modified_cfg)
# Out:
# 2022-12-05 10:13:12,781 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-12-05 10:13:12,783 (utils:131)INFO: the current dir is /home/michael/Master-Thesis/CKIM_Competition
# 2022-12-05 10:13:12,783 (utils:132)INFO: the output dir is exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# 2022-12-05 10:13:12,784 (cikm_cup:58)INFO: Loading CIKMCUP data from /home/michael/Master-Thesis/CKIM_Competition/data/CIKM22Competition.
# 2022-12-05 10:13:12,786 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #1.
# 2022-12-05 10:13:13,082 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #2.
# 2022-12-05 10:13:13,114 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #3.
# 2022-12-05 10:13:13,542 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #4.
# 2022-12-05 10:13:13,556 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #5.
# 2022-12-05 10:13:13,582 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #6.
# 2022-12-05 10:13:13,853 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #7.
# 2022-12-05 10:13:14,186 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #8.
# 2022-12-05 10:13:14,298 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #9.
# 2022-12-05 10:13:40,983 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #10.
# 2022-12-05 10:14:06,150 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #11.
# 2022-12-05 10:14:06,404 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #12.
# 2022-12-05 10:14:06,469 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #13.

# %%
Fed_runner = FedRunner(data=data,
                       server_class=LaplacianServerDomSep,
                       client_class=LaplacianDomainSeparationClient,
                       config=cfg.clone(),
                       client_config=client_cfg)
Fed_runner.run()
# Out:
# server params:
# encoder_atom.atom_embedding_list.0.weight
# 2022-12-05 10:14:23,024 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-12-05 10:14:23,034 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.263789
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,098 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,099 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-12-05 10:14:23,109 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.289617
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,171 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,172 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-12-05 10:14:23,183 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.355404
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# encoder_atom.atom_embedding_list.1.weight
# encoder_atom.atom_embedding_list.2.weight
# encoder_atom.atom_embedding_list.3.weight
# encoder_atom.atom_embedding_list.4.weight
# encoder_atom.atom_embedding_list.5.weight
# encoder_atom.atom_embedding_list.6.weight
# encoder_atom.atom_embedding_list.7.weight
# encoder_atom.atom_embedding_list.8.weight
# encoder_atom.atom_embedding_list.9.weight
# encoder_atom.atom_embedding_list.10.weight
# encoder_atom.atom_embedding_list.11.weight
# encoder_atom.atom_embedding_list.12.weight
# encoder_atom.atom_embedding_list.13.weight
# encoder_atom.atom_embedding_list.14.weight
# encoder_atom.atom_embedding_list.15.weight
# encoder_atom.atom_embedding_list.16.weight
# encoder_atom.atom_embedding_list.17.weight
# encoder_atom.atom_embedding_list.18.weight
# encoder_atom.atom_embedding_list.19.weight
# encoder_atom.atom_embedding_list.20.weight
# encoder_atom.atom_embedding_list.21.weight
# encoder.weight
# encoder.bias
# local_gnn.convs.0.nn.linears.0.weight
# local_gnn.convs.0.nn.linears.0.bias
# local_gnn.convs.0.nn.linears.1.weight
# local_gnn.convs.0.nn.linears.1.bias
# local_gnn.convs.0.nn.norms.0.weight
# local_gnn.convs.0.nn.norms.0.bias
# local_gnn.convs.0.nn.norms.1.weight
# local_gnn.convs.0.nn.norms.1.bias
# local_gnn.convs.1.nn.linears.0.weight
# local_gnn.convs.1.nn.linears.0.bias
# local_gnn.convs.1.nn.linears.1.weight
# local_gnn.convs.1.nn.linears.1.bias
# local_gnn.convs.1.nn.norms.0.weight
# local_gnn.convs.1.nn.norms.0.bias
# local_gnn.convs.1.nn.norms.1.weight
# local_gnn.convs.1.nn.norms.1.bias
# global_gnn.convs.0.nn.linears.0.weight
# global_gnn.convs.0.nn.linears.0.bias
# global_gnn.convs.0.nn.linears.1.weight
# global_gnn.convs.0.nn.linears.1.bias
# global_gnn.convs.0.nn.norms.0.weight
# global_gnn.convs.0.nn.norms.0.bias
# global_gnn.convs.0.nn.norms.1.weight
# global_gnn.convs.0.nn.norms.1.bias
# global_gnn.convs.1.nn.linears.0.weight
# global_gnn.convs.1.nn.linears.0.bias
# global_gnn.convs.1.nn.linears.1.weight
# global_gnn.convs.1.nn.linears.1.bias
# global_gnn.convs.1.nn.norms.0.weight
# global_gnn.convs.1.nn.norms.0.bias
# global_gnn.convs.1.nn.norms.1.weight
# global_gnn.convs.1.nn.norms.1.bias
# bn_edge.weight
# bn_edge.bias
# bn_node.weight
# bn_node.bias
# global_linear_out1.weight
# global_linear_out1.bias
# bn_linear0_glob.weight
# bn_linear0_glob.bias
# bn_linear1_glob.weight
# bn_linear1_glob.bias
# local_linear_out1.weight
# local_linear_out1.bias
# bn_linear0_loc.weight
# bn_linear0_loc.bias
# bn_linear1_loc.weight
# bn_linear1_loc.bias
# linear_out2.0.weight
# linear_out2.0.bias
# bn_linear2.weight
# bn_linear2.bias
# clf.weight
# clf.bias
# emb.weight
# emb.bias
# 2022-12-05 10:14:23,264 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,265 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-12-05 10:14:23,278 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.176471
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,325 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,326 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-12-05 10:14:23,342 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.396825
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,402 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,404 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-12-05 10:14:23,418 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.26158
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0005
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,480 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,481 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-12-05 10:14:23,492 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.302378
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,574 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,574 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-12-05 10:14:23,585 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.211538
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,645 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,646 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-12-05 10:14:23,657 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.059199
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,731 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,732 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-12-05 10:14:23,742 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.007083
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 10
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-05 10:14:23,792 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-05 10:14:23,793 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-12-05 10:14:23,804 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.734011
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff10
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 10
# ...
# 2022-12-06 12:04:17,125 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #2', 'Round': 170, 'Results_raw': {'train_avg_loss': 0.093791, 'train_total': 1810, 'train_imp_ratio': 98.092356, 'train_loss': 169.761274}}
# 2022-12-06 12:05:13,130 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #13', 'Round': 170, 'Results_raw': {'train_total': 70648, 'train_loss': 88.476356, 'train_avg_loss': 0.001252, 'train_imp_ratio': 71.466053}}
# 2022-12-06 12:05:22,528 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #6', 'Round': 170, 'Results_raw': {'train_avg_loss': 0.083415, 'train_total': 11010, 'train_imp_ratio': 93.958325, 'train_loss': 918.400845}}
# 2022-12-06 12:06:46,685 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #10', 'Round': 170, 'Results_raw': {'train_total': 109392, 'train_loss': 245.646368, 'train_avg_loss': 0.002246, 'train_imp_ratio': 68.296471}}
# 2022-12-06 12:07:06,577 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #7', 'Round': 170, 'Results_raw': {'train_avg_loss': 0.049979, 'train_total': 22280, 'train_imp_ratio': 93.958719, 'train_loss': 1113.536958}}
# 2022-12-06 12:07:26,014 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #11', 'Round': 170, 'Results_raw': {'train_total': 22680, 'train_loss': 1217.847769, 'train_avg_loss': 0.053697, 'train_imp_ratio': 92.684443}}
# 2022-12-06 12:07:26,997 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #4', 'Round': 170, 'Results_raw': {'train_avg_loss': 0.025081, 'train_total': 1010, 'train_imp_ratio': 100.0, 'train_loss': 25.331336}}
# 2022-12-06 12:07:26,999 (server:480)INFO: {'Role': 'Server #', 'Round': 170, 'Results_avg': {'test_avg_loss': 3.282031, 'test_total': 8350.846154, 'test_imp_ratio': -1130.835417, 'test_loss': 10612.524285, 'val_avg_loss': 0.463688, 'val_total': 8350.461538, 'val_imp_ratio': -110.707452, 'val_loss': 415.212444}}
# 2022-12-06 12:07:27,000 (monitor:512)INFO: current_best=38.300383, should_save=False
# 2022-12-06 12:07:27,000 (monitor:512)INFO: current_best=38.300383, should_save=False
# 2022-12-06 12:07:27,083 (laplacian_server_dom_sep:168)INFO: Server #0: Starting evaluation at the end of round 170.
# 2022-12-06 12:07:27,086 (laplacian_server_dom_sep:175)INFO: ----------- Starting a new training round (Round #171) -------------
# 2022-12-06 12:07:31,995 (client:410)INFO: {'Role': 'Client #1', 'Round': 171, 'Results_raw': {'test_avg_loss': 3.210744, 'test_total': 417, 'test_imp_ratio': -40.909074, 'test_loss': 1338.880077, 'val_avg_loss': 0.171091, 'val_total': 416, 'val_imp_ratio': 85.419582, 'val_loss': 71.173668}}
# 2022-12-06 12:07:31,997 (monitor:512)INFO: current_best=89.064687, should_save=False
# 2022-12-06 12:07:32,797 (client:410)INFO: {'Role': 'Client #2', 'Round': 171, 'Results_raw': {'test_avg_loss': 0.885523, 'test_total': 61, 'test_imp_ratio': -30.188898, 'test_loss': 54.01693, 'val_avg_loss': 1.017944, 'val_total': 60, 'val_imp_ratio': -9.339806, 'val_loss': 61.076632}}
# 2022-12-06 12:07:32,798 (monitor:512)INFO: current_best=-9.339806, should_save=True
# 2022-12-06 12:07:32,799 (client:431)INFO: Client: #2, val_imp_ratio: -9.339806. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff10_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221205101312/model2.pth
# 2022-12-06 12:07:41,520 (client:410)INFO: {'Role': 'Client #3', 'Round': 171, 'Results_raw': {'test_avg_loss': 1.488109, 'test_total': 740, 'test_imp_ratio': -18.251418, 'test_loss': 1101.200539, 'val_avg_loss': 0.494768, 'val_total': 740, 'val_imp_ratio': 50.950376, 'val_loss': 366.128366}}
# 2022-12-06 12:07:41,522 (monitor:512)INFO: current_best=55.132902, should_save=False
# 2022-12-06 12:07:42,002 (client:410)INFO: {'Role': 'Client #4', 'Round': 171, 'Results_raw': {'test_avg_loss': 1.833367, 'test_total': 34, 'test_imp_ratio': -183.332672, 'test_loss': 62.334486, 'val_avg_loss': 0.652387, 'val_total': 34, 'val_imp_ratio': -16.666394, 'val_loss': 22.181161}}
# 2022-12-06 12:07:42,004 (monitor:512)INFO: current_best=16.666861, should_save=False
# 2022-12-06 12:07:42,741 (client:410)INFO: {'Role': 'Client #5', 'Round': 171, 'Results_raw': {'test_avg_loss': 0.944994, 'test_total': 63, 'test_imp_ratio': 7.999908, 'test_loss': 59.534613, 'val_avg_loss': 0.749985, 'val_total': 63, 'val_imp_ratio': 11.999912, 'val_loss': 47.249046}}
# 2022-12-06 12:07:42,742 (monitor:512)INFO: current_best=23.999924, should_save=False
# 2022-12-06 12:07:47,106 (client:410)INFO: {'Role': 'Client #6', 'Round': 171, 'Results_raw': {'test_avg_loss': 2.305708, 'test_total': 367, 'test_imp_ratio': -186.458751, 'test_loss': 846.194753, 'val_avg_loss': 0.483525, 'val_total': 367, 'val_imp_ratio': 45.833254, 'val_loss': 177.453526}}
# 2022-12-06 12:07:47,108 (monitor:512)INFO: current_best=49.999927, should_save=False
# 2022-12-06 12:07:55,878 (client:410)INFO: {'Role': 'Client #7', 'Round': 171, 'Results_raw': {'test_avg_loss': 2.555184, 'test_total': 743, 'test_imp_ratio': -56.231324, 'test_loss': 1898.501478, 'val_avg_loss': 0.970375, 'val_total': 743, 'val_imp_ratio': 29.228546, 'val_loss': 720.988354}}
# 2022-12-06 12:07:55,879 (monitor:512)INFO: current_best=35.459994, should_save=False
# 2022-12-06 12:07:58,695 (client:410)INFO: {'Role': 'Client #8', 'Round': 171, 'Results_raw': {'test_avg_loss': 7.347445, 'test_total': 260, 'test_imp_ratio': -358.182818, 'test_loss': 1910.335812, 'val_avg_loss': 0.443083, 'val_total': 259, 'val_imp_ratio': 50.719443, 'val_loss': 114.758452}}
# 2022-12-06 12:07:58,696 (monitor:512)INFO: current_best=87.223559, should_save=False
# 2022-12-06 12:09:15,965 (client:410)INFO: {'Role': 'Client #9', 'Round': 171, 'Results_raw': {'test_total': 44902, 'test_loss': 118056.607268, 'test_avg_loss': 2.629206, 'test_imp_ratio': -4341.301276, 'val_total': 44902, 'val_loss': 4002.07987, 'val_avg_loss': 0.089129, 'val_imp_ratio': -50.558628}}
# 2022-12-06 12:09:15,966 (monitor:512)INFO: current_best=67.666637, should_save=False
# 2022-12-06 12:10:13,387 (client:410)INFO: {'Role': 'Client #10', 'Round': 171, 'Results_raw': {'test_total': 36465, 'test_loss': 6184.1194, 'test_avg_loss': 0.169591, 'test_imp_ratio': -2294.332171, 'val_total': 36464, 'val_loss': 172.164827, 'val_avg_loss': 0.004722, 'val_imp_ratio': 33.340373}}
# 2022-12-06 12:10:13,388 (monitor:512)INFO: current_best=72.819116, should_save=False
# 2022-12-06 12:10:22,324 (client:410)INFO: {'Role': 'Client #11', 'Round': 171, 'Results_raw': {'test_total': 756, 'test_loss': 4462.790302, 'test_avg_loss': 5.903162, 'test_imp_ratio': -704.233387, 'val_total': 756, 'val_loss': 326.702726, 'val_avg_loss': 0.432146, 'val_imp_ratio': 41.125347}}
# 2022-12-06 12:10:22,325 (monitor:512)INFO: current_best=42.849694, should_save=False
# 2022-12-06 12:10:24,581 (client:410)INFO: {'Role': 'Client #12', 'Round': 171, 'Results_raw': {'test_total': 203, 'test_loss': 2505.898063, 'test_avg_loss': 12.344325, 'test_imp_ratio': -806.786844, 'val_total': 203, 'val_loss': 116.028038, 'val_avg_loss': 0.571567, 'val_imp_ratio': 58.013977}}
# 2022-12-06 12:10:24,583 (monitor:512)INFO: current_best=61.56869, should_save=False
# 2022-12-06 12:11:03,867 (client:410)INFO: {'Role': 'Client #13', 'Round': 171, 'Results_raw': {'test_total': 23550, 'test_loss': 6209.502096, 'test_avg_loss': 0.263673, 'test_imp_ratio': -5907.591394, 'val_total': 23549, 'val_loss': 123.047854, 'val_avg_loss': 0.005225, 'val_imp_ratio': -19.05182}}
# 2022-12-06 12:11:03,867 (monitor:512)INFO: current_best=43.19493, should_save=False
# 2022-12-06 12:11:05,451 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #2', 'Round': 171, 'Results_raw': {'train_avg_loss': 0.090072, 'train_total': 1810, 'train_imp_ratio': 99.427707, 'train_loss': 163.030068}}
# 2022-12-06 12:11:10,582 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #12', 'Round': 171, 'Results_raw': {'train_total': 6080, 'train_loss': 676.364141, 'train_avg_loss': 0.111244, 'train_imp_ratio': 91.828254}}
# 2022-12-06 12:11:30,416 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #3', 'Round': 171, 'Results_raw': {'train_avg_loss': 0.192202, 'train_total': 22190, 'train_imp_ratio': 80.117708, 'train_loss': 4264.96808}}
# 2022-12-06 12:12:55,064 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #10', 'Round': 171, 'Results_raw': {'train_total': 109392, 'train_loss': 245.033161, 'train_avg_loss': 0.00224, 'train_imp_ratio': 68.375609}}
# 2022-12-06 12:14:47,760 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #9', 'Round': 171, 'Results_raw': {'train_total': 134706, 'train_loss': 2845.642974, 'train_avg_loss': 0.021125, 'train_imp_ratio': 64.31554}}
# 2022-12-06 12:14:49,305 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #5', 'Round': 171, 'Results_raw': {'train_avg_loss': 0.113795, 'train_total': 1880, 'train_imp_ratio': 97.319146, 'train_loss': 213.934116}}
# 2022-12-06 12:15:51,330 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #13', 'Round': 171, 'Results_raw': {'train_total': 70648, 'train_loss': 85.748348, 'train_avg_loss': 0.001214, 'train_imp_ratio': 72.345849}}
# 2022-12-06 12:16:14,827 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #11', 'Round': 171, 'Results_raw': {'train_total': 22680, 'train_loss': 1230.907304, 'train_avg_loss': 0.054273, 'train_imp_ratio': 92.605996}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 6
#       1 Fed_runner = FedRunner(data=data,
#       2                        server_class=LaplacianServerDomSep,
#       3                        client_class=LaplacianDomainSeparationClient,
#       4                        config=cfg.clone(),
#       5                        client_config=client_cfg)
# ----> 6 Fed_runner.run()
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/fed_runner.py:186, in FedRunner.run(self)
#     184     while len(self.shared_comm_queue) > 0:
#     185         msg = self.shared_comm_queue.popleft()
# --> 186         self._handle_msg(msg)
#     188 self.server._monitor.finish_fed_runner(fl_mode=self.mode)
#     190 return self.server.best_results
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/fed_runner.py:325, in FedRunner._handle_msg(self, msg, rcv)
#     323     self.server._monitor.track_download_bytes(download_bytes)
#     324 else:
# --> 325     self.client[each_receiver].msg_handlers[msg.msg_type](msg)
#     326     self.client[each_receiver]._monitor.track_download_bytes(
#     327         download_bytes)
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/workers/laplacian_with_domain_separation_client.py:131, in LaplacianDomainSeparationClient.callback_funcs_for_model_para(self, message)
#     126     logger.info(
#     127         f"[Normal FL Mode] Client #{self.ID} has been locally "
#     128         f"early stopped. "
#     129         f"The next FL update may result in negative effect")
#     130     self._monitor.local_converged()
# --> 131 sample_size, model_para_all, omega_set, results = self.trainer.train(self.state)
#     132 if self._cfg.federate.share_local_model and not \
#     133         self._cfg.federate.online_aggr:
#     134     model_para_all = copy.deepcopy(model_para_all)
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/auxiliaries/decorators.py:28, in use_diff_laplacian.<locals>.wrapper(self, *args, **kwargs)
#      24 if self.cfg.federate.use_diff:
#      25     # TODO: any issue for subclasses?
#      26     before_metric = self.evaluate(target_data_split_name='val')
# ---> 28 num_samples_train, model_para, omega, result_metric = func(
#      29     self, *args, **kwargs)
#      31 if self.cfg.federate.use_diff:
#      32     # TODO: any issue for subclasses?
#      33     after_metric = self.evaluate(target_data_split_name='val')
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_separation_with_summation.py:213, in LaplacianDomainSeparationWithSummationTrainer.train(self, state, target_data_split_name, hooks_set)
#     209 hooks_set = hooks_set or self.hooks_in_train
#     211 self.ctx.check_data_split(target_data_split_name)
# --> 213 self._run_routine(MODE.TRAIN, hooks_set, target_data_split_name)
#     214 self.first_round = False
#     216 return self.ctx.cfg.params.alpha, self.get_model_para(
#     217 ), self.get_omega_para(), self.ctx.eval_metrics
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/trainers/trainer.py:279, in Trainer._run_routine(self, mode, hooks_set, dataset_name)
#     277 if self.ctx.cur_mode == 'train':
#     278     for hook in hooks_set["on_batch_backward"]:
# --> 279         hook(self.ctx)
#     280 for hook in hooks_set["on_batch_end"]:
#     281     hook(self.ctx)
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_separation_with_summation.py:196, in LaplacianDomainSeparationWithSummationTrainer._hook_on_batch_backward(self, ctx)
#     193     torch.nn.utils.clip_grad_norm_(ctx.model.parameters(),
#     194                                    ctx.grad_clip)
#     195 prox_loss_change = self.get_prox_loss_change()
# --> 196 ctx.optimizer.step()
#     197 for key, param in prox_loss_change.items():
#     198     curr_val = self.ctx.model.state_dict()[key]
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch/optim/sgd.py:146, in SGD.step(self, closure)
#     143         else:
#     144             momentum_buffer_list.append(state['momentum_buffer'])
# --> 146 sgd(params_with_grad,
#     147     d_p_list,
#     148     momentum_buffer_list,
#     149     weight_decay=group['weight_decay'],
#     150     momentum=group['momentum'],
#     151     lr=group['lr'],
#     152     dampening=group['dampening'],
#     153     nesterov=group['nesterov'],
#     154     maximize=group['maximize'],
#     155     has_sparse_grad=has_sparse_grad,
#     156     foreach=group['foreach'])
#     158 # update momentum_buffers in state
#     159 for p, momentum_buffer in zip(params_with_grad, momentum_buffer_list):
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch/optim/sgd.py:197, in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     194 else:
#     195     func = _single_tensor_sgd
# --> 197 func(params,
#     198      d_p_list,
#     199      momentum_buffer_list,
#     200      weight_decay=weight_decay,
#     201      momentum=momentum,
#     202      lr=lr,
#     203      dampening=dampening,
#     204      nesterov=nesterov,
#     205      has_sparse_grad=has_sparse_grad,
#     206      maximize=maximize)
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch/optim/sgd.py:224, in _single_tensor_sgd(params, d_p_list, momentum_buffer_list, weight_decay, momentum, lr, dampening, nesterov, maximize, has_sparse_grad)
#     222 d_p = d_p_list[i]
#     223 if weight_decay != 0:
# --> 224     d_p = d_p.add(param, alpha=weight_decay)
#     226 if momentum != 0:
#     227     buf = momentum_buffer_list[i]
#
# KeyboardInterrupt:

# %% [markdown]
# -+/896*-Difference train_avg_loss: 125 -> 174
# 1: 0.539109 -> 0.540
# 2: 0.614181 -> 0.60414
# 3: 0.680621 -> 0.675371
# 4: 0.466614 -> 0.405735
# 5: 0.64907 -> 0.648837
# 6: 0.479263 -> 0.470293
# 7: 0.668663 -> 0.662036
# 8: 0.438008 -> 0.433998
# 9: 0.107733 -> 0.118945
# 10: 0.009074 -> 0.009043
# 11: 1.128238 -> 1.126667
# 12: 2.657362 -> 2.661828
# 13: -> 0.007134

# %% [markdown]
# +

# %%
data

# %%
import os

# %% [markdown]
# ,,0After 10 rounds:
#
# diff: 0, csd: 0:
# server: -8
# c1 t/val: 0.375 /0.37
# c2 t/val: 0.678 /0.606
# c3 t/val: 0.699 /0.608
# c4 t/val: 0.599 /0.537
#
# diff: 0, csd: 0:
# server: -4.5
# c1 t/val: 0.372879 /0.328
# c2 t/val: 0.678992 /0.605809
# c3 t/val: 0.70166 /0.608609
# c4 t/val: 0.597455 /0.534253
#
#
#
# diff: 10, csd: 0:
# server: -35
# c1 t/val: 0.482/0.52
# c2 t/val: 0.694/0.65
# c3 t/val: 0.724/0.65
# c4 t/val: 0.674/0.575
#
# diff: 1, csd: 0:
# server: -9.6
# c1 t/val: 0.378194/0.319349
# c2 t/val: 0.67461/0.609163
# c3 t/val: 0.705559/0.615019
# c4 t/val: 0.605581/0.572086
#
# diff: 0, csd: 1e4:
# server: -18
# c1 t/val: 0.280962/0.23074
# c2 t/val: 0.682652/0.603175
# c3 t/val: 0.699094/0.67027
# c4 t/val: 0.594985/0.609611
#
# diff: 0 csd: 1e8
# server: -18
# c1 t/val: 0.2606/0.348(0.197)
# c2 t/val: 0.653/0.0.602
# c3 t/val: 0.691/0.597
# c4 t/val: 0.581/0.629
#
# diff: 0 csd: 1e8
# server: -12.7
# c1 t/val: 0.262647/0.249875
# c2 t/val: 0.649273/0.0.600435
# c3 t/val: 0.696132/0.615158
# c4 t/val: 0.586597/0.656992
#
#
# diff: 0.1 csd: 0
# server: -11
# c1 t/val: 0.2606/0.332837
# c2 t/val: 0.678326/0.0.610099
# c3 t/val: 0.704083/0.616179
# c4 t/val: 0.604177/0.559658

# %%
os.environ['CUBLAS_WORKSPACE_CONFIG']
