# %%
from federatedscope.register import register_data
from federatedscope.register import register_trainer
from federatedscope.register import register_metric
from federatedscope.register import register_model

# %%
from federatedscope.contrib.data.cikm_cup import call_cikm_cup_data

register_data("cikm_cup", call_cikm_cup_data)

# %% [markdown]
# ### Register model

# %%
#from federatedscope.contrib.model.mnist_model import call_my_net
#register_model("mynet", call_my_net)

# %% [markdown]
# ### Register trainer

# %%
from federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation import call_laplacian_trainer

register_trainer('laplacian_trainer', call_laplacian_trainer)
# Out:
# /home/michael/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/imports.py:14: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# /home/michael/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/logger.py:23: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "

# %% [markdown]
# ### Register metric

# %% [markdown]
# ### Create the config

# %% [markdown]
# #### Set data, model, trainer and metric

# %%
from federatedscope.core.configs.config import global_cfg, CN
cfg = global_cfg.clone()

cfg.merge_from_file("federatedscope/gfl/baseline/laplacian_gine_on_cikmcup.yaml")
#cfg.data.type = 'cikm_cup'
#cfg.data.root = 'data'
#cfg.data.shuffle=True
#cfg.data.transform = [['ToTensor'], ['Normalize', {'mean': [0.], 'std': [1]}]]
#cfg.model.type = 'gin'
#cfg.model.out_channels = 10
#cfg.model.hidden = 64
#cfg.model.task='graph'
#cfg.model.dropout = 0.5
#cfg.personalization.local_param = ['encoder_atom', 'encoder', 'clf']#['node_encoder', 'clf']
#cfg.train.batch_or_epoch = "epoch"
cfg.trainer.type = 'laplacian_trainer_with_domain_separation'
cfg.data.batch_size = 64
# cfg.eval.metric = ['mymetric']
cfg.params = CN()
cfg.params.alpha=0.1
cfg.params.csd_importance= 1e2
cfg.params.eps=1e-20
cfg.params.p=0.
cfg.params.diff_importance = 1
cfg.params.lam = 1

# %% [markdown]
# #### configure other options

# %%
#cfg.use_gpu = True
#cfg.best_res_update_round_wise_key = "test_loss"

#cfg.federate.mode = 'standalone'
cfg.federate.method = \
    f'Laplacian_domain_sep_sum_csd{cfg.params.csd_importance}_lam{cfg.params.lam}_diff{cfg.params.diff_importance}_allclients'
#cfg.federate.local_update_steps = 20000000
#cfg.personalization.local_update_steps = 20000000
#cfg.finetune.local_update_steps = 20000000
#cfg.train.local_update_steps = 1

cfg.federate.total_round_num = 2000

cfg.federate.client_num = 13
cfg.early_stop.patience = 10000
#cfg.train.optimizer.lr = 0.001
#cfg.train.optimizer.weight_decay = 0.0005
#cfg.grad.grad_clip = 2.0
cfg.criterion.type = 'CrossEntropyLoss'
#cfg.seed = 123
cfg.eval.freq = 1
cfg.eval.metrics = ['imp_ratio']
cfg.eval.report = ['avg']
cfg.eval.best_res_update_round_wise_key = 'val_imp_ratio'
cfg.eval.count_flops = False
cfg.data.type = "cikm_cup"

# %%
import torch
#torch.manual_seed(0)
#torch.backends.cudnn.benchmark = False
#torch.use_deterministic_algorithms(F/home/michael/Desktop/backup files/FederatedScope/data/CIKM22Competitionalse)
#import random
#random.seed(0)
#import numpy as np
#np.random.seed(0)

# %%
from yacs.config import CfgNode
client_cfg_file = "federatedscope/gfl/baseline/laplacian_gine_on_cikmcup_per_client.yaml"
client_cfg = CfgNode.load_cfg(open(client_cfg_file,
                                       'r')) if client_cfg_file else None

# %% [markdown]
# ### Start the FL prosess

# %%
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.fed_runner import FedRunner
from federatedscope.core.auxiliaries.worker_builder import get_server_cls, get_client_cls
# Out:
# 2022-12-03 22:32:16,956 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
from federatedscope.contrib.workers.laplacian_with_domain_separation_client import LaplacianDomainSeparationClient
from federatedscope.contrib.workers.laplacian_server_dom_sep import LaplacianServerDomSep

setup_seed(cfg.seed)
update_logger(cfg)
data, modified_cfg = get_data(cfg)
cfg.merge_from_other_cfg(modified_cfg)
# Out:
# 2022-12-03 22:32:16,966 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-12-03 22:32:16,967 (utils:131)INFO: the current dir is /home/michael/Master-Thesis/CKIM_Competition
# 2022-12-03 22:32:16,967 (utils:132)INFO: the output dir is exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# 2022-12-03 22:32:16,968 (cikm_cup:58)INFO: Loading CIKMCUP data from /home/michael/Master-Thesis/CKIM_Competition/data/CIKM22Competition.
# 2022-12-03 22:32:16,970 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #1.
# 2022-12-03 22:32:17,214 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #2.
# 2022-12-03 22:32:17,234 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #3.
# 2022-12-03 22:32:17,509 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #4.
# 2022-12-03 22:32:17,520 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #5.
# 2022-12-03 22:32:17,540 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #6.
# 2022-12-03 22:32:17,796 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #7.
# 2022-12-03 22:32:18,131 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #8.
# 2022-12-03 22:32:18,229 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #9.
# 2022-12-03 22:32:43,500 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #10.
# 2022-12-03 22:33:09,077 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #11.
# 2022-12-03 22:33:09,334 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #12.
# 2022-12-03 22:33:09,403 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #13.

# %%
Fed_runner = FedRunner(data=data,
                       server_class=LaplacianServerDomSep,
                       client_class=LaplacianDomainSeparationClient,
                       config=cfg.clone(),
                       client_config=client_cfg)
Fed_runner.run()
# Out:
# server params:
# encoder_atom.atom_embedding_list.0.weight
# 2022-12-03 22:33:26,365 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-12-03 22:33:26,376 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.263789
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:26,446 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:26,446 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-12-03 22:33:26,457 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.289617
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# encoder_atom.atom_embedding_list.1.weight
# encoder_atom.atom_embedding_list.2.weight
# encoder_atom.atom_embedding_list.3.weight
# encoder_atom.atom_embedding_list.4.weight
# encoder_atom.atom_embedding_list.5.weight
# encoder_atom.atom_embedding_list.6.weight
# encoder_atom.atom_embedding_list.7.weight
# encoder_atom.atom_embedding_list.8.weight
# encoder_atom.atom_embedding_list.9.weight
# encoder_atom.atom_embedding_list.10.weight
# encoder_atom.atom_embedding_list.11.weight
# encoder_atom.atom_embedding_list.12.weight
# encoder_atom.atom_embedding_list.13.weight
# encoder_atom.atom_embedding_list.14.weight
# encoder_atom.atom_embedding_list.15.weight
# encoder_atom.atom_embedding_list.16.weight
# encoder_atom.atom_embedding_list.17.weight
# encoder_atom.atom_embedding_list.18.weight
# encoder_atom.atom_embedding_list.19.weight
# encoder_atom.atom_embedding_list.20.weight
# encoder_atom.atom_embedding_list.21.weight
# encoder.weight
# encoder.bias
# local_gnn.convs.0.nn.linears.0.weight
# local_gnn.convs.0.nn.linears.0.bias
# local_gnn.convs.0.nn.linears.1.weight
# local_gnn.convs.0.nn.linears.1.bias
# local_gnn.convs.0.nn.norms.0.weight
# local_gnn.convs.0.nn.norms.0.bias
# local_gnn.convs.0.nn.norms.1.weight
# local_gnn.convs.0.nn.norms.1.bias
# local_gnn.convs.1.nn.linears.0.weight
# local_gnn.convs.1.nn.linears.0.bias
# local_gnn.convs.1.nn.linears.1.weight
# local_gnn.convs.1.nn.linears.1.bias
# local_gnn.convs.1.nn.norms.0.weight
# local_gnn.convs.1.nn.norms.0.bias
# local_gnn.convs.1.nn.norms.1.weight
# local_gnn.convs.1.nn.norms.1.bias
# global_gnn.convs.0.nn.linears.0.weight
# global_gnn.convs.0.nn.linears.0.bias
# global_gnn.convs.0.nn.linears.1.weight
# global_gnn.convs.0.nn.linears.1.bias
# global_gnn.convs.0.nn.norms.0.weight
# global_gnn.convs.0.nn.norms.0.bias
# global_gnn.convs.0.nn.norms.1.weight
# global_gnn.convs.0.nn.norms.1.bias
# global_gnn.convs.1.nn.linears.0.weight
# global_gnn.convs.1.nn.linears.0.bias
# global_gnn.convs.1.nn.linears.1.weight
# global_gnn.convs.1.nn.linears.1.bias
# global_gnn.convs.1.nn.norms.0.weight
# global_gnn.convs.1.nn.norms.0.bias
# global_gnn.convs.1.nn.norms.1.weight
# global_gnn.convs.1.nn.norms.1.bias
# bn_edge.weight
# bn_edge.bias
# bn_node.weight
# bn_node.bias
# global_linear_out1.weight
# global_linear_out1.bias
# bn_linear0_glob.weight
# bn_linear0_glob.bias
# bn_linear1_glob.weight
# bn_linear1_glob.bias
# local_linear_out1.weight
# local_linear_out1.bias
# bn_linear0_loc.weight
# bn_linear0_loc.bias
# bn_linear1_loc.weight
# bn_linear1_loc.bias
# linear_out2.0.weight
# linear_out2.0.bias
# bn_linear2.weight
# bn_linear2.bias
# clf.weight
# clf.bias
# emb.weight
# emb.bias
# 2022-12-03 22:33:26,542 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:26,543 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-12-03 22:33:26,558 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.355404
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:26,652 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:26,652 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-12-03 22:33:26,663 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.176471
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:26,716 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:26,717 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-12-03 22:33:26,728 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.396825
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:26,789 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:26,790 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-12-03 22:33:26,802 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.26158
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0005
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:26,885 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:26,886 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-12-03 22:33:26,899 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.302378
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:26,990 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:26,991 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-12-03 22:33:27,004 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.211538
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'accuracy']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:27,079 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:27,080 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-12-03 22:33:27,093 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.059199
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:27,174 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:27,174 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-12-03 22:33:27,187 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.007083
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 10
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216
# params:
#   alpha: 0.1
#   csd_importance: 100.0
#   diff_importance: 1
#   eps: 1e-20
#   lam: 1
#   p: 0.0
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'emb', 'bn_dec', 'norms', 'norm', 'bn', 'linear_out1_loc', 'bn_linear2_loc', 'local', 'linear_out2']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-03 22:33:27,241 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_separation_with_summation.LaplacianDomainSeparationWithSummationTrainer'>
# 2022-12-03 22:33:27,242 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-12-03 22:33:27,253 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.734011
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 2000
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
# ...
# 2022-12-04 12:57:30,966 (monitor:512)INFO: current_best=16.666861, should_save=False
# 2022-12-04 12:57:32,163 (client:410)INFO: {'Role': 'Client #5', 'Round': 71, 'Results_raw': {'test_loss': 53.089056, 'test_total': 63, 'test_imp_ratio': 3.999904, 'test_avg_loss': 0.842683, 'val_loss': 38.073489, 'val_total': 63, 'val_imp_ratio': 11.999912, 'val_avg_loss': 0.604341}}
# 2022-12-04 12:57:32,164 (monitor:512)INFO: current_best=23.999924, should_save=False
# 2022-12-04 12:57:38,552 (client:410)INFO: {'Role': 'Client #6', 'Round': 71, 'Results_raw': {'test_loss': 640.165999, 'test_total': 367, 'test_imp_ratio': -173.958733, 'test_avg_loss': 1.744322, 'val_loss': 153.74645, 'val_total': 367, 'val_imp_ratio': 41.666582, 'val_avg_loss': 0.418928}}
# 2022-12-04 12:57:38,553 (monitor:512)INFO: current_best=48.958259, should_save=False
# 2022-12-04 12:57:51,947 (client:410)INFO: {'Role': 'Client #7', 'Round': 71, 'Results_raw': {'test_loss': 1839.119457, 'test_total': 743, 'test_imp_ratio': -57.121531, 'test_avg_loss': 2.475262, 'val_loss': 569.70449, 'val_total': 743, 'val_imp_ratio': 27.893235, 'val_avg_loss': 0.766762}}
# 2022-12-04 12:57:51,948 (monitor:512)INFO: current_best=32.34427, should_save=False
# 2022-12-04 12:57:56,381 (client:410)INFO: {'Role': 'Client #8', 'Round': 71, 'Results_raw': {'test_loss': 2241.562927, 'test_total': 260, 'test_imp_ratio': -321.819102, 'test_avg_loss': 8.621396, 'val_loss': 79.613432, 'val_total': 259, 'val_imp_ratio': 81.747942, 'val_avg_loss': 0.307388}}
# 2022-12-04 12:57:56,382 (monitor:512)INFO: current_best=87.223559, should_save=False
# 2022-12-04 12:59:56,843 (client:410)INFO: {'Role': 'Client #9', 'Round': 71, 'Results_raw': {'test_loss': 105845.083452, 'test_avg_loss': 2.357247, 'test_total': 44902, 'test_imp_ratio': -3881.902798, 'val_loss': 867.026685, 'val_avg_loss': 0.019309, 'val_total': 44902, 'val_imp_ratio': 67.382371}}
# 2022-12-04 12:59:56,844 (monitor:512)INFO: current_best=70.005287, should_save=False
# 2022-12-04 13:01:29,960 (client:410)INFO: {'Role': 'Client #10', 'Round': 71, 'Results_raw': {'test_loss': 6257.124009, 'test_avg_loss': 0.171593, 'test_total': 36465, 'test_imp_ratio': -2322.597884, 'val_loss': 38.675426, 'val_avg_loss': 0.001061, 'val_total': 36464, 'val_imp_ratio': 85.025461}}
# 2022-12-04 13:01:29,960 (monitor:512)INFO: current_best=85.405388, should_save=False
# 2022-12-04 13:01:43,525 (client:410)INFO: {'Role': 'Client #11', 'Round': 71, 'Results_raw': {'test_loss': 3842.638901, 'test_avg_loss': 5.082856, 'test_total': 756, 'test_imp_ratio': -592.476775, 'val_loss': 364.479472, 'val_avg_loss': 0.482116, 'val_total': 756, 'val_imp_ratio': 34.317648}}
# 2022-12-04 13:01:43,526 (monitor:512)INFO: current_best=37.282155, should_save=False
# 2022-12-04 13:01:47,070 (client:410)INFO: {'Role': 'Client #12', 'Round': 71, 'Results_raw': {'test_loss': 2439.632115, 'test_avg_loss': 12.017892, 'test_total': 203, 'test_imp_ratio': -782.807783, 'val_loss': 105.985517, 'val_avg_loss': 0.522096, 'val_total': 203, 'val_imp_ratio': 61.64797}}
# 2022-12-04 13:01:47,071 (monitor:512)INFO: current_best=61.64797, should_save=True
# 2022-12-04 13:01:47,071 (client:431)INFO: Client: #12, val_imp_ratio: 61.64797. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216/model12.pth
# 2022-12-04 13:02:51,213 (client:410)INFO: {'Role': 'Client #13', 'Round': 71, 'Results_raw': {'test_loss': 6223.59551, 'test_avg_loss': 0.264272, 'test_total': 23550, 'test_imp_ratio': -5921.225499, 'val_loss': 21.58242, 'val_avg_loss': 0.000916, 'val_total': 23549, 'val_imp_ratio': 79.118481}}
# 2022-12-04 13:02:51,214 (monitor:512)INFO: current_best=79.185842, should_save=False
# 2022-12-04 13:03:58,673 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #13', 'Round': 71, 'Results_raw': {'train_loss': 76.620044, 'train_avg_loss': 0.001085, 'train_total': 70648, 'train_imp_ratio': 75.289762}}
# 2022-12-04 13:04:00,563 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #2', 'Round': 71, 'Results_raw': {'train_loss': 344.635456, 'train_total': 1810, 'train_imp_ratio': 91.606366, 'train_avg_loss': 0.190406}}
# 2022-12-04 13:04:24,653 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #3', 'Round': 71, 'Results_raw': {'train_loss': 5694.132293, 'train_total': 22190, 'train_imp_ratio': 71.837647, 'train_avg_loss': 0.256608}}
# 2022-12-04 13:04:38,018 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #1', 'Round': 71, 'Results_raw': {'train_loss': 371.079061, 'train_total': 12490, 'train_imp_ratio': 96.357814, 'train_avg_loss': 0.02971}}
# 2022-12-04 13:06:46,855 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #9', 'Round': 71, 'Results_raw': {'train_loss': 2731.828426, 'train_avg_loss': 0.02028, 'train_total': 134706, 'train_imp_ratio': 65.742781}}
# 2022-12-04 13:06:52,289 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #12', 'Round': 71, 'Results_raw': {'train_loss': 866.629953, 'train_avg_loss': 0.142538, 'train_total': 6080, 'train_imp_ratio': 89.529486}}
# 2022-12-04 13:08:25,453 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #10', 'Round': 71, 'Results_raw': {'train_loss': 145.099638, 'train_avg_loss': 0.001326, 'train_total': 109392, 'train_imp_ratio': 81.273204}}
# 2022-12-04 13:08:27,405 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #5', 'Round': 71, 'Results_raw': {'train_loss': 367.969718, 'train_total': 1880, 'train_imp_ratio': 94.370207, 'train_avg_loss': 0.195729}}
# 2022-12-04 13:08:39,457 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #6', 'Round': 71, 'Results_raw': {'train_loss': 1785.353606, 'train_total': 11010, 'train_imp_ratio': 85.937479, 'train_avg_loss': 0.162157}}
# 2022-12-04 13:08:40,744 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #4', 'Round': 71, 'Results_raw': {'train_loss': 74.861217, 'train_total': 1010, 'train_imp_ratio': 95.511562, 'train_avg_loss': 0.07412}}
# 2022-12-04 13:09:13,645 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #7', 'Round': 71, 'Results_raw': {'train_loss': 1563.428422, 'train_total': 22280, 'train_imp_ratio': 92.28141, 'train_avg_loss': 0.070172}}
# 2022-12-04 13:09:25,275 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #8', 'Round': 71, 'Results_raw': {'train_loss': 69.566986, 'train_total': 7770, 'train_imp_ratio': 98.539835, 'train_avg_loss': 0.008953}}
# 2022-12-04 13:09:48,031 (laplacian_with_domain_separation_client:140)INFO: {'Role': 'Client #11', 'Round': 71, 'Results_raw': {'train_loss': 1925.167874, 'train_avg_loss': 0.084884, 'train_total': 22680, 'train_imp_ratio': 88.435602}}
# 2022-12-04 13:09:48,033 (server:480)INFO: {'Role': 'Server #', 'Round': 71, 'Results_avg': {'test_loss': 10141.081553, 'test_total': 8350.846154, 'test_imp_ratio': -1103.856684, 'test_avg_loss': 3.11682, 'val_loss': 211.793553, 'val_total': 8350.461538, 'val_imp_ratio': 43.656235, 'val_avg_loss': 0.403163}}
# 2022-12-04 13:09:48,034 (monitor:512)INFO: current_best=46.246746, should_save=False
# 2022-12-04 13:09:48,035 (monitor:512)INFO: current_best=46.246746, should_save=False
# 2022-12-04 13:09:48,120 (laplacian_server:168)INFO: Server #0: Starting evaluation at the end of round 71.
# 2022-12-04 13:09:48,123 (laplacian_server:175)INFO: ----------- Starting a new training round (Round #72) -------------
# 2022-12-04 13:09:55,626 (client:410)INFO: {'Role': 'Client #1', 'Round': 72, 'Results_raw': {'test_loss': 1409.550031, 'test_total': 417, 'test_imp_ratio': -43.636347, 'test_avg_loss': 3.380216, 'val_loss': 83.411209, 'val_total': 416, 'val_imp_ratio': 88.15341, 'val_avg_loss': 0.200508}}
# 2022-12-04 13:09:55,627 (monitor:512)INFO: current_best=88.15341, should_save=True
# 2022-12-04 13:09:55,627 (client:431)INFO: Client: #1, val_imp_ratio: 88.15341. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216/model1.pth
# 2022-12-04 13:09:56,838 (client:410)INFO: {'Role': 'Client #2', 'Round': 72, 'Results_raw': {'test_loss': 58.344144, 'test_total': 61, 'test_imp_ratio': -52.830445, 'test_avg_loss': 0.956461, 'val_loss': 57.461382, 'val_total': 60, 'val_imp_ratio': -49.622893, 'val_avg_loss': 0.95769}}
# 2022-12-04 13:09:56,839 (monitor:512)INFO: current_best=-38.113439, should_save=False
# 2022-12-04 13:10:10,366 (client:410)INFO: {'Role': 'Client #3', 'Round': 72, 'Results_raw': {'test_loss': 978.866355, 'test_total': 740, 'test_imp_ratio': -22.814174, 'test_avg_loss': 1.322792, 'val_loss': 358.183993, 'val_total': 740, 'val_imp_ratio': 43.726013, 'val_avg_loss': 0.484032}}
# 2022-12-04 13:10:10,367 (monitor:512)INFO: current_best=47.908539, should_save=False
# 2022-12-04 13:10:11,131 (client:410)INFO: {'Role': 'Client #4', 'Round': 72, 'Results_raw': {'test_loss': 47.701578, 'test_total': 34, 'test_imp_ratio': -183.332672, 'test_avg_loss': 1.402988, 'val_loss': 14.707469, 'val_total': 34, 'val_imp_ratio': 16.666861, 'val_avg_loss': 0.432573}}
# 2022-12-04 13:10:11,132 (monitor:512)INFO: current_best=16.666861, should_save=True
# 2022-12-04 13:10:11,133 (client:431)INFO: Client: #4, val_imp_ratio: 16.666861. model saved at exp/Laplacian_domain_sep_sum_csd100.0_lam1_diff1_allclients_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221203223216/model4.pth
# 2022-12-04 13:10:12,349 (client:410)INFO: {'Role': 'Client #5', 'Round': 72, 'Results_raw': {'test_loss': 68.504763, 'test_total': 63, 'test_imp_ratio': -4.000104, 'test_avg_loss': 1.087377, 'val_loss': 50.587294, 'val_total': 63, 'val_imp_ratio': 3.999904, 'val_avg_loss': 0.802973}}
# 2022-12-04 13:10:12,350 (monitor:512)INFO: current_best=23.999924, should_save=False
# 2022-12-04 13:10:18,792 (client:410)INFO: {'Role': 'Client #6', 'Round': 72, 'Results_raw': {'test_loss': 659.984474, 'test_total': 367, 'test_imp_ratio': -179.167074, 'test_avg_loss': 1.798323, 'val_loss': 152.436195, 'val_total': 367, 'val_imp_ratio': 44.791586, 'val_avg_loss': 0.415357}}
# 2022-12-04 13:10:18,793 (monitor:512)INFO: current_best=48.958259, should_save=False
# 2022-12-04 13:10:32,154 (client:410)INFO: {'Role': 'Client #7', 'Round': 72, 'Results_raw': {'test_loss': 1818.140321, 'test_total': 743, 'test_imp_ratio': -49.554771, 'test_avg_loss': 2.447026, 'val_loss': 583.180425, 'val_total': 743, 'val_imp_ratio': 28.338339, 'val_avg_loss': 0.7849}}
# 2022-12-04 13:10:32,155 (monitor:512)INFO: current_best=32.34427, should_save=False
# 2022-12-04 13:10:36,628 (client:410)INFO: {'Role': 'Client #8', 'Round': 72, 'Results_raw': {'test_loss': 2176.120007, 'test_total': 260, 'test_imp_ratio': -320.000916, 'test_avg_loss': 8.369692, 'val_loss': 74.266881, 'val_total': 259, 'val_imp_ratio': 81.747942, 'val_avg_loss': 0.286745}}
# 2022-12-04 13:10:36,629 (monitor:512)INFO: current_best=87.223559, should_save=False
# 2022-12-04 13:13:03,960 (client:410)INFO: {'Role': 'Client #9', 'Round': 72, 'Results_raw': {'test_loss': 112480.315136, 'test_avg_loss': 2.505018, 'test_total': 44902, 'test_imp_ratio': -4131.520393, 'val_loss': 832.295061, 'val_avg_loss': 0.018536, 'val_total': 44902, 'val_imp_ratio': 68.688979}}
# 2022-12-04 13:13:03,961 (monitor:512)INFO: current_best=70.005287, should_save=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 6
#       1 Fed_runner = FedRunner(data=data,
#       2                        server_class=LaplacianServer,
#       3                        client_class=LaplacianDomainSeparationClient,
#       4                        config=cfg.clone(),
#       5                        client_config=client_cfg)
# ----> 6 Fed_runner.run()
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/fed_runner.py:186, in FedRunner.run(self)
#     184     while len(self.shared_comm_queue) > 0:
#     185         msg = self.shared_comm_queue.popleft()
# --> 186         self._handle_msg(msg)
#     188 self.server._monitor.finish_fed_runner(fl_mode=self.mode)
#     190 return self.server.best_results
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/fed_runner.py:325, in FedRunner._handle_msg(self, msg, rcv)
#     323     self.server._monitor.track_download_bytes(download_bytes)
#     324 else:
# --> 325     self.client[each_receiver].msg_handlers[msg.msg_type](msg)
#     326     self.client[each_receiver]._monitor.track_download_bytes(
#     327         download_bytes)
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/workers/client.py:391, in Client.callback_funcs_for_evaluate(self, message)
#     389     self.trainer.finetune()
#     390 for split in self._cfg.eval.split:
# --> 391     eval_metrics = self.trainer.evaluate(
#     392         target_data_split_name=split)
#     394     if self._cfg.federate.mode == 'distributed':
#     395         logger.info(
#     396             self._monitor.format_eval_res(eval_metrics,
#     397                                           rnd=self.state,
#     398                                           role='Client #{}'.format(
#     399                                               self.ID),
#     400                                           return_raw=True))
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/trainers/torch_trainer.py:76, in GeneralTorchTrainer.evaluate(self, target_data_split_name)
#      74 def evaluate(self, target_data_split_name="test"):
#      75     with torch.no_grad():
# ---> 76         super(GeneralTorchTrainer, self).evaluate(target_data_split_name)
#      78     return self.ctx.eval_metrics
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/trainers/trainer.py:228, in Trainer.evaluate(self, target_data_split_name, hooks_set)
#     225 hooks_set = hooks_set or self.hooks_in_eval
#     227 if self.ctx.check_data_split(target_data_split_name, skip=True):
# --> 228     self._run_routine(MODE.TEST, hooks_set, target_data_split_name)
#     229 else:
#     230     self.ctx.eval_metrics = dict()
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/core/trainers/trainer.py:276, in Trainer._run_routine(self, mode, hooks_set, dataset_name)
#     274     hook(self.ctx)
#     275 for hook in hooks_set["on_batch_forward"]:
# --> 276     hook(self.ctx)
#     277 if self.ctx.cur_mode == 'train':
#     278     for hook in hooks_set["on_batch_backward"]:
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_separation_with_summation.py:132, in LaplacianDomainSeparationWithSummationTrainer._hook_on_batch_forward(self, ctx)
#     130 if len(label.size()) == 0:
#     131     label = label.unsqueeze(0)
# --> 132 ctx.diff_loss = diffloss(out_enc_shared, out_enc_private)
#     133 ctx.aggr_diff_loss += ctx.diff_loss.item()
#     134 ctx.batchnumbers += 1
#
# File ~/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Master-Thesis/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_separation_with_summation.py:266, in DiffLoss.forward(self, input1, input2)
#     264 def forward(self, input1, input2):
#     265     batch_size = input1.size(0)
# --> 266     input1 = input1.view(batch_size, -1)
#     267     input2 = input2.view(batch_size, -1)
#     269     input1_l2_norm = torch.norm(input1, p=2, dim=1, keepdim=True).detach()
#
# KeyboardInterrupt:

# %% [markdown]
# -+/896*-Difference train_avg_loss: 125 -> 174
# 1: 0.539109 -> 0.540
# 2: 0.614181 -> 0.60414
# 3: 0.680621 -> 0.675371
# 4: 0.466614 -> 0.405735
# 5: 0.64907 -> 0.648837
# 6: 0.479263 -> 0.470293
# 7: 0.668663 -> 0.662036
# 8: 0.438008 -> 0.433998
# 9: 0.107733 -> 0.118945
# 10: 0.009074 -> 0.009043
# 11: 1.128238 -> 1.126667
# 12: 2.657362 -> 2.661828
# 13: -> 0.007134

# %%
data

# %%
/home/michael/Master-Thesis/CKIM_Competition/data/CIKM22Competition

# %%
import os

# %% [markdown]
# ,,0After 10 rounds:
#
# diff: 0, csd: 0:
# server: -8
# c1 t/val: 0.375 /0.37
# c2 t/val: 0.678 /0.606
# c3 t/val: 0.699 /0.608
# c4 t/val: 0.599 /0.537
#
# diff: 0, csd: 0:
# server: -4.5
# c1 t/val: 0.372879 /0.328
# c2 t/val: 0.678992 /0.605809
# c3 t/val: 0.70166 /0.608609
# c4 t/val: 0.597455 /0.534253
#
#
#
# diff: 10, csd: 0:
# server: -35
# c1 t/val: 0.482/0.52
# c2 t/val: 0.694/0.65
# c3 t/val: 0.724/0.65
# c4 t/val: 0.674/0.575
#
# diff: 1, csd: 0:
# server: -9.6
# c1 t/val: 0.378194/0.319349
# c2 t/val: 0.67461/0.609163
# c3 t/val: 0.705559/0.615019
# c4 t/val: 0.605581/0.572086
#
# diff: 0, csd: 1e4:
# server: -18
# c1 t/val: 0.280962/0.23074
# c2 t/val: 0.682652/0.603175
# c3 t/val: 0.699094/0.67027
# c4 t/val: 0.594985/0.609611
#
# diff: 0 csd: 1e8
# server: -18
# c1 t/val: 0.2606/0.348(0.197)
# c2 t/val: 0.653/0.0.602
# c3 t/val: 0.691/0.597
# c4 t/val: 0.581/0.629
#
# diff: 0 csd: 1e8
# server: -12.7
# c1 t/val: 0.262647/0.249875
# c2 t/val: 0.649273/0.0.600435
# c3 t/val: 0.696132/0.615158
# c4 t/val: 0.586597/0.656992
#
#
# diff: 0.1 csd: 0
# server: -11
# c1 t/val: 0.2606/0.332837
# c2 t/val: 0.678326/0.0.610099
# c3 t/val: 0.704083/0.616179
# c4 t/val: 0.604177/0.559658

# %%
os.environ['CUBLAS_WORKSPACE_CONFIG']
