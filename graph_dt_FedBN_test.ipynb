# %%
import torch
# The train split of client 1
cl_num = 0
train_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/train.pt')
val_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/val.pt')
test_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/test.pt')
print(len(train_data_client) + len(val_data_client) + len(test_data_client))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 4
#       2 # The train split of client 1
#       3 cl_num = 5
# ----> 4 train_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/train.pt')
#       5 val_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/val.pt')
#       6 test_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/test.pt')
#
# File ~/test/CKIM_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:699, in load(f, map_location, pickle_module, **pickle_load_args)
#     696 if 'encoding' not in pickle_load_args.keys():
#     697     pickle_load_args['encoding'] = 'utf-8'
# --> 699 with _open_file_like(f, 'rb') as opened_file:
#     700     if _is_zipfile(opened_file):
#     701         # The zipfile reader is going to advance the current file position.
#     702         # If we want to actually tail call to torch.jit.load, we need to
#     703         # reset back to the original position.
#     704         orig_position = opened_file.tell()
#
# File ~/test/CKIM_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:230, in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# File ~/test/CKIM_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:211, in _open_file.__init__(self, name, mode)
#     210 def __init__(self, name, mode):
# --> 211     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/graph_dt/processed/5/train.pt'

# %% [markdown]
# 1: ESOL(12)
# 2: FreeSolv(11)
# 3: Lipophilicity (13)
# 4: BACE (7)
# 5: BBBP (8)
# 6: ClinTox (6)
# 7: MUTAG (1)
# 8: PTC_MR (3)
# 9: PTC_MM (2)
# 10:  PTC_FM (4)
# 11: PTC_FR (5) Zu viele Datem: 1440
# 12: NCI109 (10)
# 13: NCI1 (9)
# 14: alchemy_full (15)
# 15: ZINC_full (16)
# 16: QM9 (13) (zu viele Daten? 130831)

# %%
len(train_data_client)

# %%
import os
import sys

from federatedscope.core.cmd_args import parse_args
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.auxiliaries.worker_builder import get_client_cls, get_server_cls
from federatedscope.core.configs.config import global_cfg
from federatedscope.core.fed_runner import FedRunner
from yacs.config import CfgNode
from rdkit.Chem.Draw import IPythonConsole

if os.environ.get('https_proxy'):
    del os.environ['https_proxy']
if os.environ.get('http_proxy'):
    del os.environ['http_proxy']

# %%
cfg_file = 'scripts/B-FHTL_exp_scripts/Graph-DT/fedbn.yaml'
cfg_client = 'scripts/B-FHTL_exp_scripts/Graph-DT/cfg_per_client_bn_own.yaml'

init_cfg = global_cfg.clone()
init_cfg.merge_from_file(cfg_file)
# init_cfg.merge_from_list(args.opts)

update_logger(init_cfg)
setup_seed(init_cfg.seed)

# federated dataset might change the number of clients
# thus, we allow the creation procedure of dataset to modify the global cfg object
data, modified_cfg = get_data(config=init_cfg.clone())
init_cfg.merge_from_other_cfg(modified_cfg)

init_cfg.freeze()

# allow different settings for different clients
# cfg_client.merge_from_file(args.cfg_client)
if cfg_client is None:
    cfg_client = None
else:
    cfg_client = CfgNode.load_cfg(open(cfg_client, 'r')).clone()
# Out:
# 2022-12-19 23:53:13,502 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-12-19 23:53:13,503 (utils:131)INFO: the current dir is /home/michael/Projects/CKIM_Competition
# 2022-12-19 23:53:13,504 (utils:132)INFO: the output dir is exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# 2022-12-20 00:10:25,894 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.0
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graph
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False

# %%
runner = FedRunner(data=data,
                   server_class=get_server_cls(init_cfg),
                   client_class=get_client_cls(init_cfg),
                   config=init_cfg.clone(),
                   client_config=cfg_client)
_ = runner.run()
# Out:
# 2022-12-20 00:10:25,987 (worker_builder:73)WARNING: Server for method Graph-DC-FedBN is not implemented. Will use default one
# 2022-12-20 00:10:25,990 (worker_builder:22)WARNING: Clients for method Graph-DC-FedBN is not implemented. Will use default one
# 2022-12-20 00:10:27,622 (aggregator_builder:21)WARNING: Aggregator for method Graph-DC-FedBN is not implemented. Will use default one
# 2022-12-20 00:10:27,633 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-12-20 00:10:27,662 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 1.451
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,686 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-12-20 00:10:27,706 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.099
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,728 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-12-20 00:10:27,744 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.954
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,769 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-12-20 00:10:27,787 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.579
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,804 (fed_runner:302)INFO: Client 4 has been set up ...
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-20 00:10:27,824 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.766
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.025
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,840 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-12-20 00:10:27,864 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.579
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.025
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,882 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-12-20 00:10:27,899 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.632
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,913 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-12-20 00:10:27,929 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.581
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.0001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,943 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-12-20 00:10:27,963 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.676
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:27,977 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-12-20 00:10:27,994 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.457
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:28,008 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-12-20 00:10:28,025 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.889
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-20 00:10:28,042 (fed_runner:302)INFO: Client 11 has been set up ...
# 2022-12-20 00:10:28,064 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.624
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 00:10:28,090 (fed_runner:302)INFO: Client 12 has been set up ...
# 2022-12-20 00:10:28,109 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 300
#   the_smaller_the_better: False
# eval:
#   base: 0.589
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
# ...
# 2022-12-20 00:44:49,915 (monitor:513)INFO: current_best=-1.271899, should_save=False
# 2022-12-20 00:44:52,568 (client:415)INFO: {'Role': 'Client #14', 'Round': 28, 'Results_raw': {'test_loss': 381.590695, 'test_total': 20258, 'test_imp_ratio': -135.456764, 'test_avg_loss': 0.018837, 'val_loss': 381.541867, 'val_total': 20258, 'val_imp_ratio': -135.426612, 'val_avg_loss': 0.018834}}
# 2022-12-20 00:44:52,569 (monitor:513)INFO: current_best=-34.892925, should_save=False
# 2022-12-20 00:44:55,805 (client:415)INFO: {'Role': 'Client #15', 'Round': 28, 'Results_raw': {'test_loss': 3228.544262, 'test_total': 24946, 'test_imp_ratio': -123.140213, 'test_avg_loss': 0.129421, 'val_loss': 3250.12683, 'val_total': 24946, 'val_imp_ratio': -124.631896, 'val_avg_loss': 0.130286}}
# 2022-12-20 00:44:55,807 (monitor:513)INFO: current_best=28.705169, should_save=False
# 2022-12-20 00:44:57,486 (client:415)INFO: {'Role': 'Client #16', 'Round': 28, 'Results_raw': {'test_loss': 161.846387, 'test_total': 13084, 'test_imp_ratio': -147.395877, 'test_avg_loss': 0.01237, 'val_loss': 163.196883, 'val_total': 13083, 'val_imp_ratio': -149.47932, 'val_avg_loss': 0.012474}}
# 2022-12-20 00:44:57,488 (monitor:513)INFO: current_best=-81.833506, should_save=False
# 2022-12-20 00:44:57,655 (client:260)INFO: {'Role': 'Client #11', 'Round': 28, 'Results_raw': {'train_loss': 486.233263, 'train_imp_ratio': -5.089989, 'train_acc': 0.84375, 'train_total': 1152, 'train_avg_loss': 0.422077}}
# 2022-12-20 00:44:57,943 (client:260)INFO: {'Role': 'Client #6', 'Round': 28, 'Results_raw': {'train_loss': 1106.259621, 'train_imp_ratio': 16.820577, 'train_acc': 0.676391, 'train_total': 1851, 'train_avg_loss': 0.597655}}
# 2022-12-20 00:44:58,411 (client:260)INFO: {'Role': 'Client #12', 'Round': 28, 'Results_raw': {'train_loss': 2041.974607, 'train_imp_ratio': 7.387816, 'train_acc': 0.6701, 'train_total': 3301, 'train_avg_loss': 0.618593}}
# 2022-12-20 00:44:58,546 (client:260)INFO: {'Role': 'Client #1', 'Round': 28, 'Results_raw': {'train_loss': 2633.847384, 'train_total': 901, 'train_imp_ratio': -101.464422, 'train_avg_loss': 2.923249}}
# 2022-12-20 00:44:58,969 (client:260)INFO: {'Role': 'Client #13', 'Round': 28, 'Results_raw': {'train_loss': 2111.330971, 'train_imp_ratio': 8.590584, 'train_acc': 0.639599, 'train_total': 3288, 'train_avg_loss': 0.642132}}
# 2022-12-20 00:44:59,477 (client:260)INFO: {'Role': 'Client #3', 'Round': 28, 'Results_raw': {'train_loss': 3980.184742, 'train_total': 3360, 'train_imp_ratio': -24.169683, 'train_avg_loss': 1.184579}}
# 2022-12-20 00:45:22,686 (client:260)INFO: {'Role': 'Client #14', 'Round': 28, 'Results_raw': {'train_loss': 1227.423303, 'train_total': 162063, 'train_imp_ratio': 5.328272, 'train_avg_loss': 0.007574}}
# 2022-12-20 00:45:22,923 (client:260)INFO: {'Role': 'Client #5', 'Round': 28, 'Results_raw': {'train_loss': 739.168171, 'train_imp_ratio': 4.054441, 'train_acc': 0.797057, 'train_total': 1631, 'train_avg_loss': 0.453199}}
# 2022-12-20 00:45:22,984 (client:260)INFO: {'Role': 'Client #8', 'Round': 28, 'Results_raw': {'train_loss': 192.349732, 'train_imp_ratio': -14.8803, 'train_acc': 0.494545, 'train_total': 275, 'train_avg_loss': 0.699454}}
# 2022-12-20 00:45:23,076 (client:260)INFO: {'Role': 'Client #2', 'Round': 28, 'Results_raw': {'train_loss': 68.664519, 'train_total': 512, 'train_imp_ratio': -35.465042, 'train_avg_loss': 0.13411}}
# 2022-12-20 00:45:38,304 (client:260)INFO: {'Role': 'Client #16', 'Round': 28, 'Results_raw': {'train_loss': 409.739132, 'train_total': 104664, 'train_imp_ratio': 21.703907, 'train_avg_loss': 0.003915}}
# 2022-12-20 00:45:38,494 (client:260)INFO: {'Role': 'Client #4', 'Round': 28, 'Results_raw': {'train_loss': 800.928612, 'train_imp_ratio': 3.055996, 'train_acc': 0.596694, 'train_total': 1210, 'train_avg_loss': 0.661924}}
# 2022-12-20 00:46:06,886 (client:260)INFO: {'Role': 'Client #15', 'Round': 28, 'Results_raw': {'train_loss': 8018.689257, 'train_total': 199564, 'train_imp_ratio': 30.722344, 'train_avg_loss': 0.040181}}
# 2022-12-20 00:46:06,935 (client:260)INFO: {'Role': 'Client #10', 'Round': 28, 'Results_raw': {'train_loss': 181.92777, 'train_imp_ratio': 40.388854, 'train_acc': 0.641577, 'train_total': 279, 'train_avg_loss': 0.652071}}
# 2022-12-20 00:46:06,977 (client:260)INFO: {'Role': 'Client #9', 'Round': 28, 'Results_raw': {'train_loss': 168.578827, 'train_imp_ratio': -4.508522, 'train_acc': 0.645522, 'train_total': 268, 'train_avg_loss': 0.629025}}
# 2022-12-20 00:46:07,013 (client:260)INFO: {'Role': 'Client #7', 'Round': 28, 'Results_raw': {'train_loss': 66.066393, 'train_imp_ratio': 19.198312, 'train_acc': 0.753333, 'train_total': 150, 'train_avg_loss': 0.440443}}
# 2022-12-20 00:46:07,017 (server:496)INFO: {'Role': 'Server #', 'Round': 28, 'Results_avg': {'test_loss': 866.237406, 'test_total': 3785.25, 'test_imp_ratio': -194.579681, 'test_avg_loss': 2.201297, 'val_loss': 775.908817, 'val_total': 3784.9375, 'val_imp_ratio': -170.547705, 'val_avg_loss': 1.906608, 'test_acc': 0.550853, 'val_acc': 0.540631}}
# 2022-12-20 00:46:07,020 (monitor:513)INFO: current_best=-44.163091, should_save=False
# 2022-12-20 00:46:07,021 (monitor:513)INFO: current_best=-44.163091, should_save=False
# 2022-12-20 00:46:07,032 (server:323)INFO: Server #0: Starting evaluation at the end of round 28.
# 2022-12-20 00:46:07,035 (server:330)INFO: ----------- Starting a new training round (Round #29) -------------
# 2022-12-20 00:46:07,087 (client:415)INFO: {'Role': 'Client #1', 'Round': 29, 'Results_raw': {'test_loss': 884.733071, 'test_total': 113, 'test_imp_ratio': -439.593135, 'test_avg_loss': 7.829496, 'val_loss': 730.257083, 'val_total': 113, 'val_imp_ratio': -345.379182, 'val_avg_loss': 6.462452}}
# 2022-12-20 00:46:07,089 (monitor:513)INFO: current_best=-144.774825, should_save=False
# 2022-12-20 00:46:07,119 (client:415)INFO: {'Role': 'Client #2', 'Round': 29, 'Results_raw': {'test_loss': 135.671204, 'test_total': 64, 'test_imp_ratio': -2041.27555, 'test_avg_loss': 2.119863, 'val_loss': 129.002782, 'val_total': 63, 'val_imp_ratio': -1968.346679, 'val_avg_loss': 2.047663}}
# 2022-12-20 00:46:07,121 (monitor:513)INFO: current_best=-38.887763, should_save=False
# 2022-12-20 00:46:07,216 (client:415)INFO: {'Role': 'Client #3', 'Round': 29, 'Results_raw': {'test_loss': 14135.331192, 'test_total': 420, 'test_imp_ratio': -3427.83563, 'test_avg_loss': 33.65555, 'val_loss': 14572.154648, 'val_total': 420, 'val_imp_ratio': -3536.855999, 'val_avg_loss': 34.695606}}
# 2022-12-20 00:46:07,218 (monitor:513)INFO: current_best=-72.45828, should_save=False
# 2022-12-20 00:46:07,279 (client:415)INFO: {'Role': 'Client #4', 'Round': 29, 'Results_raw': {'test_loss': 110.984592, 'test_imp_ratio': -19.325516, 'test_acc': 0.467105, 'test_total': 152, 'test_avg_loss': 0.730162, 'val_loss': 102.667418, 'val_imp_ratio': -2.778254, 'val_acc': 0.562914, 'val_total': 151, 'val_avg_loss': 0.679917}}
# 2022-12-20 00:46:07,281 (monitor:513)INFO: current_best=6.372028, should_save=False
# 2022-12-20 00:46:07,338 (client:415)INFO: {'Role': 'Client #5', 'Round': 29, 'Results_raw': {'test_loss': 124.038368, 'test_imp_ratio': -2.728716, 'test_acc': 0.745098, 'test_total': 204, 'test_avg_loss': 0.608031, 'val_loss': 114.21183, 'val_imp_ratio': 1.11094, 'val_acc': 0.77451, 'val_total': 204, 'val_avg_loss': 0.559862}}
# 2022-12-20 00:46:07,339 (monitor:513)INFO: current_best=1.11094, should_save=True
# 2022-12-20 00:46:07,341 (client:436)INFO: Client: #5, val_imp_ratio: 1.11094. model saved at exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313/model5.pth
# 2022-12-20 00:46:07,402 (client:415)INFO: {'Role': 'Client #6', 'Round': 29, 'Results_raw': {'test_loss': 267.254606, 'test_imp_ratio': -3.966411, 'test_acc': 0.556034, 'test_total': 232, 'test_avg_loss': 1.15196, 'val_loss': 259.947036, 'val_imp_ratio': -3.550681, 'val_acc': 0.558442, 'val_total': 231, 'val_avg_loss': 1.125312}}
# 2022-12-20 00:46:07,403 (monitor:513)INFO: current_best=13.64571, should_save=False
# 2022-12-20 00:46:07,431 (client:415)INFO: {'Role': 'Client #7', 'Round': 29, 'Results_raw': {'test_loss': 29.539771, 'test_imp_ratio': -50.033311, 'test_acc': 0.315789, 'test_total': 19, 'test_avg_loss': 1.554725, 'val_loss': 28.785, 'val_imp_ratio': -50.033311, 'val_acc': 0.315789, 'val_total': 19, 'val_avg_loss': 1.515}}
# 2022-12-20 00:46:07,432 (monitor:513)INFO: current_best=24.916722, should_save=False
# 2022-12-20 00:46:07,452 (client:415)INFO: {'Role': 'Client #8', 'Round': 29, 'Results_raw': {'test_loss': 23.421754, 'test_imp_ratio': 3.270224, 'test_acc': 0.6, 'test_total': 35, 'test_avg_loss': 0.669193, 'val_loss': 23.822049, 'val_imp_ratio': -13.94148, 'val_acc': 0.5, 'val_total': 34, 'val_avg_loss': 0.700648}}
# 2022-12-20 00:46:07,454 (monitor:513)INFO: current_best=-13.94148, should_save=True
# 2022-12-20 00:46:07,455 (client:436)INFO: Client: #8, val_imp_ratio: -13.94148. model saved at exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313/model8.pth
# 2022-12-20 00:46:07,485 (client:415)INFO: {'Role': 'Client #9', 'Round': 29, 'Results_raw': {'test_loss': 17.183566, 'test_imp_ratio': 13.122172, 'test_acc': 0.764706, 'test_total': 34, 'test_avg_loss': 0.505399, 'val_loss': 25.053938, 'val_imp_ratio': -12.982945, 'val_acc': 0.588235, 'val_total': 34, 'val_avg_loss': 0.736881}}
# 2022-12-20 00:46:07,486 (monitor:513)INFO: current_best=-8.632092, should_save=False
# 2022-12-20 00:46:07,519 (client:415)INFO: {'Role': 'Client #10', 'Round': 29, 'Results_raw': {'test_loss': 24.934328, 'test_imp_ratio': 18.787121, 'test_acc': 0.542857, 'test_total': 35, 'test_avg_loss': 0.712409, 'val_loss': 24.65754, 'val_imp_ratio': 25.039075, 'val_acc': 0.571429, 'val_total': 35, 'val_avg_loss': 0.704501}}
# 2022-12-20 00:46:07,521 (monitor:513)INFO: current_best=25.039075, should_save=True
# 2022-12-20 00:46:07,522 (client:436)INFO: Client: #10, val_imp_ratio: 25.039075. model saved at exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313/model10.pth
# 2022-12-20 00:46:07,566 (client:415)INFO: {'Role': 'Client #11', 'Round': 29, 'Results_raw': {'test_loss': 92.518461, 'test_imp_ratio': -5.480565, 'test_acc': 0.840278, 'test_total': 144, 'test_avg_loss': 0.642489, 'val_loss': 99.332851, 'val_imp_ratio': -8.605174, 'val_acc': 0.8125, 'val_total': 144, 'val_avg_loss': 0.689811}}
# 2022-12-20 00:46:07,568 (monitor:513)INFO: current_best=-8.605174, should_save=True
# 2022-12-20 00:46:07,569 (client:436)INFO: Client: #11, val_imp_ratio: -8.605174. model saved at exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219235313/model11.pth
# 2022-12-20 00:46:07,692 (client:415)INFO: {'Role': 'Client #12', 'Round': 29, 'Results_raw': {'test_loss': 324.682152, 'test_imp_ratio': -27.438381, 'test_acc': 0.452785, 'test_total': 413, 'test_avg_loss': 0.786155, 'val_loss': 317.216074, 'val_imp_ratio': -18.51369, 'val_acc': 0.508475, 'val_total': 413, 'val_avg_loss': 0.768078}}
# 2022-12-20 00:46:07,694 (monitor:513)INFO: current_best=-6.872788, should_save=False
# 2022-12-20 00:46:07,780 (client:415)INFO: {'Role': 'Client #13', 'Round': 29, 'Results_raw': {'test_loss': 455.103532, 'test_imp_ratio': -11.599106, 'test_acc': 0.520681, 'test_total': 411, 'test_avg_loss': 1.107308, 'val_loss': 514.857688, 'val_imp_ratio': -19.447784, 'val_acc': 0.474453, 'val_total': 411, 'val_avg_loss': 1.252695}}
# 2022-12-20 00:46:07,782 (monitor:513)INFO: current_best=-1.271899, should_save=False
# 2022-12-20 00:46:10,515 (client:415)INFO: {'Role': 'Client #14', 'Round': 29, 'Results_raw': {'test_loss': 535.89059, 'test_total': 20258, 'test_imp_ratio': -230.665964, 'test_avg_loss': 0.026453, 'val_loss': 536.551443, 'val_total': 20258, 'val_imp_ratio': -231.07379, 'val_avg_loss': 0.026486}}
# 2022-12-20 00:46:10,517 (monitor:513)INFO: current_best=-34.892925, should_save=False
# 2022-12-20 00:46:14,262 (client:415)INFO: {'Role': 'Client #15', 'Round': 29, 'Results_raw': {'test_loss': 5403.673373, 'test_total': 24946, 'test_imp_ratio': -273.473841, 'test_avg_loss': 0.216615, 'val_loss': 5440.183561, 'val_total': 24946, 'val_imp_ratio': -275.997224, 'val_avg_loss': 0.218078}}
# 2022-12-20 00:46:14,263 (monitor:513)INFO: current_best=28.705169, should_save=False
# 2022-12-20 00:46:15,964 (client:415)INFO: {'Role': 'Client #16', 'Round': 29, 'Results_raw': {'test_loss': 172.555073, 'test_total': 13084, 'test_imp_ratio': -163.765007, 'test_avg_loss': 0.013188, 'val_loss': 173.895591, 'val_total': 13083, 'val_imp_ratio': -165.834443, 'val_avg_loss': 0.013292}}
# 2022-12-20 00:46:15,965 (monitor:513)INFO: current_best=-81.833506, should_save=False
# 2022-12-20 00:46:16,104 (client:260)INFO: {'Role': 'Client #1', 'Round': 29, 'Results_raw': {'train_loss': 2326.332929, 'train_total': 901, 'train_imp_ratio': -77.942499, 'train_avg_loss': 2.581946}}
# 2022-12-20 00:46:16,588 (client:260)INFO: {'Role': 'Client #3', 'Round': 29, 'Results_raw': {'train_loss': 3999.741505, 'train_total': 3360, 'train_imp_ratio': -24.7798, 'train_avg_loss': 1.190399}}
# 2022-12-20 00:46:30,402 (client:260)INFO: {'Role': 'Client #16', 'Round': 29, 'Results_raw': {'train_loss': 410.958024, 'train_total': 104664, 'train_imp_ratio': 21.47102, 'train_avg_loss': 0.003926}}
# 2022-12-20 00:46:30,596 (client:260)INFO: {'Role': 'Client #4', 'Round': 29, 'Results_raw': {'train_loss': 800.984383, 'train_imp_ratio': 3.055996, 'train_acc': 0.596694, 'train_total': 1210, 'train_avg_loss': 0.661971}}
# 2022-12-20 00:46:30,862 (client:260)INFO: {'Role': 'Client #6', 'Round': 29, 'Results_raw': {'train_loss': 1107.733755, 'train_imp_ratio': 14.021362, 'train_acc': 0.660184, 'train_total': 1851, 'train_avg_loss': 0.598452}}
# 2022-12-20 00:46:30,912 (client:260)INFO: {'Role': 'Client #10', 'Round': 29, 'Results_raw': {'train_loss': 186.161758, 'train_imp_ratio': 35.683082, 'train_acc': 0.620072, 'train_total': 279, 'train_avg_loss': 0.667246}}
# 2022-12-20 00:46:31,400 (client:260)INFO: {'Role': 'Client #12', 'Round': 29, 'Results_raw': {'train_loss': 2039.617567, 'train_imp_ratio': 5.979928, 'train_acc': 0.661315, 'train_total': 3301, 'train_avg_loss': 0.617879}}
# 2022-12-20 00:46:31,588 (client:260)INFO: {'Role': 'Client #11', 'Round': 29, 'Results_raw': {'train_loss': 483.684473, 'train_imp_ratio': -5.089989, 'train_acc': 0.84375, 'train_total': 1152, 'train_avg_loss': 0.419865}}
# 2022-12-20 00:46:31,624 (client:260)INFO: {'Role': 'Client #7', 'Round': 29, 'Results_raw': {'train_loss': 68.941379, 'train_imp_ratio': 18.14346, 'train_acc': 0.746667, 'train_total': 150, 'train_avg_loss': 0.459609}}
# 2022-12-20 00:46:58,902 (client:260)INFO: {'Role': 'Client #15', 'Round': 29, 'Results_raw': {'train_loss': 8033.013005, 'train_total': 199564, 'train_imp_ratio': 30.598587, 'train_avg_loss': 0.040253}}
# 2022-12-20 00:46:58,988 (client:260)INFO: {'Role': 'Client #2', 'Round': 29, 'Results_raw': {'train_loss': 76.724523, 'train_total': 512, 'train_imp_ratio': -51.366236, 'train_avg_loss': 0.149853}}
# 2022-12-20 00:46:59,493 (client:260)INFO: {'Role': 'Client #13', 'Round': 29, 'Results_raw': {'train_loss': 2095.342036, 'train_imp_ratio': 9.778213, 'train_acc': 0.646594, 'train_total': 3288, 'train_avg_loss': 0.637269}}
# 2022-12-20 00:46:59,762 (client:260)INFO: {'Role': 'Client #5', 'Round': 29, 'Results_raw': {'train_loss': 746.25074, 'train_imp_ratio': 2.453604, 'train_acc': 0.784795, 'train_total': 1631, 'train_avg_loss': 0.457542}}
# 2022-12-20 00:46:59,821 (client:260)INFO: {'Role': 'Client #9', 'Round': 29, 'Results_raw': {'train_loss': 167.607254, 'train_imp_ratio': -2.300627, 'train_acc': 0.660448, 'train_total': 268, 'train_avg_loss': 0.6254}}
# 2022-12-20 00:46:59,888 (client:260)INFO: {'Role': 'Client #8', 'Round': 29, 'Results_raw': {'train_loss': 192.07898, 'train_imp_ratio': -10.499139, 'train_acc': 0.52, 'train_total': 275, 'train_avg_loss': 0.698469}}
#
# KeyboardInterrupt

# %%
1

# %%
cfg_client['client_4']['eval']['metrics']=['mse']

# %%
cfg_client['client_5']['eval']['metrics']=['mse']

# %%
cfg_client['client_6']['eval']['metrics']=['mse']

# %%
cfg_client['client_7']['eval']['metrics']=['mse']

# %%
cfg_client['client_8']['eval']['metrics']=['mse']

# %%
cfg_client['client_9']['eval']['metrics']=['mse']

# %%
cfg_client['client_10']['eval']['metrics']=['mse']

# %%
cfg_client['client_11']['eval']['metrics']=['mse']

# %%
cfg_client['client_12']['eval']['metrics']=['mse']

# %%
cfg_client['client_13']['eval']['metrics']=['mse']

# %%
cl_list = ['client_' + str(i) for i in range(1,17)]

# %%
cl_list
# Out:
# ['client_1',
#  'client_2',
#  'client_3',
#  'client_4',
#  'client_5',
#  'client_6',
#  'client_7',
#  'client_8',
#  'client_9',
#  'client_10',
#  'client_11',
#  'client_12',
#  'client_13',
#  'client_14',
#  'client_15',
#  'client_16']

# %%
cfg_client['client_13']['train']['local_update_steps']
# Out:
# 21

# %%
for el in cl_list:
    cfg_client[el]['train']['local_update_steps']=1

# %%
cfg_client
# Out:
# CfgNode({'client_1': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.01}), 'local_update_steps': 1})}), 'client_2': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1})}), 'client_3': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1})}), 'client_4': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.01}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_5': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_6': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_7': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_8': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.0001}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_9': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_10': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_11': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_12': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_13': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_14': CfgNode({'model': CfgNode({'out_channels': 12, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1})}), 'client_15': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1})}), 'client_16': CfgNode({'model': CfgNode({'out_channels': 19, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1})})})
