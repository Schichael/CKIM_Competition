# %%
import torch
# The train split of client 1
cl_num = 0
train_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/train.pt')
val_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/val.pt')
test_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/test.pt')
print(len(train_data_client) + len(val_data_client) + len(test_data_client))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 4
#       2 # The train split of client 1
#       3 cl_num = 5
# ----> 4 train_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/train.pt')
#       5 val_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/val.pt')
#       6 test_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/test.pt')
#
# File ~/test/CKIM_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:699, in load(f, map_location, pickle_module, **pickle_load_args)
#     696 if 'encoding' not in pickle_load_args.keys():
#     697     pickle_load_args['encoding'] = 'utf-8'
# --> 699 with _open_file_like(f, 'rb') as opened_file:
#     700     if _is_zipfile(opened_file):
#     701         # The zipfile reader is going to advance the current file position.
#     702         # If we want to actually tail call to torch.jit.load, we need to
#     703         # reset back to the original position.
#     704         orig_position = opened_file.tell()
#
# File ~/test/CKIM_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:230, in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# File ~/test/CKIM_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:211, in _open_file.__init__(self, name, mode)
#     210 def __init__(self, name, mode):
# --> 211     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/graph_dt/processed/5/train.pt'

# %% [markdown]
# 1: ESOL(12)
# 2: FreeSolv(11)
# 3: Lipophilicity (13)
# 4: BACE (7)
# 5: BBBP (8)
# 6: ClinTox (6)
# 7: MUTAG (1)
# 8: PTC_MR (3)
# 9: PTC_MM (2)
# 10:  PTC_FM (4)
# 11: PTC_FR (5) Zu viele Datem: 1440
# 12: NCI109 (10)
# 13: NCI1 (9)
# 14: alchemy_full (15)
# 15: ZINC_full (16)
# 16: QM9 (13) (zu viele Daten? 130831)

# %%
len(train_data_client)

# %%
import os
import sys

from federatedscope.core.cmd_args import parse_args
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.auxiliaries.worker_builder import get_client_cls, get_server_cls
from federatedscope.core.configs.config import global_cfg
from federatedscope.core.fed_runner import FedRunner
from yacs.config import CfgNode
from rdkit.Chem.Draw import IPythonConsole

if os.environ.get('https_proxy'):
    del os.environ['https_proxy']
if os.environ.get('http_proxy'):
    del os.environ['http_proxy']
# Out:
# 2022-12-19 18:17:43,591 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
cfg_file = 'scripts/B-FHTL_exp_scripts/Graph-DT/fedbn.yaml'
cfg_client = 'scripts/B-FHTL_exp_scripts/Graph-DT/cfg_per_client_bn_own.yaml'

init_cfg = global_cfg.clone()
init_cfg.merge_from_file(cfg_file)
# init_cfg.merge_from_list(args.opts)

update_logger(init_cfg)
setup_seed(init_cfg.seed)

# federated dataset might change the number of clients
# thus, we allow the creation procedure of dataset to modify the global cfg object
data, modified_cfg = get_data(config=init_cfg.clone())
init_cfg.merge_from_other_cfg(modified_cfg)

init_cfg.freeze()

# allow different settings for different clients
# cfg_client.merge_from_file(args.cfg_client)
if cfg_client is None:
    cfg_client = None
else:
    cfg_client = CfgNode.load_cfg(open(cfg_client, 'r')).clone()
# Out:
# 2022-12-19 18:17:43,611 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-12-19 18:17:43,611 (utils:131)INFO: the current dir is /home/michael/Master-Thesis/CKIM_Competition
# 2022-12-19 18:17:43,612 (utils:132)INFO: the output dir is exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# 2022-12-19 18:24:31,053 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.0
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graph
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False

# %%
runner = FedRunner(data=data,
                   server_class=get_server_cls(init_cfg),
                   client_class=get_client_cls(init_cfg),
                   config=init_cfg.clone(),
                   client_config=cfg_client)
_ = runner.run()
# Out:
# 2022-12-19 18:24:31,076 (worker_builder:73)WARNING: Server for method Graph-DC-FedBN is not implemented. Will use default one
# 2022-12-19 18:24:31,077 (worker_builder:22)WARNING: Clients for method Graph-DC-FedBN is not implemented. Will use default one
# /home/michael/Master-Thesis/CKIM_Competition/venv/lib/python3.9/site-packages/torch/nn/init.py:405: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# 2022-12-19 18:24:31,385 (aggregator_builder:21)WARNING: Aggregator for method Graph-DC-FedBN is not implemented. Will use default one
# 2022-12-19 18:24:31,385 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-12-19 18:24:31,398 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 1.451
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,407 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-12-19 18:24:31,420 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.099
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,429 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-12-19 18:24:31,441 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.954
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,451 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-12-19 18:24:31,463 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.579
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,477 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-12-19 18:24:31,488 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.766
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.025
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,497 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-12-19 18:24:31,506 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.579
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.025
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,515 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-12-19 18:24:31,526 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.632
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,532 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-12-19 18:24:31,543 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.581
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.0001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,556 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-12-19 18:24:31,566 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.676
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,574 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-12-19 18:24:31,584 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.457
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,592 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-12-19 18:24:31,604 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.889
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,612 (fed_runner:302)INFO: Client 11 has been set up ...
# 2022-12-19 18:24:31,623 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.624
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,634 (fed_runner:302)INFO: Client 12 has been set up ...
# 2022-12-19 18:24:31,645 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.589
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,656 (fed_runner:302)INFO: Client 13 has been set up ...
# 2022-12-19 18:24:31,666 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.008
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 12
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,676 (fed_runner:302)INFO: Client 14 has been set up ...
# 2022-12-19 18:24:31,687 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.058
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,702 (fed_runner:302)INFO: Client 15 has been set up ...
# 2022-12-19 18:24:31,714 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 16
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: graph-dt
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.005
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_
# expname_tag:
# federate:
#   client_num: 16
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Graph-DC-FedBN
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 16
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 19
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Graph-DC-FedBN_gin_on_graph-dt_lr0.5_lstep21_/sub_exp_20221219181743
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'norms']
#   local_update_steps: 21
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 21
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-19 18:24:31,723 (fed_runner:302)INFO: Client 16 has been set up ...
# 2022-12-19 18:24:31,724 (trainer:324)INFO: Model meta-info: <class 'federatedscope.gfl.model.graph_level.GNN_Net_Graph'>.
# 2022-12-19 18:24:31,725 (trainer:332)INFO: Num of original para names: 58.
# 2022-12-19 18:24:31,725 (trainer:333)INFO: Num of original trainable para names: 44.
# 2022-12-19 18:24:31,726 (trainer:335)INFO: Num of preserved para names in local update: 12.
# Preserved para names in local update: {'gnn.convs.1.nn.linears.0.bias', 'linear.0.weight', 'linear.0.bias', 'gnn.convs.0.nn.linears.0.weight', 'gnn.convs.0.nn.linears.0.bias', 'gnn.convs.0.eps', 'gnn.convs.0.nn.linears.1.weight', 'gnn.convs.1.nn.linears.0.weight', 'gnn.convs.1.nn.linears.1.bias', 'gnn.convs.0.nn.linears.1.bias', 'gnn.convs.1.nn.linears.1.weight', 'gnn.convs.1.eps'}.
# 2022-12-19 18:24:31,726 (trainer:339)INFO: Num of filtered para names in local update: 46.
# Filtered para names in local update: {'gnn.convs.0.nn.norms.1.weight', 'encoder_atom.atom_embedding_list.11.weight', 'gnn.convs.0.nn.norms.1.running_var', 'gnn.convs.0.nn.norms.0.weight', 'gnn.convs.1.nn.norms.0.num_batches_tracked', 'encoder_atom.atom_embedding_list.0.weight', 'encoder_atom.atom_embedding_list.18.weight', 'encoder_atom.atom_embedding_list.13.weight', 'encoder_atom.atom_embedding_list.8.weight', 'gnn.convs.0.nn.norms.0.num_batches_tracked', 'encoder_atom.atom_embedding_list.16.weight', 'gnn.convs.0.nn.norms.0.bias', 'encoder_atom.atom_embedding_list.17.weight', 'encoder_atom.atom_embedding_list.1.weight', 'gnn.convs.0.nn.norms.1.bias', 'gnn.convs.0.nn.norms.1.num_batches_tracked', 'encoder_atom.atom_embedding_list.19.weight', 'encoder_atom.atom_embedding_list.14.weight', 'encoder_atom.atom_embedding_list.10.weight', 'gnn.convs.1.nn.norms.0.running_mean', 'gnn.convs.1.nn.norms.1.weight', 'gnn.convs.0.nn.norms.0.running_mean', 'gnn.convs.0.nn.norms.1.running_mean', 'gnn.convs.1.nn.norms.1.running_var', 'clf.weight', 'encoder_atom.atom_embedding_list.4.weight', 'encoder_atom.atom_embedding_list.21.weight', 'encoder_atom.atom_embedding_list.12.weight', 'clf.bias', 'gnn.convs.1.nn.norms.0.weight', 'gnn.convs.1.nn.norms.1.num_batches_tracked', 'encoder.bias', 'encoder_atom.atom_embedding_list.20.weight', 'encoder_atom.atom_embedding_list.6.weight', 'encoder_atom.atom_embedding_list.9.weight', 'gnn.convs.1.nn.norms.1.bias', 'gnn.convs.1.nn.norms.0.bias', 'gnn.convs.1.nn.norms.1.running_mean', 'encoder.weight', 'encoder_atom.atom_embedding_list.2.weight', 'gnn.convs.0.nn.norms.0.running_var', 'encoder_atom.atom_embedding_list.5.weight', 'encoder_atom.atom_embedding_list.7.weight', 'encoder_atom.atom_embedding_list.3.weight', 'encoder_atom.atom_embedding_list.15.weight', 'gnn.convs.1.nn.norms.0.running_var'}.
# 2022-12-19 18:24:31,727 (trainer:344)INFO: After register default hooks,
# 	the hooks_in_train is:
# 	{
# 	  "on_fit_start": [
# 	    "_hook_on_fit_start_init",
# 	    "_hook_on_fit_start_calculate_model_size"
# 	  ],
# 	  "on_epoch_start": [
# 	    "_hook_on_epoch_start"
# 	  ],
# 	  "on_batch_start": [
# 	    "_hook_on_batch_start_init"
# 	  ],
# 	  "on_batch_forward": [
# 	    "_hook_on_batch_forward",
# 	    "_hook_on_batch_forward_regularizer",
# 	    "_hook_on_batch_forward_flop_count"
# 	  ],
# 	  "on_batch_backward": [
# 	    "_hook_on_batch_backward"
# 	  ],
# 	  "on_batch_end": [
# 	    "_hook_on_batch_end"
# 	  ],
# 	  "on_fit_end": [
# 	    "_hook_on_fit_end"
# 	  ]
# 	};
# 	the hooks_in_eval is:
#             t{
# 	  "on_fit_start": [
# 	    "_hook_on_fit_start_init"
# 	  ],
# 	  "on_epoch_start": [
# 	    "_hook_on_epoch_start"
# 	  ],
# 	  "on_batch_start": [
# 	    "_hook_on_batch_start_init"
# 	  ],
# 	  "on_batch_forward": [
# 	    "_hook_on_batch_forward"
# 	  ],
# 	  "on_batch_end": [
# 	    "_hook_on_batch_end"
# 	  ],
# 	  "on_fit_end": [
# 	    "_hook_on_fit_end"
# 	  ]
# 	}
# 2022-12-19 18:24:31,734 (server:644)INFO: ----------- Starting training (Round #0) -------------

# %%
1

# %%
cfg_client['client_4']['eval']['metrics']=['mse']

# %%
cfg_client['client_5']['eval']['metrics']=['mse']

# %%
cfg_client['client_6']['eval']['metrics']=['mse']

# %%
cfg_client['client_7']['eval']['metrics']=['mse']

# %%
cfg_client['client_8']['eval']['metrics']=['mse']

# %%
cfg_client['client_9']['eval']['metrics']=['mse']

# %%
cfg_client['client_10']['eval']['metrics']=['mse']

# %%
cfg_client['client_11']['eval']['metrics']=['mse']

# %%
cfg_client['client_12']['eval']['metrics']=['mse']

# %%
cfg_client['client_13']['eval']['metrics']=['mse']

# %%
cl_list = ['client_' + str(i) for i in range(1,17)]

# %%
cl_list
# Out:
# ['client_1',
#  'client_2',
#  'client_3',
#  'client_4',
#  'client_5',
#  'client_6',
#  'client_7',
#  'client_8',
#  'client_9',
#  'client_10',
#  'client_11',
#  'client_12',
#  'client_13',
#  'client_14',
#  'client_15',
#  'client_16']

# %%
cfg_client['client_13']['train']['local_update_steps']
# Out:
# 21

# %%
for el in cl_list:
    cfg_client[el]['train']['local_update_steps']=1

# %%
cfg_client
# Out:
# CfgNode({'client_1': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.01}), 'local_update_steps': 1})}), 'client_2': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1})}), 'client_3': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1})}), 'client_4': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.01}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_5': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_6': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_7': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_8': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.0001}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_9': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_10': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_11': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_12': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_13': CfgNode({'model': CfgNode({'out_channels': 2, 'task': 'graphClassification'}), 'criterion': CfgNode({'type': 'CrossEntropyLoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1}), 'eval': CfgNode({'metrics': ['acc']})}), 'client_14': CfgNode({'model': CfgNode({'out_channels': 12, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1})}), 'client_15': CfgNode({'model': CfgNode({'out_channels': 1, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.1}), 'local_update_steps': 1})}), 'client_16': CfgNode({'model': CfgNode({'out_channels': 19, 'task': 'graphRegression'}), 'criterion': CfgNode({'type': 'MSELoss'}), 'train': CfgNode({'optimizer': CfgNode({'lr': 0.05}), 'local_update_steps': 1})})})
