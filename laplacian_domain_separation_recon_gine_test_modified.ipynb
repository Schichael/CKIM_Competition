# %%
from federatedscope.register import register_data
from federatedscope.register import register_trainer
from federatedscope.register import register_metric
from federatedscope.register import register_model

# %%
from federatedscope.contrib.data.cikm_cup import call_cikm_cup_data

register_data("cikm_cup", call_cikm_cup_data)

# %% [markdown]
# ### Register model

# %%
#from federatedscope.contrib.model.mnist_model import call_my_net
#register_model("mynet", call_my_net)

# %% [markdown]
# ### Register trainer

# %%
from federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation import call_laplacian_trainer

register_trainer('laplacian_trainer', call_laplacian_trainer)

# %% [markdown]
# ### Register metric

# %% [markdown]
# ### Create the config

# %% [markdown]
# #### Set data, model, trainer and metric

# %%
from federatedscope.core.configs.config import global_cfg, CN
cfg = global_cfg.clone()

cfg.merge_from_file("federatedscope/gfl/baseline/laplacian_gine_on_cikmcup_modified"
                    ".yaml")
#cfg.data.type = 'cikm_cup'
#cfg.data.root = 'data'
#cfg.data.shuffle=True
#cfg.data.transform = [['ToTensor'], ['Normalize', {'mean': [0.], 'std': [1]}]]
#cfg.model.type = 'gin'
#cfg.model.out_channels = 10
#cfg.model.hidden = 64
#cfg.model.task='graph'
#cfg.model.dropout = 0.5
#cfg.personalization.local_param = ['encoder_atom', 'encoder', 'clf']#['node_encoder', 'clf']
#cfg.train.batch_or_epoch = "epoch"
cfg.trainer.type = 'laplacian_trainer_with_domain_separation'
cfg.data.batch_size = 64
# cfg.eval.metric = ['mymetric']
cfg.model.out_channels = 2
cfg.params = CN()
cfg.params.alpha=0.1
cfg.params.csd_importance=1e4
cfg.params.eps=1e-10
cfg.params.p=0.
cfg.params.diff_importance = 0.1
cfg.params.recon_importance = 0.1

# %% [markdown]
# #### configure other options

# %%
#cfg.use_gpu = True
#cfg.best_res_update_round_wise_key = "test_loss"

#cfg.federate.mode = 'standalone'
cfg.federate.method = \
    'Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer'
#cfg.federate.local_update_steps = 20000000
#cfg.personalization.local_update_steps = 20000000
#cfg.finetune.local_update_steps = 20000000
#cfg.train.local_update_steps = 1

cfg.federate.total_round_num = 200

cfg.federate.client_num = 13
cfg.early_stop.patience = 10000
#cfg.train.optimizer.lr = 0.001
cfg.train.optimizer.weight_decay = 0.0005
cfg.grad.grad_clip = 2.0
cfg.criterion.type = 'CrossEntropyLoss'
#cfg.seed = 123
cfg.eval.freq = 1
cfg.eval.metrics = ['imp_ratio']
cfg.eval.report = ['avg']
cfg.eval.best_res_update_round_wise_key = 'val_imp_ratio'
cfg.eval.count_flops = False
cfg.data.type = "cikm_cup"

# %%
import torch
#torch.manual_seed(0)
#torch.backends.cudnn.benchmark = False
#torch.use_deterministic_algorithms(F/home/michael/Desktop/backup files/FederatedScope/data/CIKM22Competitionalse)
#import random
#random.seed(0)
#import numpy as np
#np.random.seed(0)

# %%
from yacs.config import CfgNode
client_cfg_file = "federatedscope/gfl/baseline/laplacian_gine_on_cikmcup_per_client.yaml"
client_cfg = CfgNode.load_cfg(open(client_cfg_file,
                                       'r')) if client_cfg_file else None

# %% [markdown]
# ### Start the FL prosess

# %%
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.fed_runner import FedRunner
from federatedscope.core.auxiliaries.worker_builder import get_server_cls, get_client_cls
# Out:
# 2022-10-22 14:10:50,906 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
from federatedscope.contrib.workers.laplacian_with_domain_separation_with_autoenc_client import LaplacianDomainSeparationReconClient
from federatedscope.contrib.workers.laplacian_server import LaplacianServer

setup_seed(cfg.seed)
update_logger(cfg)
data, modified_cfg = get_data(cfg)
cfg.merge_from_other_cfg(modified_cfg)
# Out:
# 2022-10-22 14:10:50,921 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-10-22 14:10:50,922 (utils:131)INFO: the current dir is /home/michael/Projects/CKIM_Competition
# 2022-10-22 14:10:50,923 (utils:132)INFO: the output dir is exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# 2022-10-22 14:10:50,924 (cikm_cup:58)INFO: Loading CIKMCUP data from /home/michael/Projects/CKIM_Competition/data/CIKM22Competition.
# 2022-10-22 14:10:50,925 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #1.
# 2022-10-22 14:10:51,164 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #2.
# 2022-10-22 14:10:51,193 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #3.
# 2022-10-22 14:10:51,570 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #4.
# 2022-10-22 14:10:51,587 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #5.
# 2022-10-22 14:10:51,618 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #6.
# 2022-10-22 14:10:51,961 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #7.
# 2022-10-22 14:10:52,255 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #8.

# %%
Fed_runner = FedRunner(data=data,
                       server_class=LaplacianServer,
                       client_class=LaplacianDomainSeparationReconClient,
                       config=cfg.clone(),
                       client_config=client_cfg)
Fed_runner.run()
# Out:
# server params:
# encoder_atom.atom_embedding_list.0.weight
# 2022-10-22 14:10:55,413 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-10-22 14:10:55,430 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.263789
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-22 14:10:55,531 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:55,532 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-10-22 14:10:55,551 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.289617
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# encoder_atom.atom_embedding_list.1.weight
# encoder_atom.atom_embedding_list.2.weight
# encoder_atom.atom_embedding_list.3.weight
# encoder_atom.atom_embedding_list.4.weight
# encoder_atom.atom_embedding_list.5.weight
# encoder_atom.atom_embedding_list.6.weight
# encoder_atom.atom_embedding_list.7.weight
# encoder_atom.atom_embedding_list.8.weight
# encoder_atom.atom_embedding_list.9.weight
# encoder_atom.atom_embedding_list.10.weight
# encoder_atom.atom_embedding_list.11.weight
# encoder_atom.atom_embedding_list.12.weight
# encoder_atom.atom_embedding_list.13.weight
# encoder_atom.atom_embedding_list.14.weight
# encoder_atom.atom_embedding_list.15.weight
# encoder_atom.atom_embedding_list.16.weight
# encoder_atom.atom_embedding_list.17.weight
# encoder_atom.atom_embedding_list.18.weight
# encoder_atom.atom_embedding_list.19.weight
# encoder_atom.atom_embedding_list.20.weight
# encoder_atom.atom_embedding_list.21.weight
# encoder.weight
# encoder.bias
# local_gnn.convs.0.nn.linears.0.weight
# local_gnn.convs.0.nn.linears.0.bias
# local_gnn.convs.0.nn.linears.1.weight
# local_gnn.convs.0.nn.linears.1.bias
# local_gnn.convs.0.nn.norms.0.weight
# local_gnn.convs.0.nn.norms.0.bias
# local_gnn.convs.0.nn.norms.1.weight
# local_gnn.convs.0.nn.norms.1.bias
# local_gnn.convs.1.nn.linears.0.weight
# local_gnn.convs.1.nn.linears.0.bias
# local_gnn.convs.1.nn.linears.1.weight
# local_gnn.convs.1.nn.linears.1.bias
# local_gnn.convs.1.nn.norms.0.weight
# local_gnn.convs.1.nn.norms.0.bias
# local_gnn.convs.1.nn.norms.1.weight
# local_gnn.convs.1.nn.norms.1.bias
# local_gnn.jk_linear.weight
# local_gnn.jk_linear.bias
# global_gnn.convs.0.nn.linears.0.weight
# global_gnn.convs.0.nn.linears.0.bias
# global_gnn.convs.0.nn.linears.1.weight
# global_gnn.convs.0.nn.linears.1.bias
# global_gnn.convs.0.nn.norms.0.weight
# global_gnn.convs.0.nn.norms.0.bias
# global_gnn.convs.0.nn.norms.1.weight
# global_gnn.convs.0.nn.norms.1.bias
# global_gnn.convs.1.nn.linears.0.weight
# global_gnn.convs.1.nn.linears.0.bias
# global_gnn.convs.1.nn.linears.1.weight
# global_gnn.convs.1.nn.linears.1.bias
# global_gnn.convs.1.nn.norms.0.weight
# global_gnn.convs.1.nn.norms.0.bias
# global_gnn.convs.1.nn.norms.1.weight
# global_gnn.convs.1.nn.norms.1.bias
# global_gnn.jk_linear.weight
# global_gnn.jk_linear.bias
# linear1.0.weight
# linear1.0.bias
# bn_linear.weight
# bn_linear.bias
# clf.weight
# clf.bias
# emb.weight
# 2022-10-22 14:10:55,657 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:55,659 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-10-22 14:10:55,678 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.355404
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-22 14:10:55,795 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:55,797 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-10-22 14:10:55,814 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.176471
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-22 14:10:55,888 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:55,889 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-10-22 14:10:55,908 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.396825
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-22 14:10:55,998 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:55,999 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-10-22 14:10:56,017 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.26158
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0005
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-22 14:10:56,111 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:56,113 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-10-22 14:10:56,130 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.302378
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-22 14:10:56,248 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:56,249 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-10-22 14:10:56,267 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.211538
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 0.1
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'linear1']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-22 14:10:56,357 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-22 14:10:56,358 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-10-22 14:10:56,359 (trainer:325)INFO: Model meta-info: <class 'federatedscope.gfl.model.graph_level.GNN_Net_Graph'>.
# 2022-10-22 14:10:56,362 (trainer:333)INFO: Num of original para names: 98.
# 2022-10-22 14:10:56,363 (trainer:334)INFO: Num of original trainable para names: 67.
# 2022-10-22 14:10:56,364 (trainer:336)INFO: Num of preserved para names in local update: 65.
# Preserved para names in local update: {'local_gnn.jk_linear.bias', 'global_gnn.convs.1.eps', 'global_gnn.convs.1.nn.norms.0.bias', 'local_gnn.convs.0.nn.norms.1.weight', 'local_gnn.convs.1.nn.norms.0.weight', 'local_gnn.convs.1.nn.norms.0.running_mean', 'local_gnn.convs.1.nn.norms.1.weight', 'local_gnn.convs.0.nn.linears.1.weight', 'global_gnn.convs.1.nn.norms.1.running_mean', 'global_gnn.convs.0.nn.norms.1.num_batches_tracked', 'local_gnn.convs.0.nn.norms.0.bias', 'local_gnn.convs.1.eps', 'local_gnn.convs.1.nn.norms.1.num_batches_tracked', 'global_gnn.convs.0.nn.norms.0.running_var', 'local_gnn.convs.1.nn.norms.1.bias', 'global_gnn.convs.1.nn.linears.0.bias', 'local_gnn.convs.0.nn.norms.0.running_mean', 'global_gnn.convs.1.nn.norms.0.weight', 'global_gnn.convs.1.nn.linears.0.weight', 'global_gnn.convs.0.nn.norms.1.weight', 'local_gnn.convs.0.nn.norms.1.running_var', 'local_gnn.convs.1.nn.linears.0.bias', 'local_gnn.convs.1.nn.norms.0.bias', 'global_gnn.convs.0.nn.linears.1.weight', 'global_gnn.convs.0.nn.norms.0.weight', 'global_gnn.convs.0.nn.norms.1.running_mean', 'local_gnn.convs.1.nn.norms.1.running_var', 'global_gnn.jk_linear.weight', 'local_gnn.convs.0.nn.norms.0.weight', 'local_gnn.convs.1.nn.linears.0.weight', 'local_gnn.jk_linear.weight', 'global_gnn.convs.1.nn.norms.0.num_batches_tracked', 'local_gnn.convs.1.nn.norms.0.num_batches_tracked', 'global_gnn.convs.0.nn.linears.1.bias', 'global_gnn.convs.0.nn.linears.0.weight', 'global_gnn.convs.1.nn.linears.1.bias', 'local_gnn.convs.0.nn.linears.0.bias', 'local_gnn.convs.0.eps', 'local_gnn.convs.1.nn.linears.1.bias', 'global_gnn.convs.1.nn.linears.1.weight', 'global_gnn.convs.1.nn.norms.1.weight', 'global_gnn.convs.1.nn.norms.0.running_mean', 'global_gnn.convs.1.nn.norms.1.num_batches_tracked', 'global_gnn.convs.1.nn.norms.1.bias', 'local_gnn.convs.0.nn.linears.0.weight', 'local_gnn.convs.0.nn.norms.1.num_batches_tracked', 'global_gnn.convs.0.nn.norms.0.bias', 'global_gnn.convs.0.nn.norms.0.running_mean', 'emb.weight', 'global_gnn.jk_linear.bias', 'local_gnn.convs.0.nn.norms.1.running_mean', 'global_gnn.convs.0.eps', 'local_gnn.convs.0.nn.norms.0.running_var', 'local_gnn.convs.1.nn.linears.1.weight', 'local_gnn.convs.0.nn.linears.1.bias', 'global_gnn.convs.1.nn.norms.0.running_var', 'local_gnn.convs.0.nn.norms.1.bias', 'global_gnn.convs.0.nn.linears.0.bias', 'global_gnn.convs.0.nn.norms.1.bias', 'local_gnn.convs.1.nn.norms.0.running_var', 'global_gnn.convs.1.nn.norms.1.running_var', 'local_gnn.convs.1.nn.norms.1.running_mean', 'local_gnn.convs.0.nn.norms.0.num_batches_tracked', 'global_gnn.convs.0.nn.norms.0.num_batches_tracked', 'global_gnn.convs.0.nn.norms.1.running_var'}.
# 2022-10-22 14:10:56,366 (trainer:340)INFO: Num of filtered para names in local update: 33.
# Filtered para names in local update: {'encoder_atom.atom_embedding_list.18.weight', 'bn_linear.weight', 'encoder_atom.atom_embedding_list.10.weight', 'clf.bias', 'encoder_atom.atom_embedding_list.17.weight', 'encoder_atom.atom_embedding_list.3.weight', 'encoder_atom.atom_embedding_list.6.weight', 'encoder_atom.atom_embedding_list.19.weight', 'encoder_atom.atom_embedding_list.12.weight', 'encoder_atom.atom_embedding_list.2.weight', 'bn_linear.bias', 'bn_linear.running_mean', 'encoder_atom.atom_embedding_list.4.weight', 'encoder_atom.atom_embedding_list.16.weight', 'linear1.0.weight', 'encoder_atom.atom_embedding_list.13.weight', 'bn_linear.num_batches_tracked', 'encoder_atom.atom_embedding_list.5.weight', 'encoder.weight', 'encoder.bias', 'linear1.0.bias', 'encoder_atom.atom_embedding_list.1.weight', 'encoder_atom.atom_embedding_list.21.weight', 'encoder_atom.atom_embedding_list.7.weight', 'encoder_atom.atom_embedding_list.11.weight', 'encoder_atom.atom_embedding_list.20.weight', 'encoder_atom.atom_embedding_list.0.weight', 'bn_linear.running_var', 'encoder_atom.atom_embedding_list.15.weight', 'encoder_atom.atom_embedding_list.14.weight', 'encoder_atom.atom_embedding_list.8.weight', 'encoder_atom.atom_embedding_list.9.weight', 'clf.weight'}.
# 2022-10-22 14:10:56,367 (trainer:345)INFO: After register default hooks,
# 	the hooks_in_train is:
# 	{
# 	  "on_fit_start": [
# 	    "_hook_on_fit_start_init",
# 	    "_hook_on_fit_start_calculate_model_size"
# 	  ],
# 	  "on_epoch_start": [
# 	    "_hook_on_epoch_start"
# 	  ],
# 	  "on_batch_start": [
# 	    "_hook_on_batch_start_init"
# 	  ],
# 	  "on_batch_forward": [
# 	    "_hook_on_batch_forward",
# 	    "_hook_on_batch_forward_regularizer",
# 	    "_hook_on_batch_forward_flop_count"
# 	  ],
# 	  "on_batch_backward": [
# 	    "_hook_on_batch_backward"
# 	  ],
# 	  "on_batch_end": [
# 	    "_hook_on_batch_end"
# 	  ],
# 	  "on_fit_end": [
# 	    "_hook_on_fit_end"
# 	  ]
# 	};
# 	the hooks_in_eval is:
#             t{
# 	  "on_fit_start": [
# 	    "_hook_on_fit_start_init"
# 	  ],
# 	  "on_epoch_start": [
# 	    "_hook_on_epoch_start"
# 	  ],
# 	  "on_batch_start": [
# 	    "_hook_on_batch_start_init"
# 	  ],
# 	  "on_batch_forward": [
# 	    "_hook_on_batch_forward"
# 	  ],
# 	  "on_batch_end": [
# 	    "_hook_on_batch_end"
# 	  ],
# 	  "on_fit_end": [
# 	    "_hook_on_fit_end"
# 	  ]
# 	}
# 2022-10-22 14:10:56,372 (server:628)INFO: ----------- Starting training (Round #0) -------------
# 2022-10-22 14:12:08,608 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #7', 'Round': 0, 'Results_raw': {'train_total': 22280, 'train_loss': 10965.689196, 'train_imp_ratio': 25.842163, 'train_avg_loss': 0.492176}}
# 2022-10-22 14:13:21,565 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #3', 'Round': 0, 'Results_raw': {'train_total': 22190, 'train_loss': 12767.68426, 'train_imp_ratio': 15.132539, 'train_avg_loss': 0.57538}}
# 2022-10-22 14:13:27,024 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #2', 'Round': 0, 'Results_raw': {'train_total': 1810, 'train_loss': 1222.334881, 'train_imp_ratio': -54.709944, 'train_avg_loss': 0.675323}}
# 2022-10-22 14:13:50,503 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #8', 'Round': 0, 'Results_raw': {'train_total': 7770, 'train_loss': 2848.858093, 'train_imp_ratio': 30.581339, 'train_avg_loss': 0.366648}}
# 2022-10-22 14:13:54,107 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #4', 'Round': 0, 'Results_raw': {'train_total': 1010, 'train_loss': 636.025873, 'train_imp_ratio': -100.296562, 'train_avg_loss': 0.629729}}
# 2022-10-22 14:14:35,089 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #1', 'Round': 0, 'Results_raw': {'train_total': 12490, 'train_loss': 6200.013971, 'train_imp_ratio': 14.469331, 'train_avg_loss': 0.496398}}
# 2022-10-22 14:15:09,941 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #6', 'Round': 0, 'Results_raw': {'train_total': 11010, 'train_loss': 6973.269949, 'train_imp_ratio': -28.229354, 'train_avg_loss': 0.633358}}
# 2022-10-22 14:15:15,389 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #5', 'Round': 0, 'Results_raw': {'train_total': 1880, 'train_loss': 1377.590625, 'train_imp_ratio': -30.289492, 'train_avg_loss': 0.732761}}
# 2022-10-22 14:15:15,527 (laplacian_server:159)INFO: Server #0: Starting evaluation at the end of round 0.
# 2022-10-22 14:15:15,531 (laplacian_server:166)INFO: ----------- Starting a new training round (Round #1) -------------
# 2022-10-22 14:15:42,710 (client:410)INFO: {'Role': 'Client #1', 'Round': 1, 'Results_raw': {'test_total': 417, 'test_loss': 144.541572, 'test_imp_ratio': 60.909096, 'test_avg_loss': 0.346622, 'val_total': 416, 'val_loss': 227.198374, 'val_imp_ratio': -23.933552, 'val_avg_loss': 0.54615}}
# 2022-10-22 14:15:42,711 (monitor:512)INFO: current_best=-23.933552, should_save=True
# 2022-10-22 14:15:42,712 (client:431)INFO: Client: #1, val_imp_ratio: -23.933552. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model1.pth
# 2022-10-22 14:15:46,632 (client:410)INFO: {'Role': 'Client #2', 'Round': 1, 'Results_raw': {'test_total': 61, 'test_loss': 49.048561, 'test_imp_ratio': -149.057022, 'test_avg_loss': 0.804075, 'val_total': 60, 'val_loss': 39.584109, 'val_imp_ratio': -43.868166, 'val_avg_loss': 0.659735}}
# 2022-10-22 14:15:46,633 (monitor:512)INFO: current_best=-43.868166, should_save=True
# 2022-10-22 14:15:46,634 (client:431)INFO: Client: #2, val_imp_ratio: -43.868166. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model2.pth
# 2022-10-22 14:16:35,726 (client:410)INFO: {'Role': 'Client #3', 'Round': 1, 'Results_raw': {'test_total': 740, 'test_loss': 477.633291, 'test_imp_ratio': 8.744886, 'test_avg_loss': 0.64545, 'val_total': 740, 'val_loss': 435.653835, 'val_imp_ratio': 19.771546, 'val_avg_loss': 0.588721}}
# 2022-10-22 14:16:35,727 (monitor:512)INFO: current_best=19.771546, should_save=True
# 2022-10-22 14:16:35,728 (client:431)INFO: Client: #3, val_imp_ratio: 19.771546. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model3.pth
# 2022-10-22 14:16:38,021 (client:410)INFO: {'Role': 'Client #4', 'Round': 1, 'Results_raw': {'test_total': 34, 'test_loss': 23.934446, 'test_imp_ratio': -266.665811, 'test_avg_loss': 0.703954, 'val_total': 34, 'val_loss': 21.420652, 'val_imp_ratio': -33.333022, 'val_avg_loss': 0.630019}}
# 2022-10-22 14:16:38,022 (monitor:512)INFO: current_best=-33.333022, should_save=True
# 2022-10-22 14:16:38,023 (client:431)INFO: Client: #4, val_imp_ratio: -33.333022. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model4.pth
# 2022-10-22 14:16:42,059 (client:410)INFO: {'Role': 'Client #5', 'Round': 1, 'Results_raw': {'test_total': 63, 'test_loss': 44.534862, 'test_imp_ratio': 3.999904, 'test_avg_loss': 0.706903, 'val_total': 63, 'val_loss': 49.906619, 'val_imp_ratio': -56.000156, 'val_avg_loss': 0.792169}}
# 2022-10-22 14:16:42,060 (monitor:512)INFO: current_best=-56.000156, should_save=True
# 2022-10-22 14:16:42,061 (client:431)INFO: Client: #5, val_imp_ratio: -56.000156. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model5.pth
# 2022-10-22 14:17:05,967 (client:410)INFO: {'Role': 'Client #6', 'Round': 1, 'Results_raw': {'test_total': 367, 'test_loss': 314.640056, 'test_imp_ratio': -207.292115, 'test_avg_loss': 0.85733, 'val_total': 367, 'val_loss': 208.354999, 'val_imp_ratio': 24.999891, 'val_avg_loss': 0.567725}}
# 2022-10-22 14:17:05,968 (monitor:512)INFO: current_best=24.999891, should_save=True
# 2022-10-22 14:17:05,969 (client:431)INFO: Client: #6, val_imp_ratio: 24.999891. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model6.pth
# 2022-10-22 14:17:54,595 (client:410)INFO: {'Role': 'Client #7', 'Round': 1, 'Results_raw': {'test_total': 743, 'test_loss': 509.80503, 'test_imp_ratio': -25.519183, 'test_avg_loss': 0.686144, 'val_total': 743, 'val_loss': 391.543473, 'val_imp_ratio': 24.777511, 'val_avg_loss': 0.526976}}
# 2022-10-22 14:17:54,597 (monitor:512)INFO: current_best=24.777511, should_save=True
# ...
# 2022-10-22 14:22:33,628 (server:480)INFO: {'Role': 'Server #', 'Round': 1, 'Results_avg': {'test_total': 335.625, 'test_loss': 268.210399, 'test_imp_ratio': -118.451069, 'test_avg_loss': 0.873399, 'val_total': 335.25, 'val_loss': 185.581377, 'val_imp_ratio': -6.205368, 'val_avg_loss': 0.592503}}
# 2022-10-22 14:22:33,628 (monitor:512)INFO: current_best=-10000, should_save=False
# 2022-10-22 14:22:33,629 (monitor:512)INFO: current_best=-6.205368, should_save=True
# 2022-10-22 14:22:33,774 (laplacian_server:159)INFO: Server #0: Starting evaluation at the end of round 1.
# 2022-10-22 14:22:33,777 (laplacian_server:166)INFO: ----------- Starting a new training round (Round #2) -------------
# 2022-10-22 14:23:02,585 (client:410)INFO: {'Role': 'Client #1', 'Round': 2, 'Results_raw': {'test_total': 417, 'test_loss': 207.403131, 'test_imp_ratio': 12.727283, 'test_avg_loss': 0.49737, 'val_total': 416, 'val_loss': 186.404778, 'val_imp_ratio': 1.582179, 'val_avg_loss': 0.448088}}
# 2022-10-22 14:23:02,586 (monitor:512)INFO: current_best=1.582179, should_save=True
# 2022-10-22 14:23:02,587 (client:431)INFO: Client: #1, val_imp_ratio: 1.582179. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model1.pth
# 2022-10-22 14:23:06,847 (client:410)INFO: {'Role': 'Client #2', 'Round': 2, 'Results_raw': {'test_total': 61, 'test_loss': 46.506598, 'test_imp_ratio': -143.396635, 'test_avg_loss': 0.762403, 'val_total': 60, 'val_loss': 39.613613, 'val_imp_ratio': -43.868166, 'val_avg_loss': 0.660227}}
# 2022-10-22 14:23:06,848 (monitor:512)INFO: current_best=-43.868166, should_save=True
# 2022-10-22 14:23:06,849 (client:431)INFO: Client: #2, val_imp_ratio: -43.868166. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model2.pth
# 2022-10-22 14:23:56,736 (client:410)INFO: {'Role': 'Client #3', 'Round': 2, 'Results_raw': {'test_total': 740, 'test_loss': 488.481193, 'test_imp_ratio': 5.703049, 'test_avg_loss': 0.66011, 'val_total': 740, 'val_loss': 433.964607, 'val_imp_ratio': 26.23545, 'val_avg_loss': 0.586439}}
# 2022-10-22 14:23:56,737 (monitor:512)INFO: current_best=26.23545, should_save=True
# 2022-10-22 14:23:56,738 (client:431)INFO: Client: #3, val_imp_ratio: 26.23545. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model3.pth
# 2022-10-22 14:23:59,159 (client:410)INFO: {'Role': 'Client #4', 'Round': 2, 'Results_raw': {'test_total': 34, 'test_loss': 19.014101, 'test_imp_ratio': 33.333489, 'test_avg_loss': 0.559238, 'val_total': 34, 'val_loss': 23.262384, 'val_imp_ratio': -166.666044, 'val_avg_loss': 0.684188}}
# 2022-10-22 14:23:59,160 (monitor:512)INFO: current_best=-33.333022, should_save=False
# 2022-10-22 14:24:03,247 (client:410)INFO: {'Role': 'Client #5', 'Round': 2, 'Results_raw': {'test_total': 63, 'test_loss': 45.904164, 'test_imp_ratio': 3.999904, 'test_avg_loss': 0.728638, 'val_total': 63, 'val_loss': 51.54266, 'val_imp_ratio': -56.000156, 'val_avg_loss': 0.818137}}
# 2022-10-22 14:24:03,248 (monitor:512)INFO: current_best=-56.000156, should_save=True
# 2022-10-22 14:24:03,248 (client:431)INFO: Client: #5, val_imp_ratio: -56.000156. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model5.pth
# 2022-10-22 14:24:27,313 (client:410)INFO: {'Role': 'Client #6', 'Round': 2, 'Results_raw': {'test_total': 367, 'test_loss': 311.781293, 'test_imp_ratio': -203.125442, 'test_avg_loss': 0.84954, 'val_total': 367, 'val_loss': 210.944213, 'val_imp_ratio': 22.916554, 'val_avg_loss': 0.57478}}
# 2022-10-22 14:24:27,315 (monitor:512)INFO: current_best=24.999891, should_save=False
# 2022-10-22 14:25:16,767 (client:410)INFO: {'Role': 'Client #7', 'Round': 2, 'Results_raw': {'test_total': 743, 'test_loss': 556.917447, 'test_imp_ratio': -33.531046, 'test_avg_loss': 0.749552, 'val_total': 743, 'val_loss': 372.546023, 'val_imp_ratio': 25.222614, 'val_avg_loss': 0.501408}}
# 2022-10-22 14:25:16,768 (monitor:512)INFO: current_best=25.222614, should_save=True
# 2022-10-22 14:25:16,769 (client:431)INFO: Client: #7, val_imp_ratio: 25.222614. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model7.pth
# 2022-10-22 14:25:33,723 (client:410)INFO: {'Role': 'Client #8', 'Round': 2, 'Results_raw': {'test_total': 260, 'test_loss': 688.877083, 'test_imp_ratio': -372.728304, 'test_avg_loss': 2.649527, 'val_total': 259, 'val_loss': 110.759917, 'val_imp_ratio': 37.943003, 'val_avg_loss': 0.427644}}
# 2022-10-22 14:25:33,724 (monitor:512)INFO: current_best=37.943003, should_save=True
# 2022-10-22 14:25:33,725 (client:431)INFO: Client: #8, val_imp_ratio: 37.943003. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model8.pth
# 2022-10-22 14:26:10,110 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #6', 'Round': 2, 'Results_raw': {'train_total': 11010, 'train_loss': 6318.420396, 'train_imp_ratio': 17.083212, 'train_avg_loss': 0.57388}}
# 2022-10-22 14:27:24,466 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #3', 'Round': 2, 'Results_raw': {'train_total': 22190, 'train_loss': 12864.884948, 'train_imp_ratio': 22.626438, 'train_avg_loss': 0.57976}}
# 2022-10-22 14:27:27,826 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #4', 'Round': 2, 'Results_raw': {'train_total': 1010, 'train_loss': 587.272707, 'train_imp_ratio': -34.653151, 'train_avg_loss': 0.581458}}
# 2022-10-22 14:27:33,525 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #5', 'Round': 2, 'Results_raw': {'train_total': 1880, 'train_loss': 1365.799402, 'train_imp_ratio': -35.651199, 'train_avg_loss': 0.726489}}
# 2022-10-22 14:27:56,966 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #8', 'Round': 2, 'Results_raw': {'train_total': 7770, 'train_loss': 2268.015596, 'train_imp_ratio': 44.939625, 'train_avg_loss': 0.291894}}
# 2022-10-22 14:28:38,251 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #1', 'Round': 2, 'Results_raw': {'train_total': 12490, 'train_loss': 4583.104995, 'train_imp_ratio': 43.090843, 'train_avg_loss': 0.366942}}
# 2022-10-22 14:29:50,166 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #7', 'Round': 2, 'Results_raw': {'train_total': 22280, 'train_loss': 9007.484827, 'train_imp_ratio': 44.040223, 'train_avg_loss': 0.404286}}
# 2022-10-22 14:29:55,625 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #2', 'Round': 2, 'Results_raw': {'train_total': 1810, 'train_loss': 1220.468388, 'train_imp_ratio': -50.703891, 'train_avg_loss': 0.674292}}
# 2022-10-22 14:29:55,628 (server:480)INFO: {'Role': 'Server #', 'Round': 2, 'Results_avg': {'test_total': 335.625, 'test_loss': 295.610626, 'test_imp_ratio': -87.127213, 'test_avg_loss': 0.932047, 'val_total': 335.25, 'val_loss': 178.629774, 'val_imp_ratio': -19.079321, 'val_avg_loss': 0.587614}}
# 2022-10-22 14:29:55,629 (monitor:512)INFO: current_best=-6.205368, should_save=False
# 2022-10-22 14:29:55,631 (monitor:512)INFO: current_best=-6.205368, should_save=False
# 2022-10-22 14:29:55,768 (laplacian_server:159)INFO: Server #0: Starting evaluation at the end of round 2.
# 2022-10-22 14:29:55,772 (laplacian_server:166)INFO: ----------- Starting a new training round (Round #3) -------------
# 2022-10-22 14:30:23,427 (client:410)INFO: {'Role': 'Client #1', 'Round': 3, 'Results_raw': {'test_total': 417, 'test_loss': 292.510673, 'test_imp_ratio': -20.909077, 'test_avg_loss': 0.701464, 'val_total': 416, 'val_loss': 138.705128, 'val_imp_ratio': 40.767052, 'val_avg_loss': 0.333426}}
# 2022-10-22 14:30:23,428 (monitor:512)INFO: current_best=40.767052, should_save=True
# 2022-10-22 14:30:23,429 (client:431)INFO: Client: #1, val_imp_ratio: 40.767052. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model1.pth
# 2022-10-22 14:30:27,459 (client:410)INFO: {'Role': 'Client #2', 'Round': 3, 'Results_raw': {'test_total': 61, 'test_loss': 46.011424, 'test_imp_ratio': -132.075861, 'test_avg_loss': 0.754286, 'val_total': 60, 'val_loss': 40.121713, 'val_imp_ratio': -43.868166, 'val_avg_loss': 0.668695}}
# 2022-10-22 14:30:27,461 (monitor:512)INFO: current_best=-43.868166, should_save=True
# 2022-10-22 14:30:27,461 (client:431)INFO: Client: #2, val_imp_ratio: -43.868166. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model2.pth
# 2022-10-22 14:31:16,452 (client:410)INFO: {'Role': 'Client #3', 'Round': 3, 'Results_raw': {'test_total': 740, 'test_loss': 496.343776, 'test_imp_ratio': -0.760855, 'test_avg_loss': 0.670735, 'val_total': 740, 'val_loss': 434.917008, 'val_imp_ratio': 28.897057, 'val_avg_loss': 0.587726}}
# 2022-10-22 14:31:16,453 (monitor:512)INFO: current_best=28.897057, should_save=True
# 2022-10-22 14:31:16,453 (client:431)INFO: Client: #3, val_imp_ratio: 28.897057. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model3.pth
# 2022-10-22 14:31:18,851 (client:410)INFO: {'Role': 'Client #4', 'Round': 3, 'Results_raw': {'test_total': 34, 'test_loss': 19.877893, 'test_imp_ratio': -33.333022, 'test_avg_loss': 0.584644, 'val_total': 34, 'val_loss': 23.188352, 'val_imp_ratio': -199.9993, 'val_avg_loss': 0.68201}}
# 2022-10-22 14:31:18,851 (monitor:512)INFO: current_best=-33.333022, should_save=False
# 2022-10-22 14:31:23,045 (client:410)INFO: {'Role': 'Client #5', 'Round': 3, 'Results_raw': {'test_total': 63, 'test_loss': 45.155732, 'test_imp_ratio': 7.999908, 'test_avg_loss': 0.716758, 'val_total': 63, 'val_loss': 51.78005, 'val_imp_ratio': -52.000152, 'val_avg_loss': 0.821906}}
# 2022-10-22 14:31:23,047 (monitor:512)INFO: current_best=-52.000152, should_save=True
# 2022-10-22 14:31:23,048 (client:431)INFO: Client: #5, val_imp_ratio: -52.000152. model saved at exp/Laplacian_domain_sep_gine_class_clients_diff_0_1_recon_0_1_csd_1e4_shared_jk_layer_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221022141050/model5.pth
# 2022-10-22 14:31:49,919 (client:410)INFO: {'Role': 'Client #6', 'Round': 3, 'Results_raw': {'test_total': 367, 'test_loss': 318.658413, 'test_imp_ratio': -208.333783, 'test_avg_loss': 0.868279, 'val_total': 367, 'val_loss': 211.364736, 'val_imp_ratio': 19.79155, 'val_avg_loss': 0.575926}}
# 2022-10-22 14:31:49,920 (monitor:512)INFO: current_best=24.999891, should_save=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 6
#       1 Fed_runner = FedRunner(data=data,
#       2                        server_class=LaplacianServer,
#       3                        client_class=LaplacianDomainSeparationReconClient,
#       4                        config=cfg.clone(),
#       5                        client_config=client_cfg)
# ----> 6 Fed_runner.run()
#
# File ~/Projects/CKIM_Competition/federatedscope/core/fed_runner.py:186, in FedRunner.run(self)
#     184     while len(self.shared_comm_queue) > 0:
#     185         msg = self.shared_comm_queue.popleft()
# --> 186         self._handle_msg(msg)
#     188 self.server._monitor.finish_fed_runner(fl_mode=self.mode)
#     190 return self.server.best_results
#
# File ~/Projects/CKIM_Competition/federatedscope/core/fed_runner.py:325, in FedRunner._handle_msg(self, msg, rcv)
#     323     self.server._monitor.track_download_bytes(download_bytes)
#     324 else:
# --> 325     self.client[each_receiver].msg_handlers[msg.msg_type](msg)
#     326     self.client[each_receiver]._monitor.track_download_bytes(
#     327         download_bytes)
#
# File ~/Projects/CKIM_Competition/federatedscope/contrib/workers/client.py:389, in Client.callback_funcs_for_evaluate(self, message)
#     387 metrics = {}
#     388 if self._cfg.finetune.before_eval:
# --> 389     self.trainer.finetune()
#     390 for split in self._cfg.eval.split:
#     391     eval_metrics = self.trainer.evaluate(
#     392         target_data_split_name=split)
#
# File ~/Projects/CKIM_Competition/federatedscope/core/trainers/trainer.py:239, in Trainer.finetune(self, target_data_split_name, hooks_set)
#     235 hooks_set = hooks_set or self.hooks_in_ft
#     237 self.ctx.check_data_split(target_data_split_name)
# --> 239 self._run_routine(MODE.FINETUNE, hooks_set, target_data_split_name)
#
# File ~/Projects/CKIM_Competition/federatedscope/core/trainers/trainer.py:277, in Trainer._run_routine(self, mode, hooks_set, dataset_name)
#     275     hook(self.ctx)
#     276 for hook in hooks_set["on_batch_forward"]:
# --> 277     hook(self.ctx)
#     278 if self.ctx.cur_mode == 'train':
#     279     for hook in hooks_set["on_batch_backward"]:
#
# File ~/Projects/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_with_autoenc_separation.py:102, in LaplacianDomainSeparationReconTrainer._hook_on_batch_forward(self, ctx)
#     101 def _hook_on_batch_forward(self, ctx):
# --> 102     batch = ctx.data_batch.to(ctx.device)
#     103     pred, out_enc_shared, out_enc_private, recon_loss = ctx.model(batch)
#     104     diffloss = DiffLoss()
#
# File ~/anaconda3/envs/FederatedScope/lib/python3.9/site-packages/torch_geometric/data/data.py:216, in BaseData.to(self, device, non_blocking, *args)
#     212 def to(self, device: Union[int, str], *args: List[str],
#     213        non_blocking: bool = False):
#     214     r"""Performs tensor device conversion, either for all attributes or
#     215     only the ones given in :obj:`*args`."""
# --> 216     return self.apply(
#     217         lambda x: x.to(device=device, non_blocking=non_blocking), *args)
#
# File ~/anaconda3/envs/FederatedScope/lib/python3.9/site-packages/torch_geometric/data/data.py:199, in BaseData.apply(self, func, *args)
#     196 r"""Applies the function :obj:`func`, either to all attributes or only
#     197 the ones given in :obj:`*args`."""
#     198 for store in self.stores:
# --> 199     store.apply(func, *args)
#     200 return self
#
# File ~/anaconda3/envs/FederatedScope/lib/python3.9/site-packages/torch_geometric/data/storage.py:148, in BaseStorage.apply(self, func, *args)
#     145 r"""Applies the function :obj:`func`, either to all attributes or only
#     146 the ones given in :obj:`*args`."""
#     147 for key, value in self.items(*args):
# --> 148     self[key] = recursive_apply(value, func)
#     149 return self
#
# File ~/anaconda3/envs/FederatedScope/lib/python3.9/site-packages/torch_geometric/data/storage.py:498, in recursive_apply(data, func)
#     496 def recursive_apply(data: Any, func: Callable) -> Any:
#     497     if isinstance(data, Tensor):
# --> 498         return func(data)
#     499     elif isinstance(data, torch.nn.utils.rnn.PackedSequence):
#     500         return func(data)
#
# File ~/anaconda3/envs/FederatedScope/lib/python3.9/site-packages/torch_geometric/data/data.py:217, in BaseData.to.<locals>.<lambda>(x)
#     212 def to(self, device: Union[int, str], *args: List[str],
#     213        non_blocking: bool = False):
#     214     r"""Performs tensor device conversion, either for all attributes or
#     215     only the ones given in :obj:`*args`."""
#     216     return self.apply(
# --> 217         lambda x: x.to(device=device, non_blocking=non_blocking), *args)
#
# KeyboardInterrupt:

# %% [markdown]
# Difference train_avg_loss: 125 -> 174
# 1: 0.539109 -> 0.540
# 2: 0.614181 -> 0.60414
# 3: 0.680621 -> 0.675371
# 4: 0.466614 -> 0.405735
# 5: 0.64907 -> 0.648837
# 6: 0.479263 -> 0.470293
# 7: 0.668663 -> 0.662036
# 8: 0.438008 -> 0.433998
# 9: 0.107733 -> 0.118945
# 10: 0.009074 -> 0.009043
# 11: 1.128238 -> 1.126667
# 12: 2.657362 -> 2.661828
# 13: -> 0.007134

# %%
data

# %%
import os

# %% [markdown]
# After 10 rounds:
#
# diff: 0, csd: 0:
# server: -8
# c1 t/val: 0.375 /0.37
# c2 t/val: 0.678 /0.606
# c3 t/val: 0.699 /0.608
# c4 t/val: 0.599 /0.537
#
# diff: 0, csd: 0:
# server: -4.5
# c1 t/val: 0.372879 /0.328
# c2 t/val: 0.678992 /0.605809
# c3 t/val: 0.70166 /0.608609
# c4 t/val: 0.597455 /0.534253
#
#
#
# diff: 10, csd: 0:
# server: -35
# c1 t/val: 0.482/0.52
# c2 t/val: 0.694/0.65
# c3 t/val: 0.724/0.65
# c4 t/val: 0.674/0.575
#
# diff: 1, csd: 0:
# server: -9.6
# c1 t/val: 0.378194/0.319349
# c2 t/val: 0.67461/0.609163
# c3 t/val: 0.705559/0.615019
# c4 t/val: 0.605581/0.572086
#
# diff: 0, csd: 1e4:
# server: -18
# c1 t/val: 0.280962/0.23074
# c2 t/val: 0.682652/0.603175
# c3 t/val: 0.699094/0.67027
# c4 t/val: 0.594985/0.609611
#
# diff: 0 csd: 1e8
# server: -18
# c1 t/val: 0.2606/0.348(0.197)
# c2 t/val: 0.653/0.0.602
# c3 t/val: 0.691/0.597
# c4 t/val: 0.581/0.629
#
# diff: 0 csd: 1e8
# server: -12.7
# c1 t/val: 0.262647/0.249875
# c2 t/val: 0.649273/0.0.600435
# c3 t/val: 0.696132/0.615158
# c4 t/val: 0.586597/0.656992
#
#
# diff: 0.1 csd: 0
# server: -11
# c1 t/val: 0.2606/0.332837
# c2 t/val: 0.678326/0.0.610099
# c3 t/val: 0.704083/0.616179
# c4 t/val: 0.604177/0.559658

# %%
os.environ['CUBLAS_WORKSPACE_CONFIG']
