# %%
import torch
# The train split of client 1
#cl_num = 2
for cl_num in range(0,13):
    train_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/train.pt')
    val_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/val.pt')
    test_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/test.pt')
    print(f"{cl_num +1}:  {len(train_data_client) + len(val_data_client) + len(test_data_client)}")
# Out:
# 1:  188
# 2:  405
# 3:  467
# 4:  756
# 5:  344
# 6:  2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 5
#       2 # The train split of client 1
#       3 #cl_num = 2
#       4 for cl_num in range(0,13):
# ----> 5     train_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/train.pt')
#       6     val_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/val.pt')
#       7     test_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/test.pt')
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:712, in load(f, map_location, pickle_module, **pickle_load_args)
#     710             opened_file.seek(orig_position)
#     711             return torch.jit.load(opened_file)
# --> 712         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     713 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:1049, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1047 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1048 unpickler.persistent_load = persistent_load
# -> 1049 result = unpickler.load()
#    1051 torch._utils._validate_loaded_sparse_tensors()
#    1053 return result
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/_utils.py:143, in _rebuild_tensor_v2(storage, storage_offset, size, stride, requires_grad, backward_hooks)
#     139 tensor.requires_grad = requires_grad
#     140 # NB: This line exists only for backwards compatibility; the
#     141 # general expectation is that backward_hooks is an empty
#     142 # OrderedDict.  See Note [Don't serialize hooks]
# --> 143 tensor._backward_hooks = backward_hooks
#     144 return tensor
#
# KeyboardInterrupt:

# %% [markdown]
# 1 -> 1
# 2 -> 5
# 3 -> 6
# 4 -> 7
# 5 -> 3
# 6 -> 10
# 7 -> 11
# 8 -> 13
# 9 -> 12
# 10 -> 2
# 11 -> 4
# 12 -> 8
# 13 -> 9

# %%
import os
import sys

from federatedscope.core.cmd_args import parse_args
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.auxiliaries.worker_builder import get_client_cls, get_server_cls
from federatedscope.core.configs.config import global_cfg
from federatedscope.core.fed_runner import FedRunner
from yacs.config import CfgNode
from rdkit.Chem.Draw import IPythonConsole

if os.environ.get('https_proxy'):
    del os.environ['https_proxy']
if os.environ.get('http_proxy'):
    del os.environ['http_proxy']
# Out:
# 2022-12-18 20:01:18,738 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
cfg_file = 'scripts/B-FHTL_exp_scripts/Graph-DC/fedavg.yaml'
cfg_client = 'scripts/B-FHTL_exp_scripts/Graph-DC/cfg_per_client.yaml'

init_cfg = global_cfg.clone()
init_cfg.merge_from_file(cfg_file)
# init_cfg.merge_from_list(args.opts)

update_logger(init_cfg)
setup_seed(init_cfg.seed)

# federated dataset might change the number of clients
# thus, we allow the creation procedure of dataset to modify the global cfg object
data, modified_cfg = get_data(config=init_cfg.clone())
init_cfg.merge_from_other_cfg(modified_cfg)

init_cfg.freeze()

# allow different settings for different clients
# cfg_client.merge_from_file(args.cfg_client)
if cfg_client is None:
    cfg_client = None
else:
    cfg_client = CfgNode.load_cfg(open(cfg_client, 'r')).clone()
# Out:
# 2022-12-18 20:01:18,756 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-12-18 20:01:18,757 (utils:131)INFO: the current dir is /home/michael/Projects/CKIM_Competition
# 2022-12-18 20:01:18,758 (utils:132)INFO: the output dir is exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# 2022-12-18 20:01:31,999 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False

# %%
runner = FedRunner(data=data,
                   server_class=get_server_cls(init_cfg),
                   client_class=get_client_cls(init_cfg),
                   config=init_cfg.clone(),
                   client_config=cfg_client)
_ = runner.run()
# Out:
# 2022-12-18 20:01:32,122 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-12-18 20:01:32,141 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.86
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,155 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-12-18 20:01:32,172 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.823
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,197 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-12-18 20:01:32,213 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.83
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,230 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-12-18 20:01:32,253 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.667
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,275 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-12-18 20:01:32,293 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.541
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,308 (fed_runner:302)INFO: Client 5 has been set up ...
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-18 20:01:32,437 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.853
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,458 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-12-18 20:01:32,476 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.531
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,500 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-12-18 20:01:32,521 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.663
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,537 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-12-18 20:01:32,556 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.567
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,575 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-12-18 20:01:32,592 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.657
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,608 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-12-18 20:01:32,632 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.709
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,645 (fed_runner:302)INFO: Client 11 has been set up ...
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-18 20:01:32,662 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.985
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-18 20:01:32,674 (fed_runner:302)INFO: Client 12 has been set up ...
# 2022-12-18 20:01:32,695 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.703
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
# ...
# 2022-12-18 20:05:59,318 (monitor:513)INFO: current_best=-8.961593, should_save=False
# 2022-12-18 20:05:59,480 (client:260)INFO: {'Role': 'Client #4', 'Round': 58, 'Results_raw': {'train_imp_ratio': -7.993023, 'train_loss': 599.408748, 'train_avg_loss': 0.661599, 'train_total': 906, 'train_acc': 0.613687}}
# 2022-12-18 20:05:59,685 (client:260)INFO: {'Role': 'Client #13', 'Round': 58, 'Results_raw': {'train_imp_ratio': -3.034614, 'train_loss': 712.043574, 'train_avg_loss': 0.59337, 'train_total': 1200, 'train_acc': 0.681667}}
# 2022-12-18 20:06:00,380 (client:260)INFO: {'Role': 'Client #7', 'Round': 58, 'Results_raw': {'train_imp_ratio': 28.260348, 'train_loss': 2915.231358, 'train_avg_loss': 0.591085, 'train_total': 4932, 'train_acc': 0.681062}}
# 2022-12-18 20:06:00,468 (client:260)INFO: {'Role': 'Client #3', 'Round': 58, 'Results_raw': {'train_imp_ratio': -3.614458, 'train_loss': 258.55259, 'train_avg_loss': 0.461701, 'train_total': 560, 'train_acc': 0.8}}
# 2022-12-18 20:06:00,531 (client:260)INFO: {'Role': 'Client #11', 'Round': 58, 'Results_raw': {'train_imp_ratio': -1.605212, 'train_loss': 245.662304, 'train_avg_loss': 0.58491, 'train_total': 420, 'train_acc': 0.697619}}
# 2022-12-18 20:06:00,602 (client:260)INFO: {'Role': 'Client #10', 'Round': 58, 'Results_raw': {'train_imp_ratio': 1.09271, 'train_loss': 252.79028, 'train_avg_loss': 0.628832, 'train_total': 402, 'train_acc': 0.664179}}
# 2022-12-18 20:06:00,789 (client:260)INFO: {'Role': 'Client #12', 'Round': 58, 'Results_raw': {'train_imp_ratio': -1.692047, 'train_loss': 121.894986, 'train_avg_loss': 0.101579, 'train_total': 1200, 'train_acc': 0.968333}}
# 2022-12-18 20:06:01,395 (client:260)INFO: {'Role': 'Client #9', 'Round': 58, 'Results_raw': {'train_imp_ratio': 19.809786, 'train_loss': 2987.362896, 'train_avg_loss': 0.603264, 'train_total': 4952, 'train_acc': 0.679321}}
# 2022-12-18 20:06:01,468 (client:260)INFO: {'Role': 'Client #2', 'Round': 58, 'Results_raw': {'train_imp_ratio': -0.744541, 'train_loss': 217.085472, 'train_avg_loss': 0.446678, 'train_total': 486, 'train_acc': 0.816872}}
# 2022-12-18 20:06:01,553 (client:260)INFO: {'Role': 'Client #5', 'Round': 58, 'Results_raw': {'train_imp_ratio': 12.610592, 'train_loss': 267.211988, 'train_avg_loss': 0.648573, 'train_total': 412, 'train_acc': 0.609223}}
# 2022-12-18 20:06:01,609 (client:260)INFO: {'Role': 'Client #1', 'Round': 58, 'Results_raw': {'train_imp_ratio': -9.67608, 'train_loss': 95.45941, 'train_avg_loss': 0.426158, 'train_total': 224, 'train_acc': 0.776786}}
# 2022-12-18 20:06:01,959 (client:260)INFO: {'Role': 'Client #6', 'Round': 58, 'Results_raw': {'train_imp_ratio': 4.826104, 'train_loss': 608.228404, 'train_avg_loss': 0.253429, 'train_total': 2400, 'train_acc': 0.894167}}
# 2022-12-18 20:06:02,615 (client:260)INFO: {'Role': 'Client #8', 'Round': 58, 'Results_raw': {'train_imp_ratio': 12.07877, 'train_loss': 2774.000515, 'train_avg_loss': 0.533052, 'train_total': 5204, 'train_acc': 0.743082}}
# 2022-12-18 20:06:02,620 (server:496)INFO: {'Role': 'Server #', 'Round': 58, 'Results_avg': {'test_imp_ratio': -18.229865, 'test_loss': 541.966176, 'test_avg_loss': 3.385709, 'test_total': 299.153846, 'test_acc': 0.590756, 'val_imp_ratio': -18.166253, 'val_loss': 529.268484, 'val_avg_loss': 3.822438, 'val_total': 298.692308, 'val_acc': 0.589903}}
# 2022-12-18 20:06:02,621 (monitor:513)INFO: current_best=-7.00481, should_save=False
# 2022-12-18 20:06:02,623 (monitor:513)INFO: current_best=-7.00481, should_save=False
# 2022-12-18 20:06:02,640 (server:323)INFO: Server #0: Starting evaluation at the end of round 58.
# 2022-12-18 20:06:02,642 (server:330)INFO: ----------- Starting a new training round (Round #59) -------------
# 2022-12-18 20:06:02,666 (monitor:513)INFO: current_best=-2.080783, should_save=False
# 2022-12-18 20:06:02,699 (monitor:513)INFO: current_best=0.505528, should_save=False
# 2022-12-18 20:06:02,739 (monitor:513)INFO: current_best=-5.428164, should_save=False
# 2022-12-18 20:06:02,790 (monitor:513)INFO: current_best=-10.640706, should_save=True
# 2022-12-18 20:06:02,791 (client:435)INFO: Client: #4, val_imp_ratio: -10.640706. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118/model4.pth
# 2022-12-18 20:06:02,836 (monitor:513)INFO: current_best=17.870824, should_save=False
# 2022-12-18 20:06:02,918 (monitor:513)INFO: current_best=-3.868699, should_save=True
# 2022-12-18 20:06:02,920 (client:435)INFO: Client: #6, val_imp_ratio: -3.868699. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118/model6.pth
# 2022-12-18 20:06:03,061 (monitor:513)INFO: current_best=-1.71416, should_save=False
# 2022-12-18 20:06:03,195 (monitor:513)INFO: current_best=7.859664, should_save=False
# 2022-12-18 20:06:03,323 (monitor:513)INFO: current_best=5.820106, should_save=False
# 2022-12-18 20:06:03,351 (monitor:513)INFO: current_best=-2.314909, should_save=False
# 2022-12-18 20:06:03,379 (monitor:513)INFO: current_best=-1.269394, should_save=False
# 2022-12-18 20:06:03,440 (monitor:513)INFO: current_best=-1.522843, should_save=True
# 2022-12-18 20:06:03,441 (client:435)INFO: Client: #12, val_imp_ratio: -1.522843. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118/model12.pth
# 2022-12-18 20:06:03,500 (monitor:513)INFO: current_best=-8.961593, should_save=False
# 2022-12-18 20:06:03,845 (client:260)INFO: {'Role': 'Client #6', 'Round': 59, 'Results_raw': {'train_imp_ratio': 2.921063, 'train_loss': 690.393111, 'train_avg_loss': 0.287664, 'train_total': 2400, 'train_acc': 0.877917}}
# 2022-12-18 20:06:04,590 (client:260)INFO: {'Role': 'Client #8', 'Round': 59, 'Results_raw': {'train_imp_ratio': 12.310637, 'train_loss': 2787.358015, 'train_avg_loss': 0.535618, 'train_total': 5204, 'train_acc': 0.74462}}
# 2022-12-18 20:06:04,747 (client:260)INFO: {'Role': 'Client #4', 'Round': 59, 'Results_raw': {'train_imp_ratio': -7.165622, 'train_loss': 588.53061, 'train_avg_loss': 0.649592, 'train_total': 906, 'train_acc': 0.619205}}
# 2022-12-18 20:06:05,453 (client:260)INFO: {'Role': 'Client #9', 'Round': 59, 'Results_raw': {'train_imp_ratio': 21.305627, 'train_loss': 2962.521266, 'train_avg_loss': 0.598247, 'train_total': 4952, 'train_acc': 0.687803}}
# 2022-12-18 20:06:05,673 (client:260)INFO: {'Role': 'Client #13', 'Round': 59, 'Results_raw': {'train_imp_ratio': 1.70697, 'train_loss': 672.210797, 'train_avg_loss': 0.560176, 'train_total': 1200, 'train_acc': 0.715}}
# 2022-12-18 20:06:05,760 (client:260)INFO: {'Role': 'Client #2', 'Round': 59, 'Results_raw': {'train_imp_ratio': -1.99461, 'train_loss': 230.14372, 'train_avg_loss': 0.473547, 'train_total': 486, 'train_acc': 0.806584}}
# 2022-12-18 20:06:06,421 (client:260)INFO: {'Role': 'Client #7', 'Round': 59, 'Results_raw': {'train_imp_ratio': 30.627762, 'train_loss': 2915.903814, 'train_avg_loss': 0.591221, 'train_total': 4932, 'train_acc': 0.693633}}
# 2022-12-18 20:06:06,504 (client:260)INFO: {'Role': 'Client #11', 'Round': 59, 'Results_raw': {'train_imp_ratio': -0.597757, 'train_loss': 248.420678, 'train_avg_loss': 0.591478, 'train_total': 420, 'train_acc': 0.704762}}
# 2022-12-18 20:06:06,561 (client:260)INFO: {'Role': 'Client #1', 'Round': 59, 'Results_raw': {'train_imp_ratio': -2.927741, 'train_loss': 87.68817, 'train_avg_loss': 0.391465, 'train_total': 224, 'train_acc': 0.834821}}
# 2022-12-18 20:06:06,643 (client:260)INFO: {'Role': 'Client #10', 'Round': 59, 'Results_raw': {'train_imp_ratio': 5.257578, 'train_loss': 239.192278, 'train_avg_loss': 0.595006, 'train_total': 402, 'train_acc': 0.691542}}
# 2022-12-18 20:06:06,719 (client:260)INFO: {'Role': 'Client #5', 'Round': 59, 'Results_raw': {'train_imp_ratio': 10.816001, 'train_loss': 268.06363, 'train_avg_loss': 0.65064, 'train_total': 412, 'train_acc': 0.599515}}
# 2022-12-18 20:06:06,932 (client:260)INFO: {'Role': 'Client #12', 'Round': 59, 'Results_raw': {'train_imp_ratio': -1.77665, 'train_loss': 124.146639, 'train_avg_loss': 0.103456, 'train_total': 1200, 'train_acc': 0.9675}}
# 2022-12-18 20:06:07,023 (client:260)INFO: {'Role': 'Client #3', 'Round': 59, 'Results_raw': {'train_imp_ratio': -1.462995, 'train_loss': 249.347583, 'train_avg_loss': 0.445264, 'train_total': 560, 'train_acc': 0.817857}}
# 2022-12-18 20:06:07,026 (server:496)INFO: {'Role': 'Server #', 'Round': 59, 'Results_avg': {'test_imp_ratio': -21.000812, 'test_loss': 584.766182, 'test_avg_loss': 3.439857, 'test_total': 299.153846, 'test_acc': 0.571426, 'val_imp_ratio': -20.520929, 'val_loss': 574.842583, 'val_avg_loss': 3.903272, 'val_total': 298.692308, 'val_acc': 0.57323}}
# 2022-12-18 20:06:07,027 (monitor:513)INFO: current_best=-7.00481, should_save=False
# 2022-12-18 20:06:07,028 (monitor:513)INFO: current_best=-7.00481, should_save=False
# 2022-12-18 20:06:07,044 (server:323)INFO: Server #0: Starting evaluation at the end of round 59.
# 2022-12-18 20:06:07,047 (server:330)INFO: ----------- Starting a new training round (Round #60) -------------
# 2022-12-18 20:06:07,067 (monitor:513)INFO: current_best=-2.080783, should_save=False
# 2022-12-18 20:06:07,099 (monitor:513)INFO: current_best=0.505528, should_save=False
# 2022-12-18 20:06:07,141 (monitor:513)INFO: current_best=-5.428164, should_save=False
# 2022-12-18 20:06:07,181 (monitor:513)INFO: current_best=-10.640706, should_save=True
# 2022-12-18 20:06:07,183 (client:435)INFO: Client: #4, val_imp_ratio: -10.640706. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118/model4.pth
# 2022-12-18 20:06:07,226 (monitor:513)INFO: current_best=17.870824, should_save=False
# 2022-12-18 20:06:07,312 (monitor:513)INFO: current_best=-3.868699, should_save=True
# 2022-12-18 20:06:07,313 (client:435)INFO: Client: #6, val_imp_ratio: -3.868699. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118/model6.pth
# 2022-12-18 20:06:07,456 (monitor:513)INFO: current_best=-1.71416, should_save=False
# 2022-12-18 20:06:07,585 (monitor:513)INFO: current_best=7.859664, should_save=False
# 2022-12-18 20:06:07,720 (monitor:513)INFO: current_best=5.820106, should_save=False
# 2022-12-18 20:06:07,749 (monitor:513)INFO: current_best=-2.314909, should_save=False
# 2022-12-18 20:06:07,781 (monitor:513)INFO: current_best=-1.269394, should_save=False
# 2022-12-18 20:06:07,840 (monitor:513)INFO: current_best=-1.522843, should_save=True
# 2022-12-18 20:06:07,842 (client:435)INFO: Client: #12, val_imp_ratio: -1.522843. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221218200118/model12.pth
# 2022-12-18 20:06:07,897 (monitor:513)INFO: current_best=-8.961593, should_save=False
# 2022-12-18 20:06:08,136 (client:260)INFO: {'Role': 'Client #13', 'Round': 60, 'Results_raw': {'train_imp_ratio': -0.308203, 'train_loss': 680.994491, 'train_avg_loss': 0.567495, 'train_total': 1200, 'train_acc': 0.700833}}
# 2022-12-18 20:06:08,347 (client:260)INFO: {'Role': 'Client #12', 'Round': 60, 'Results_raw': {'train_imp_ratio': -1.522843, 'train_loss': 115.730402, 'train_avg_loss': 0.096442, 'train_total': 1200, 'train_acc': 0.97}}
# 2022-12-18 20:06:08,421 (client:260)INFO: {'Role': 'Client #11', 'Round': 60, 'Results_raw': {'train_imp_ratio': -4.291759, 'train_loss': 245.570699, 'train_avg_loss': 0.584692, 'train_total': 420, 'train_acc': 0.678571}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 6
#       1 runner = FedRunner(data=data,
#       2                    server_class=get_server_cls(init_cfg),
#       3                    client_class=get_client_cls(init_cfg),
#       4                    config=init_cfg.clone(),
#       5                    client_config=cfg_client)
# ----> 6 _ = runner.run()
#
# File ~/Projects/CKIM_Competition/federatedscope/core/fed_runner.py:186, in FedRunner.run(self)
#     184     while len(self.shared_comm_queue) > 0:
#     185         msg = self.shared_comm_queue.popleft()
# --> 186         self._handle_msg(msg)
#     188 self.server._monitor.finish_fed_runner(fl_mode=self.mode)
#     190 return self.server.best_results
#
# File ~/Projects/CKIM_Competition/federatedscope/core/fed_runner.py:325, in FedRunner._handle_msg(self, msg, rcv)
#     323     self.server._monitor.track_download_bytes(download_bytes)
#     324 else:
# --> 325     self.client[each_receiver].msg_handlers[msg.msg_type](msg)
#     326     self.client[each_receiver]._monitor.track_download_bytes(
#     327         download_bytes)
#
# File ~/Projects/CKIM_Competition/federatedscope/core/worker/client.py:251, in Client.callback_funcs_for_model_para(self, message)
#     246     logger.info(
#     247         f"[Normal FL Mode] Client #{self.ID} has been locally "
#     248         f"early stopped. "
#     249         f"The next FL update may result in negative effect")
#     250     self._monitor.local_converged()
# --> 251 sample_size, model_para_all, results = self.trainer.train()
#     252 if self._cfg.federate.share_local_model and not \
#     253         self._cfg.federate.online_aggr:
#     254     model_para_all = copy.deepcopy(model_para_all)
#
# File ~/Projects/CKIM_Competition/federatedscope/core/auxiliaries/decorators.py:7, in use_diff.<locals>.wrapper(self, *args, **kwargs)
#       3 if self.cfg.federate.use_diff:
#       4     # TODO: any issue for subclasses?
#       5     before_metric = self.evaluate(target_data_split_name='val')
# ----> 7 num_samples_train, model_para, result_metric = func(
#       8     self, *args, **kwargs)
#      10 if self.cfg.federate.use_diff:
#      11     # TODO: any issue for subclasses?
#      12     after_metric = self.evaluate(target_data_split_name='val')
#
# File ~/Projects/CKIM_Competition/federatedscope/core/trainers/trainer.py:219, in Trainer.train(self, target_data_split_name, hooks_set)
#     215 hooks_set = hooks_set or self.hooks_in_train
#     217 self.ctx.check_data_split(target_data_split_name)
# --> 219 self._run_routine(MODE.TRAIN, hooks_set, target_data_split_name)
#     221 return self.ctx.num_samples_train, self.get_model_para(
#     222 ), self.ctx.eval_metrics
#
# File ~/Projects/CKIM_Competition/federatedscope/core/trainers/trainer.py:279, in Trainer._run_routine(self, mode, hooks_set, dataset_name)
#     277 if self.ctx.cur_mode == 'train':
#     278     for hook in hooks_set["on_batch_backward"]:
# --> 279         hook(self.ctx)
#     280 for hook in hooks_set["on_batch_end"]:
#     281     hook(self.ctx)
#
# File ~/Projects/CKIM_Competition/federatedscope/core/trainers/torch_trainer.py:257, in GeneralTorchTrainer._hook_on_batch_backward(self, ctx)
#     255 def _hook_on_batch_backward(self, ctx):
#     256     ctx.optimizer.zero_grad()
# --> 257     ctx.loss_task.backward()
#     258     if ctx.grad_clip > 0:
#     259         torch.nn.utils.clip_grad_norm_(ctx.model.parameters(),
#     260                                        ctx.grad_clip)
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
