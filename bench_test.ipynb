# %%
import torch
# The train split of client 1
#cl_num = 2
for cl_num in range(0,13):
    train_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/train.pt')
    val_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/val.pt')
    test_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/test.pt')
    print(f"{cl_num +1}:  {len(train_data_client) + len(val_data_client) + len(test_data_client)}")
# Out:
# 1:  188
# 2:  405
# 3:  467
# 4:  756
# 5:  344
# 6:  2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 5
#       2 # The train split of client 1
#       3 #cl_num = 2
#       4 for cl_num in range(0,13):
# ----> 5     train_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/train.pt')
#       6     val_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/val.pt')
#       7     test_data_client = torch.load(f'./data/fscontest/processed/{cl_num}/test.pt')
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:712, in load(f, map_location, pickle_module, **pickle_load_args)
#     710             opened_file.seek(orig_position)
#     711             return torch.jit.load(opened_file)
# --> 712         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     713 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/serialization.py:1049, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1047 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1048 unpickler.persistent_load = persistent_load
# -> 1049 result = unpickler.load()
#    1051 torch._utils._validate_loaded_sparse_tensors()
#    1053 return result
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/_utils.py:143, in _rebuild_tensor_v2(storage, storage_offset, size, stride, requires_grad, backward_hooks)
#     139 tensor.requires_grad = requires_grad
#     140 # NB: This line exists only for backwards compatibility; the
#     141 # general expectation is that backward_hooks is an empty
#     142 # OrderedDict.  See Note [Don't serialize hooks]
# --> 143 tensor._backward_hooks = backward_hooks
#     144 return tensor
#
# KeyboardInterrupt:

# %% [markdown]
# 1 -> 1
# 2 -> 5
# 3 -> 6
# 4 -> 7
# 5 -> 3
# 6 -> 10
# 7 -> 11
# 8 -> 13
# 9 -> 12
# 10 -> 2
# 11 -> 4
# 12 -> 8
# 13 -> 9

# %%
import os
import sys

from federatedscope.core.cmd_args import parse_args
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.auxiliaries.worker_builder import get_client_cls, get_server_cls
from federatedscope.core.configs.config import global_cfg
from federatedscope.core.fed_runner import FedRunner
from yacs.config import CfgNode
from rdkit.Chem.Draw import IPythonConsole

if os.environ.get('https_proxy'):
    del os.environ['https_proxy']
if os.environ.get('http_proxy'):
    del os.environ['http_proxy']
# Out:
# 2022-12-20 10:58:05,467 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
cfg_file = 'scripts/B-FHTL_exp_scripts/Graph-DC/fedavg.yaml'
cfg_client = 'scripts/B-FHTL_exp_scripts/Graph-DC/cfg_per_client.yaml'

init_cfg = global_cfg.clone()
init_cfg.merge_from_file(cfg_file)
# init_cfg.merge_from_list(args.opts)

update_logger(init_cfg)
setup_seed(init_cfg.seed)

# federated dataset might change the number of clients
# thus, we allow the creation procedure of dataset to modify the global cfg object
data, modified_cfg = get_data(config=init_cfg.clone())
init_cfg.merge_from_other_cfg(modified_cfg)

init_cfg.freeze()

# allow different settings for different clients
# cfg_client.merge_from_file(args.cfg_client)
if cfg_client is None:
    cfg_client = None
else:
    cfg_client = CfgNode.load_cfg(open(cfg_client, 'r')).clone()
# Out:
# 2022-12-20 10:58:05,490 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-12-20 10:58:05,491 (utils:131)INFO: the current dir is /home/michael/Projects/CKIM_Competition
# 2022-12-20 10:58:05,492 (utils:132)INFO: the output dir is exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# 2022-12-20 10:58:17,906 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False

# %%
runner = FedRunner(data=data,
                   server_class=get_server_cls(init_cfg),
                   client_class=get_client_cls(init_cfg),
                   config=init_cfg.clone(),
                   client_config=cfg_client)
_ = runner.run()
# Out:
# 2022-12-20 10:58:18,053 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-12-20 10:58:18,074 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.86
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,107 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-12-20 10:58:18,122 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.823
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,224 (fed_runner:302)INFO: Client 2 has been set up ...
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-20 10:58:18,240 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.83
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,307 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-12-20 10:58:18,324 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.667
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,418 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-12-20 10:58:18,433 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.541
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,480 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-12-20 10:58:18,495 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.853
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-20 10:58:18,573 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-12-20 10:58:18,589 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.531
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,659 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-12-20 10:58:18,675 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.663
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,716 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-12-20 10:58:18,733 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.567
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-20 10:58:18,807 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-12-20 10:58:18,825 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.657
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,873 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-12-20 10:58:18,889 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.709
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,936 (fed_runner:302)INFO: Client 11 has been set up ...
# 2022-12-20 10:58:18,954 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.985
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 0
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 2
#   lr: 0.5
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 2
#   optimizer:
#     lr: 0.5
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-12-20 10:58:18,988 (fed_runner:302)INFO: Client 12 has been set up ...
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# track_running_stats: True
# 2022-12-20 10:58:19,005 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter: ooxx
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: fs_contest_data
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 80
#   the_smaller_the_better: False
# eval:
#   base: 0.703
#   best_res_update_round_wise_key: val_loss
#   count_flops: True
#   freq: 1
#   metrics: ['imp_ratio', 'acc']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 400
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# maml:
#   use: False
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
# ...
# 2022-12-20 10:58:32,030 (client:436)INFO: Client: #6, val_imp_ratio: -3.868699. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model6.pth
# 2022-12-20 10:58:32,265 (client:415)INFO: {'Role': 'Client #7', 'Round': 2, 'Results_raw': {'test_loss': 624.065309, 'test_total': 822, 'test_acc': 0.50365, 'test_imp_ratio': -5.150728, 'test_avg_loss': 0.759204, 'val_loss': 613.285844, 'val_total': 822, 'val_acc': 0.519465, 'val_imp_ratio': -2.172369, 'val_avg_loss': 0.74609}}
# 2022-12-20 10:58:32,266 (monitor:513)INFO: current_best=-2.172369, should_save=True
# 2022-12-20 10:58:32,267 (client:436)INFO: Client: #7, val_imp_ratio: -2.172369. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model7.pth
# 2022-12-20 10:58:32,476 (client:415)INFO: {'Role': 'Client #8', 'Round': 2, 'Results_raw': {'test_loss': 623.603268, 'test_total': 868, 'test_acc': 0.436636, 'test_imp_ratio': -34.142391, 'test_avg_loss': 0.718437, 'val_loss': 613.072235, 'val_total': 867, 'val_acc': 0.455594, 'val_imp_ratio': -31.282956, 'val_avg_loss': 0.707119}}
# 2022-12-20 10:58:32,477 (monitor:513)INFO: current_best=-8.493253, should_save=False
# 2022-12-20 10:58:32,639 (client:415)INFO: {'Role': 'Client #9', 'Round': 2, 'Results_raw': {'test_loss': 889.630807, 'test_total': 826, 'test_acc': 0.469734, 'test_imp_ratio': -17.154558, 'test_avg_loss': 1.077035, 'val_loss': 824.353505, 'val_total': 825, 'val_acc': 0.515152, 'val_imp_ratio': -9.144354, 'val_avg_loss': 0.999216}}
# 2022-12-20 10:58:32,640 (monitor:513)INFO: current_best=-9.144354, should_save=True
# 2022-12-20 10:58:32,641 (client:436)INFO: Client: #9, val_imp_ratio: -9.144354. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model9.pth
# 2022-12-20 10:58:32,744 (client:415)INFO: {'Role': 'Client #10', 'Round': 2, 'Results_raw': {'test_loss': 46.614749, 'test_total': 68, 'test_acc': 0.588235, 'test_imp_ratio': -10.46647, 'test_avg_loss': 0.685511, 'val_loss': 46.200853, 'val_total': 67, 'val_acc': 0.626866, 'val_imp_ratio': -4.586656, 'val_avg_loss': 0.689565}}
# 2022-12-20 10:58:32,745 (monitor:513)INFO: current_best=-4.586656, should_save=True
# 2022-12-20 10:58:32,746 (client:436)INFO: Client: #10, val_imp_ratio: -4.586656. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model10.pth
# 2022-12-20 10:58:32,807 (client:415)INFO: {'Role': 'Client #11', 'Round': 2, 'Results_raw': {'test_loss': 46.315572, 'test_total': 71, 'test_acc': 0.647887, 'test_imp_ratio': -8.619559, 'test_avg_loss': 0.652332, 'val_loss': 45.482486, 'val_total': 70, 'val_acc': 0.657143, 'val_imp_ratio': -7.314125, 'val_avg_loss': 0.64975}}
# 2022-12-20 10:58:32,808 (monitor:513)INFO: current_best=-7.314125, should_save=True
# 2022-12-20 10:58:32,809 (client:436)INFO: Client: #11, val_imp_ratio: -7.314125. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model11.pth
# 2022-12-20 10:58:32,896 (client:415)INFO: {'Role': 'Client #12', 'Round': 2, 'Results_raw': {'test_loss': 55.435388, 'test_total': 200, 'test_acc': 0.95, 'test_imp_ratio': -3.553299, 'test_avg_loss': 0.277177, 'val_loss': 33.140654, 'val_total': 200, 'val_acc': 0.97, 'val_imp_ratio': -1.522843, 'val_avg_loss': 0.165703}}
# 2022-12-20 10:58:32,897 (monitor:513)INFO: current_best=-1.522843, should_save=True
# 2022-12-20 10:58:32,899 (client:436)INFO: Client: #12, val_imp_ratio: -1.522843. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model12.pth
# 2022-12-20 10:58:32,986 (client:415)INFO: {'Role': 'Client #13', 'Round': 2, 'Results_raw': {'test_loss': 135.742986, 'test_total': 200, 'test_acc': 0.56, 'test_imp_ratio': -20.341394, 'test_avg_loss': 0.678715, 'val_loss': 135.034575, 'val_total': 200, 'val_acc': 0.58, 'val_imp_ratio': -17.496444, 'val_avg_loss': 0.675173}}
# 2022-12-20 10:58:32,987 (monitor:513)INFO: current_best=-17.496444, should_save=True
# 2022-12-20 10:58:32,988 (client:436)INFO: Client: #13, val_imp_ratio: -17.496444. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model13.pth
# 2022-12-20 10:58:33,091 (client:260)INFO: {'Role': 'Client #11', 'Round': 2, 'Results_raw': {'train_loss': 282.783795, 'train_total': 420, 'train_acc': 0.630952, 'train_imp_ratio': -11.008127, 'train_avg_loss': 0.673295}}
# 2022-12-20 10:58:33,206 (client:260)INFO: {'Role': 'Client #2', 'Round': 2, 'Results_raw': {'train_loss': 251.969838, 'train_total': 486, 'train_acc': 0.769547, 'train_imp_ratio': -6.494857, 'train_avg_loss': 0.518456}}
# 2022-12-20 10:58:34,001 (client:260)INFO: {'Role': 'Client #7', 'Round': 2, 'Results_raw': {'train_loss': 3180.961152, 'train_total': 4932, 'train_acc': 0.64335, 'train_imp_ratio': 21.158108, 'train_avg_loss': 0.644964}}
# 2022-12-20 10:58:34,864 (client:260)INFO: {'Role': 'Client #8', 'Round': 2, 'Results_raw': {'train_loss': 3054.10163, 'train_total': 5204, 'train_acc': 0.698693, 'train_imp_ratio': 5.383607, 'train_avg_loss': 0.586876}}
# 2022-12-20 10:58:34,994 (client:260)INFO: {'Role': 'Client #3', 'Round': 2, 'Results_raw': {'train_loss': 279.007445, 'train_total': 560, 'train_acc': 0.796429, 'train_imp_ratio': -4.04475, 'train_avg_loss': 0.498228}}
# 2022-12-20 10:58:35,259 (client:260)INFO: {'Role': 'Client #13', 'Round': 2, 'Results_raw': {'train_loss': 781.101388, 'train_total': 1200, 'train_acc': 0.641667, 'train_imp_ratio': -8.724514, 'train_avg_loss': 0.650918}}
# 2022-12-20 10:58:35,573 (client:260)INFO: {'Role': 'Client #6', 'Round': 2, 'Results_raw': {'train_loss': 652.834004, 'train_total': 2400, 'train_acc': 0.885417, 'train_imp_ratio': 3.800313, 'train_avg_loss': 0.272014}}
# 2022-12-20 10:58:35,802 (client:260)INFO: {'Role': 'Client #12', 'Round': 2, 'Results_raw': {'train_loss': 156.997123, 'train_total': 1200, 'train_acc': 0.968333, 'train_imp_ratio': -1.692047, 'train_avg_loss': 0.130831}}
# 2022-12-20 10:58:35,844 (client:260)INFO: {'Role': 'Client #1', 'Round': 2, 'Results_raw': {'train_loss': 119.699692, 'train_total': 224, 'train_acc': 0.700893, 'train_imp_ratio': -18.500831, 'train_avg_loss': 0.534374}}
# 2022-12-20 10:58:36,046 (client:260)INFO: {'Role': 'Client #4', 'Round': 2, 'Results_raw': {'train_loss': 599.220741, 'train_total': 906, 'train_acc': 0.602649, 'train_imp_ratio': -9.647825, 'train_avg_loss': 0.661392}}
# 2022-12-20 10:58:36,119 (client:260)INFO: {'Role': 'Client #5', 'Round': 2, 'Results_raw': {'train_loss': 293.803884, 'train_total': 412, 'train_acc': 0.589806, 'train_imp_ratio': 9.021409, 'train_avg_loss': 0.713116}}
# 2022-12-20 10:58:36,193 (client:260)INFO: {'Role': 'Client #10', 'Round': 2, 'Results_raw': {'train_loss': 263.595064, 'train_total': 402, 'train_acc': 0.654229, 'train_imp_ratio': -0.421788, 'train_avg_loss': 0.655709}}
# 2022-12-20 10:58:36,992 (client:260)INFO: {'Role': 'Client #9', 'Round': 2, 'Results_raw': {'train_loss': 3203.639434, 'train_total': 4952, 'train_acc': 0.633683, 'train_imp_ratio': 11.760734, 'train_avg_loss': 0.646938}}
# 2022-12-20 10:58:36,995 (server:496)INFO: {'Role': 'Server #', 'Round': 2, 'Results_avg': {'test_loss': 233.730032, 'test_total': 299.153846, 'test_acc': 0.652049, 'test_imp_ratio': -10.016869, 'test_avg_loss': 0.69311, 'val_loss': 223.697226, 'val_total': 298.692308, 'val_acc': 0.660222, 'val_imp_ratio': -8.267199, 'val_avg_loss': 0.690011}}
# 2022-12-20 10:58:36,996 (monitor:513)INFO: current_best=-8.614383, should_save=False
# 2022-12-20 10:58:36,997 (monitor:513)INFO: current_best=-8.267199, should_save=True
# 2022-12-20 10:58:37,020 (server:323)INFO: Server #0: Starting evaluation at the end of round 2.
# 2022-12-20 10:58:37,021 (server:330)INFO: ----------- Starting a new training round (Round #3) -------------
# 2022-12-20 10:58:37,055 (client:415)INFO: {'Role': 'Client #1', 'Round': 3, 'Results_raw': {'test_loss': 31.353451, 'test_total': 38, 'test_acc': 0.736842, 'test_imp_ratio': -14.320685, 'test_avg_loss': 0.825091, 'val_loss': 37.758282, 'val_total': 38, 'val_acc': 0.684211, 'val_imp_ratio': -20.440636, 'val_avg_loss': 0.993639}}
# 2022-12-20 10:58:37,056 (monitor:513)INFO: current_best=-20.440636, should_save=True
# 2022-12-20 10:58:37,057 (client:436)INFO: Client: #1, val_imp_ratio: -20.440636. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model1.pth
# 2022-12-20 10:58:37,127 (client:415)INFO: {'Role': 'Client #2', 'Round': 3, 'Results_raw': {'test_loss': 41.678085, 'test_total': 81, 'test_acc': 0.814815, 'test_imp_ratio': -0.994555, 'test_avg_loss': 0.514544, 'val_loss': 41.022953, 'val_total': 81, 'val_acc': 0.814815, 'val_imp_ratio': -0.994555, 'val_avg_loss': 0.506456}}
# 2022-12-20 10:58:37,128 (monitor:513)INFO: current_best=-0.994555, should_save=True
# 2022-12-20 10:58:37,129 (client:436)INFO: Client: #2, val_imp_ratio: -0.994555. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model2.pth
# 2022-12-20 10:58:37,242 (client:415)INFO: {'Role': 'Client #3', 'Round': 3, 'Results_raw': {'test_loss': 64.028258, 'test_total': 94, 'test_acc': 0.797872, 'test_imp_ratio': -3.870802, 'test_avg_loss': 0.681152, 'val_loss': 85.91297, 'val_total': 93, 'val_acc': 0.72043, 'val_imp_ratio': -13.201192, 'val_avg_loss': 0.923795}}
# 2022-12-20 10:58:37,243 (monitor:513)INFO: current_best=-13.201192, should_save=True
# 2022-12-20 10:58:37,244 (client:436)INFO: Client: #3, val_imp_ratio: -13.201192. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model3.pth
# 2022-12-20 10:58:37,361 (client:415)INFO: {'Role': 'Client #4', 'Round': 3, 'Results_raw': {'test_loss': 143.864642, 'test_total': 152, 'test_acc': 0.644737, 'test_imp_ratio': -3.337805, 'test_avg_loss': 0.946478, 'val_loss': 161.029594, 'val_total': 151, 'val_acc': 0.596026, 'val_imp_ratio': -10.640706, 'val_avg_loss': 1.066421}}
# 2022-12-20 10:58:37,363 (monitor:513)INFO: current_best=-10.640706, should_save=True
# 2022-12-20 10:58:37,364 (client:436)INFO: Client: #4, val_imp_ratio: -10.640706. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model4.pth
# 2022-12-20 10:58:37,465 (client:415)INFO: {'Role': 'Client #5', 'Round': 3, 'Results_raw': {'test_loss': 68.427933, 'test_total': 69, 'test_acc': 0.463768, 'test_imp_ratio': -14.275764, 'test_avg_loss': 0.991709, 'val_loss': 77.665713, 'val_total': 69, 'val_acc': 0.376812, 'val_imp_ratio': -30.349058, 'val_avg_loss': 1.12559}}
# 2022-12-20 10:58:37,466 (monitor:513)INFO: current_best=15.191942, should_save=False
# 2022-12-20 10:58:37,578 (client:415)INFO: {'Role': 'Client #6', 'Round': 3, 'Results_raw': {'test_loss': 387.885865, 'test_total': 400, 'test_acc': 0.79, 'test_imp_ratio': -7.385698, 'test_avg_loss': 0.969715, 'val_loss': 333.1775, 'val_total': 400, 'val_acc': 0.82, 'val_imp_ratio': -3.868699, 'val_avg_loss': 0.832944}}
# 2022-12-20 10:58:37,579 (monitor:513)INFO: current_best=-3.868699, should_save=True
# 2022-12-20 10:58:37,580 (client:436)INFO: Client: #6, val_imp_ratio: -3.868699. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model6.pth
# 2022-12-20 10:58:37,792 (client:415)INFO: {'Role': 'Client #7', 'Round': 3, 'Results_raw': {'test_loss': 634.682941, 'test_total': 822, 'test_acc': 0.50365, 'test_imp_ratio': -5.150728, 'test_avg_loss': 0.77212, 'val_loss': 623.024682, 'val_total': 822, 'val_acc': 0.519465, 'val_imp_ratio': -2.172369, 'val_avg_loss': 0.757938}}
# 2022-12-20 10:58:37,793 (monitor:513)INFO: current_best=-2.172369, should_save=True
# 2022-12-20 10:58:37,794 (client:436)INFO: Client: #7, val_imp_ratio: -2.172369. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model7.pth
# 2022-12-20 10:58:37,998 (client:415)INFO: {'Role': 'Client #8', 'Round': 3, 'Results_raw': {'test_loss': 556.94265, 'test_total': 868, 'test_acc': 0.672811, 'test_imp_ratio': 1.479798, 'test_avg_loss': 0.641639, 'val_loss': 550.368149, 'val_total': 867, 'val_acc': 0.678201, 'val_imp_ratio': 2.292714, 'val_avg_loss': 0.634796}}
# 2022-12-20 10:58:37,999 (monitor:513)INFO: current_best=2.292714, should_save=True
# 2022-12-20 10:58:38,000 (client:436)INFO: Client: #8, val_imp_ratio: 2.292714. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model8.pth
# 2022-12-20 10:58:38,174 (client:415)INFO: {'Role': 'Client #9', 'Round': 3, 'Results_raw': {'test_loss': 1195.32812, 'test_total': 826, 'test_acc': 0.469734, 'test_imp_ratio': -17.154558, 'test_avg_loss': 1.447128, 'val_loss': 1096.36707, 'val_total': 825, 'val_acc': 0.515152, 'val_imp_ratio': -9.144354, 'val_avg_loss': 1.32893}}
# 2022-12-20 10:58:38,175 (monitor:513)INFO: current_best=-9.144354, should_save=True
# 2022-12-20 10:58:38,176 (client:436)INFO: Client: #9, val_imp_ratio: -9.144354. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model9.pth
# 2022-12-20 10:58:38,276 (client:415)INFO: {'Role': 'Client #10', 'Round': 3, 'Results_raw': {'test_loss': 59.614622, 'test_total': 68, 'test_acc': 0.308824, 'test_imp_ratio': -52.994897, 'test_avg_loss': 0.876686, 'val_loss': 54.997746, 'val_total': 67, 'val_acc': 0.402985, 'val_imp_ratio': -38.66285, 'val_avg_loss': 0.820862}}
# 2022-12-20 10:58:38,277 (monitor:513)INFO: current_best=-4.586656, should_save=False
# 2022-12-20 10:58:38,315 (client:415)INFO: {'Role': 'Client #11', 'Round': 3, 'Results_raw': {'test_loss': 53.09353, 'test_total': 71, 'test_acc': 0.352113, 'test_imp_ratio': -50.336717, 'test_avg_loss': 0.747796, 'val_loss': 52.55225, 'val_total': 70, 'val_acc': 0.342857, 'val_imp_ratio': -51.642152, 'val_avg_loss': 0.750746}}
# 2022-12-20 10:58:38,316 (monitor:513)INFO: current_best=-7.314125, should_save=False
# 2022-12-20 10:58:38,391 (client:415)INFO: {'Role': 'Client #12', 'Round': 3, 'Results_raw': {'test_loss': 68.650992, 'test_total': 200, 'test_acc': 0.95, 'test_imp_ratio': -3.553299, 'test_avg_loss': 0.343255, 'val_loss': 40.527369, 'val_total': 200, 'val_acc': 0.97, 'val_imp_ratio': -1.522843, 'val_avg_loss': 0.202637}}
# 2022-12-20 10:58:38,392 (monitor:513)INFO: current_best=-1.522843, should_save=True
# 2022-12-20 10:58:38,393 (client:436)INFO: Client: #12, val_imp_ratio: -1.522843. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model12.pth
# 2022-12-20 10:58:38,486 (client:415)INFO: {'Role': 'Client #13', 'Round': 3, 'Results_raw': {'test_loss': 184.847454, 'test_total': 200, 'test_acc': 0.56, 'test_imp_ratio': -20.341394, 'test_avg_loss': 0.924237, 'val_loss': 178.420416, 'val_total': 200, 'val_acc': 0.58, 'val_imp_ratio': -17.496444, 'val_avg_loss': 0.892102}}
# 2022-12-20 10:58:38,487 (monitor:513)INFO: current_best=-17.496444, should_save=True
# 2022-12-20 10:58:38,488 (client:436)INFO: Client: #13, val_imp_ratio: -17.496444. model saved at exp/FedAvg_gin_on_fs_contest_data_lr0.5_lstep2_/sub_exp_20221220105805/model13.pth
# 2022-12-20 10:58:38,853 (client:260)INFO: {'Role': 'Client #6', 'Round': 3, 'Results_raw': {'train_loss': 626.731774, 'train_total': 2400, 'train_acc': 0.898333, 'train_imp_ratio': 5.314576, 'train_avg_loss': 0.261138}}
# 2022-12-20 10:58:38,937 (client:260)INFO: {'Role': 'Client #5', 'Round': 3, 'Results_raw': {'train_loss': 297.79509, 'train_total': 412, 'train_acc': 0.521845, 'train_imp_ratio': -3.540728, 'train_avg_loss': 0.722804}}
# 2022-12-20 10:58:39,096 (client:260)INFO: {'Role': 'Client #3', 'Round': 3, 'Results_raw': {'train_loss': 276.274201, 'train_total': 560, 'train_acc': 0.796429, 'train_imp_ratio': -4.04475, 'train_avg_loss': 0.493347}}
# 2022-12-20 10:58:39,180 (client:260)INFO: {'Role': 'Client #11', 'Round': 3, 'Results_raw': {'train_loss': 282.219657, 'train_total': 420, 'train_acc': 0.640476, 'train_imp_ratio': -9.664853, 'train_avg_loss': 0.671952}}
# 2022-12-20 10:58:39,940 (client:260)INFO: {'Role': 'Client #9', 'Round': 3, 'Results_raw': {'train_loss': 3184.764207, 'train_total': 4952, 'train_acc': 0.637722, 'train_imp_ratio': 12.473039, 'train_avg_loss': 0.643127}}
#
# KeyboardInterrupt

# %%
import torch
# The train split of client 1
cl_num = 0
train_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/train.pt')
val_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/val.pt')
test_data_client = torch.load(f'./data/graph_dt/processed/{cl_num}/test.pt')
print(len(train_data_client) + len(val_data_client) + len(test_data_client))

# %%
val_data_client
# Out:
# [Data(x=[14, 22], edge_index=[2, 28], edge_attr=[28, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[7, 22], edge_index=[2, 12], edge_attr=[12, 8], y=[1, 1]),
#  Data(x=[5, 22], edge_index=[2, 8], edge_attr=[8, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 22], edge_attr=[22, 8], y=[1, 1]),
#  Data(x=[15, 22], edge_index=[2, 30], edge_attr=[30, 8], y=[1, 1]),
#  Data(x=[5, 22], edge_index=[2, 8], edge_attr=[8, 8], y=[1, 1]),
#  Data(x=[29, 22], edge_index=[2, 64], edge_attr=[64, 8], y=[1, 1]),
#  Data(x=[19, 22], edge_index=[2, 44], edge_attr=[44, 8], y=[1, 1]),
#  Data(x=[18, 22], edge_index=[2, 38], edge_attr=[38, 8], y=[1, 1]),
#  Data(x=[20, 22], edge_index=[2, 48], edge_attr=[48, 8], y=[1, 1]),
#  Data(x=[17, 22], edge_index=[2, 34], edge_attr=[34, 8], y=[1, 1]),
#  Data(x=[22, 22], edge_index=[2, 46], edge_attr=[46, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 22], edge_attr=[22, 8], y=[1, 1]),
#  Data(x=[12, 22], edge_index=[2, 26], edge_attr=[26, 8], y=[1, 1]),
#  Data(x=[14, 22], edge_index=[2, 30], edge_attr=[30, 8], y=[1, 1]),
#  Data(x=[20, 22], edge_index=[2, 42], edge_attr=[42, 8], y=[1, 1]),
#  Data(x=[13, 22], edge_index=[2, 28], edge_attr=[28, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 18], edge_attr=[18, 8], y=[1, 1]),
#  Data(x=[10, 22], edge_index=[2, 20], edge_attr=[20, 8], y=[1, 1]),
#  Data(x=[14, 22], edge_index=[2, 28], edge_attr=[28, 8], y=[1, 1]),
#  Data(x=[10, 22], edge_index=[2, 20], edge_attr=[20, 8], y=[1, 1]),
#  Data(x=[5, 22], edge_index=[2, 8], edge_attr=[8, 8], y=[1, 1]),
#  Data(x=[26, 22], edge_index=[2, 56], edge_attr=[56, 8], y=[1, 1]),
#  Data(x=[13, 22], edge_index=[2, 28], edge_attr=[28, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 18], edge_attr=[18, 8], y=[1, 1]),
#  Data(x=[22, 22], edge_index=[2, 44], edge_attr=[44, 8], y=[1, 1]),
#  Data(x=[17, 22], edge_index=[2, 36], edge_attr=[36, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[18, 22], edge_index=[2, 38], edge_attr=[38, 8], y=[1, 1]),
#  Data(x=[23, 22], edge_index=[2, 46], edge_attr=[46, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 14], edge_attr=[14, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[21, 22], edge_index=[2, 44], edge_attr=[44, 8], y=[1, 1]),
#  Data(x=[14, 22], edge_index=[2, 30], edge_attr=[30, 8], y=[1, 1]),
#  Data(x=[16, 22], edge_index=[2, 32], edge_attr=[32, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[25, 22], edge_index=[2, 58], edge_attr=[58, 8], y=[1, 1]),
#  Data(x=[17, 22], edge_index=[2, 34], edge_attr=[34, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[26, 22], edge_index=[2, 56], edge_attr=[56, 8], y=[1, 1]),
#  Data(x=[4, 22], edge_index=[2, 6], edge_attr=[6, 8], y=[1, 1]),
#  Data(x=[4, 22], edge_index=[2, 6], edge_attr=[6, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 18], edge_attr=[18, 8], y=[1, 1]),
#  Data(x=[16, 22], edge_index=[2, 32], edge_attr=[32, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 14], edge_attr=[14, 8], y=[1, 1]),
#  Data(x=[14, 22], edge_index=[2, 26], edge_attr=[26, 8], y=[1, 1]),
#  Data(x=[12, 22], edge_index=[2, 26], edge_attr=[26, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 20], edge_attr=[20, 8], y=[1, 1]),
#  Data(x=[21, 22], edge_index=[2, 42], edge_attr=[42, 8], y=[1, 1]),
#  Data(x=[10, 22], edge_index=[2, 20], edge_attr=[20, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 22], edge_attr=[22, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[21, 22], edge_index=[2, 42], edge_attr=[42, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[17, 22], edge_index=[2, 36], edge_attr=[36, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 18], edge_attr=[18, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 22], edge_attr=[22, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 14], edge_attr=[14, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 22], edge_attr=[22, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 18], edge_attr=[18, 8], y=[1, 1]),
#  Data(x=[23, 22], edge_index=[2, 50], edge_attr=[50, 8], y=[1, 1]),
#  Data(x=[7, 22], edge_index=[2, 12], edge_attr=[12, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[21, 22], edge_index=[2, 44], edge_attr=[44, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[22, 22], edge_index=[2, 44], edge_attr=[44, 8], y=[1, 1]),
#  Data(x=[12, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 22], edge_attr=[22, 8], y=[1, 1]),
#  Data(x=[5, 22], edge_index=[2, 8], edge_attr=[8, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1]),
#  Data(x=[17, 22], edge_index=[2, 36], edge_attr=[36, 8], y=[1, 1]),
#  Data(x=[23, 22], edge_index=[2, 48], edge_attr=[48, 8], y=[1, 1]),
#  Data(x=[16, 22], edge_index=[2, 32], edge_attr=[32, 8], y=[1, 1]),
#  Data(x=[20, 22], edge_index=[2, 40], edge_attr=[40, 8], y=[1, 1]),
#  Data(x=[15, 22], edge_index=[2, 30], edge_attr=[30, 8], y=[1, 1]),
#  Data(x=[17, 22], edge_index=[2, 36], edge_attr=[36, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[23, 22], edge_index=[2, 52], edge_attr=[52, 8], y=[1, 1]),
#  Data(x=[18, 22], edge_index=[2, 38], edge_attr=[38, 8], y=[1, 1]),
#  Data(x=[21, 22], edge_index=[2, 42], edge_attr=[42, 8], y=[1, 1]),
#  Data(x=[5, 22], edge_index=[2, 8], edge_attr=[8, 8], y=[1, 1]),
#  Data(x=[20, 22], edge_index=[2, 42], edge_attr=[42, 8], y=[1, 1]),
#  Data(x=[12, 22], edge_index=[2, 22], edge_attr=[22, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[7, 22], edge_index=[2, 12], edge_attr=[12, 8], y=[1, 1]),
#  Data(x=[6, 22], edge_index=[2, 10], edge_attr=[10, 8], y=[1, 1]),
#  Data(x=[7, 22], edge_index=[2, 12], edge_attr=[12, 8], y=[1, 1]),
#  Data(x=[12, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1]),
#  Data(x=[18, 22], edge_index=[2, 36], edge_attr=[36, 8], y=[1, 1]),
#  Data(x=[12, 22], edge_index=[2, 26], edge_attr=[26, 8], y=[1, 1]),
#  Data(x=[13, 22], edge_index=[2, 26], edge_attr=[26, 8], y=[1, 1]),
#  Data(x=[20, 22], edge_index=[2, 42], edge_attr=[42, 8], y=[1, 1]),
#  Data(x=[20, 22], edge_index=[2, 48], edge_attr=[48, 8], y=[1, 1]),
#  Data(x=[10, 22], edge_index=[2, 20], edge_attr=[20, 8], y=[1, 1]),
#  Data(x=[14, 22], edge_index=[2, 30], edge_attr=[30, 8], y=[1, 1]),
#  Data(x=[8, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[22, 22], edge_index=[2, 50], edge_attr=[50, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 16], edge_attr=[16, 8], y=[1, 1]),
#  Data(x=[17, 22], edge_index=[2, 34], edge_attr=[34, 8], y=[1, 1]),
#  Data(x=[9, 22], edge_index=[2, 18], edge_attr=[18, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1]),
#  Data(x=[10, 22], edge_index=[2, 20], edge_attr=[20, 8], y=[1, 1]),
#  Data(x=[11, 22], edge_index=[2, 24], edge_attr=[24, 8], y=[1, 1])]
