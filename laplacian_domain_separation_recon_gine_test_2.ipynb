# %%
from federatedscope.register import register_data
from federatedscope.register import register_trainer
from federatedscope.register import register_metric
from federatedscope.register import register_model

# %%
from federatedscope.contrib.data.cikm_cup import call_cikm_cup_data

register_data("cikm_cup", call_cikm_cup_data)

# %% [markdown]
# ### Register model

# %%
#from federatedscope.contrib.model.mnist_model import call_my_net
#register_model("mynet", call_my_net)

# %% [markdown]
# ### Register trainer

# %%
from federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation import call_laplacian_trainer

register_trainer('laplacian_trainer', call_laplacian_trainer)
# Out:
# /home/michael/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/imports.py:14: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# /home/michael/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch_geometric/graphgym/logger.py:23: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "

# %% [markdown]
# ### Register metric

# %% [markdown]
# ### Create the config

# %% [markdown]
# #### Set data, model, trainer and metric

# %%
from federatedscope.core.configs.config import global_cfg, CN
cfg = global_cfg.clone()

cfg.merge_from_file("federatedscope/gfl/baseline/laplacian_gine_on_cikmcup.yaml")
#cfg.data.type = 'cikm_cup'
#cfg.data.root = 'data'
#cfg.data.shuffle=True
#cfg.data.transform = [['ToTensor'], ['Normalize', {'mean': [0.], 'std': [1]}]]
#cfg.model.type = 'gin'
#cfg.model.out_channels = 10
#cfg.model.hidden = 64
#cfg.model.task='graph'
#cfg.model.dropout = 0.5
#cfg.personalization.local_param = ['encoder_atom', 'encoder', 'clf']#['node_encoder', 'clf']
#cfg.train.batch_or_epoch = "epoch"
cfg.trainer.type = 'laplacian_trainer_with_domain_separation'
cfg.data.batch_size = 64
# cfg.eval.metric = ['mymetric']
cfg.model.out_channels = 2
cfg.params = CN()
cfg.params.alpha=0.1
cfg.params.csd_importance=1e4
cfg.params.eps=1e-10
cfg.params.p=0.
cfg.params.diff_importance = 1.
cfg.params.recon_importance = 0.1

# %% [markdown]
# #### configure other options

# %%
#cfg.use_gpu = True
#cfg.best_res_update_round_wise_key = "test_loss"

#cfg.federate.mode = 'standalone'
cfg.federate.method = \
    'Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4'
#cfg.federate.local_update_steps = 20000000
#cfg.personalization.local_update_steps = 20000000
#cfg.finetune.local_update_steps = 20000000
#cfg.train.local_update_steps = 1

cfg.federate.total_round_num = 200

cfg.federate.client_num = 13
cfg.early_stop.patience = 10000
#cfg.train.optimizer.lr = 0.001
#cfg.train.optimizer.weight_decay = 0.0005
#cfg.grad.grad_clip = 2.0
cfg.criterion.type = 'CrossEntropyLoss'
#cfg.seed = 123
cfg.eval.freq = 1
cfg.eval.metrics = ['imp_ratio']
cfg.eval.report = ['avg']
cfg.eval.best_res_update_round_wise_key = 'val_imp_ratio'
cfg.eval.count_flops = False
cfg.data.type = "cikm_cup"

# %%
import torch
#torch.manual_seed(0)
#torch.backends.cudnn.benchmark = False
#torch.use_deterministic_algorithms(F/home/michael/Desktop/backup files/FederatedScope/data/CIKM22Competitionalse)
#import random
#random.seed(0)
#import numpy as np
#np.random.seed(0)

# %%
from yacs.config import CfgNode
client_cfg_file = "federatedscope/gfl/baseline/laplacian_gine_on_cikmcup_per_client.yaml"
client_cfg = CfgNode.load_cfg(open(client_cfg_file,
                                       'r')) if client_cfg_file else None

# %% [markdown]
# ### Start the FL prosess

# %%
from federatedscope.core.auxiliaries.data_builder import get_data
from federatedscope.core.auxiliaries.utils import setup_seed, update_logger
from federatedscope.core.fed_runner import FedRunner
from federatedscope.core.auxiliaries.worker_builder import get_server_cls, get_client_cls
# Out:
# 2022-10-25 18:28:38,939 (trainer_builder:11)WARNING: No module named 'federatedscope.contrib.optimizer' in `federatedscope.contrib.trainer`, some modules are not available.

# %%
from federatedscope.contrib.workers.laplacian_with_domain_separation_with_autoenc_client import LaplacianDomainSeparationReconClient
from federatedscope.contrib.workers.laplacian_server import LaplacianServer

setup_seed(cfg.seed)
update_logger(cfg)
data, modified_cfg = get_data(cfg)
cfg.merge_from_other_cfg(modified_cfg)
# Out:
# 2022-10-25 18:28:39,325 (utils:129)INFO: the current machine is at 127.0.1.1
# 2022-10-25 18:28:39,327 (utils:131)INFO: the current dir is /home/michael/Projects/CKIM_Competition
# 2022-10-25 18:28:39,328 (utils:132)INFO: the output dir is exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# 2022-10-25 18:28:39,330 (cikm_cup:58)INFO: Loading CIKMCUP data from /home/michael/Projects/CKIM_Competition/data/CIKM22Competition.
# 2022-10-25 18:28:39,331 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #1.
# 2022-10-25 18:28:39,871 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #2.
# 2022-10-25 18:28:39,914 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #3.
# 2022-10-25 18:28:40,514 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #4.
# 2022-10-25 18:28:40,543 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #5.
# 2022-10-25 18:28:40,587 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #6.
# 2022-10-25 18:28:41,103 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #7.
# 2022-10-25 18:28:41,694 (cikm_cup:68)INFO: Loading CIKMCUP data for Client #8.

# %%
Fed_runner = FedRunner(data=data,
                       server_class=LaplacianServer,
                       client_class=LaplacianDomainSeparationReconClient,
                       config=cfg.clone(),
                       client_config=client_cfg)
Fed_runner.run()
# Out:
# server params:
# encoder_atom.atom_embedding_list.0.weight
# 2022-10-25 18:28:44,248 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-10-25 18:28:44,266 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.263789
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# encoder_atom.atom_embedding_list.1.weight
# encoder_atom.atom_embedding_list.2.weight
# encoder_atom.atom_embedding_list.3.weight
# encoder_atom.atom_embedding_list.4.weight
# encoder_atom.atom_embedding_list.5.weight
# encoder_atom.atom_embedding_list.6.weight
# encoder_atom.atom_embedding_list.7.weight
# encoder_atom.atom_embedding_list.8.weight
# encoder_atom.atom_embedding_list.9.weight
# encoder_atom.atom_embedding_list.10.weight
# encoder_atom.atom_embedding_list.11.weight
# encoder_atom.atom_embedding_list.12.weight
# encoder_atom.atom_embedding_list.13.weight
# encoder_atom.atom_embedding_list.14.weight
# encoder_atom.atom_embedding_list.15.weight
# encoder_atom.atom_embedding_list.16.weight
# encoder_atom.atom_embedding_list.17.weight
# encoder_atom.atom_embedding_list.18.weight
# encoder_atom.atom_embedding_list.19.weight
# encoder_atom.atom_embedding_list.20.weight
# encoder_atom.atom_embedding_list.21.weight
# encoder.weight
# encoder.bias
# local_gnn.convs.0.nn.linears.0.weight
# local_gnn.convs.0.nn.linears.0.bias
# local_gnn.convs.0.nn.linears.1.weight
# local_gnn.convs.0.nn.linears.1.bias
# local_gnn.convs.0.nn.norms.0.weight
# local_gnn.convs.0.nn.norms.0.bias
# local_gnn.convs.0.nn.norms.1.weight
# local_gnn.convs.0.nn.norms.1.bias
# local_gnn.convs.1.nn.linears.0.weight
# local_gnn.convs.1.nn.linears.0.bias
# local_gnn.convs.1.nn.linears.1.weight
# local_gnn.convs.1.nn.linears.1.bias
# local_gnn.convs.1.nn.norms.0.weight
# local_gnn.convs.1.nn.norms.0.bias
# local_gnn.convs.1.nn.norms.1.weight
# local_gnn.convs.1.nn.norms.1.bias
# local_gnn.jk_linear.weight
# local_gnn.jk_linear.bias
# global_gnn.convs.0.nn.linears.0.weight
# global_gnn.convs.0.nn.linears.0.bias
# global_gnn.convs.0.nn.linears.1.weight
# global_gnn.convs.0.nn.linears.1.bias
# global_gnn.convs.0.nn.norms.0.weight
# global_gnn.convs.0.nn.norms.0.bias
# global_gnn.convs.0.nn.norms.1.weight
# global_gnn.convs.0.nn.norms.1.bias
# global_gnn.convs.1.nn.linears.0.weight
# global_gnn.convs.1.nn.linears.0.bias
# global_gnn.convs.1.nn.linears.1.weight
# global_gnn.convs.1.nn.linears.1.bias
# global_gnn.convs.1.nn.norms.0.weight
# global_gnn.convs.1.nn.norms.0.bias
# global_gnn.convs.1.nn.norms.1.weight
# global_gnn.convs.1.nn.norms.1.bias
# global_gnn.jk_linear.weight
# global_gnn.jk_linear.bias
# lin_dec1.0.weight
# lin_dec1.0.bias
# lin_dec2.0.weight
# lin_dec2.0.bias
# linear_out.0.weight
# linear_out.0.bias
# bn_linear.weight
# bn_linear.bias
# clf.weight
# clf.bias
# emb.weight
# 2022-10-25 18:28:44,409 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:44,410 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-10-25 18:28:44,434 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.289617
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-25 18:28:44,561 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:44,562 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-10-25 18:28:44,579 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.355404
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-25 18:28:44,739 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:44,740 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-10-25 18:28:44,758 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.176471
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-25 18:28:44,854 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:44,855 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-10-25 18:28:44,874 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.396825
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-25 18:28:44,989 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:44,990 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-10-25 18:28:45,010 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.26158
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0005
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-25 18:28:45,135 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:45,136 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-10-25 18:28:45,158 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.302378
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-25 18:28:45,309 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:45,311 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-10-25 18:28:45,330 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 8
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikm_cup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 10000
#   the_smaller_the_better: False
# eval:
#   base: 0.211538
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 1
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_
# expname_tag:
# federate:
#   client_num: 8
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 8
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 200
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: True
#   freeze_param:
#   local_update_steps: 5000
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 2.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.0
#   embed_size: 8
#   graph_pooling: add
#   hidden: 512
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp/Laplacian_domain_sep_gine_class_clients_diff_1_0_recon_1_0_csd_1e4_gin_on_cikm_cup_lr0.1_lstep10_/sub_exp_20221025182839
# params:
#   alpha: 0.1
#   csd_importance: 10000.0
#   diff_importance: 1.0
#   eps: 1e-10
#   p: 0.0
#   recon_importance: 0.1
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf', 'bn_linear', 'local_gnn', 'linear_out']
#   local_update_steps: 10
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0001
# trainer:
#   type: laplacian_trainer_with_domain_separation
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-10-25 18:28:45,438 (trainer:50)WARNING: Will not use monitor in trainer with class <class 'federatedscope.contrib.trainer.laplacian_trainer_with_domain_with_autoenc_separation.LaplacianDomainSeparationReconTrainer'>
# 2022-10-25 18:28:45,439 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-10-25 18:28:45,440 (trainer:324)INFO: Model meta-info: <class 'federatedscope.gfl.model.graph_level.GNN_Net_Graph'>.
# 2022-10-25 18:28:45,443 (trainer:332)INFO: Num of original para names: 102.
# 2022-10-25 18:28:45,444 (trainer:333)INFO: Num of original trainable para names: 71.
# 2022-10-25 18:28:45,445 (trainer:335)INFO: Num of preserved para names in local update: 37.
# Preserved para names in local update: {'global_gnn.convs.1.nn.linears.0.weight', 'global_gnn.jk_linear.weight', 'global_gnn.convs.0.nn.norms.1.weight', 'global_gnn.convs.0.nn.norms.0.bias', 'global_gnn.convs.1.nn.norms.0.running_mean', 'lin_dec2.0.weight', 'emb.weight', 'global_gnn.convs.0.nn.linears.0.bias', 'global_gnn.convs.1.nn.norms.1.bias', 'global_gnn.convs.0.nn.linears.1.weight', 'global_gnn.convs.1.nn.norms.1.weight', 'lin_dec1.0.bias', 'global_gnn.convs.1.nn.norms.0.weight', 'lin_dec1.0.weight', 'global_gnn.convs.1.nn.linears.1.bias', 'global_gnn.convs.1.nn.norms.0.running_var', 'global_gnn.convs.0.nn.norms.1.bias', 'global_gnn.convs.0.nn.norms.1.running_mean', 'global_gnn.convs.1.nn.linears.0.bias', 'global_gnn.convs.0.nn.norms.0.weight', 'global_gnn.convs.1.nn.norms.1.running_mean', 'global_gnn.convs.1.nn.norms.1.running_var', 'global_gnn.convs.0.nn.norms.1.num_batches_tracked', 'global_gnn.convs.0.eps', 'global_gnn.convs.0.nn.norms.0.num_batches_tracked', 'global_gnn.convs.0.nn.norms.0.running_mean', 'global_gnn.convs.1.nn.linears.1.weight', 'global_gnn.convs.0.nn.norms.1.running_var', 'global_gnn.convs.1.nn.norms.1.num_batches_tracked', 'global_gnn.convs.0.nn.linears.0.weight', 'global_gnn.convs.1.eps', 'lin_dec2.0.bias', 'global_gnn.convs.0.nn.norms.0.running_var', 'global_gnn.convs.1.nn.norms.0.bias', 'global_gnn.convs.0.nn.linears.1.bias', 'global_gnn.jk_linear.bias', 'global_gnn.convs.1.nn.norms.0.num_batches_tracked'}.
# 2022-10-25 18:28:45,446 (trainer:339)INFO: Num of filtered para names in local update: 65.
# Filtered para names in local update: {'encoder_atom.atom_embedding_list.18.weight', 'clf.weight', 'encoder_atom.atom_embedding_list.6.weight', 'encoder_atom.atom_embedding_list.10.weight', 'encoder_atom.atom_embedding_list.9.weight', 'clf.bias', 'encoder_atom.atom_embedding_list.20.weight', 'local_gnn.convs.0.nn.norms.1.bias', 'bn_linear.bias', 'local_gnn.convs.0.eps', 'encoder_atom.atom_embedding_list.12.weight', 'bn_linear.running_mean', 'encoder_atom.atom_embedding_list.0.weight', 'local_gnn.convs.1.nn.linears.1.bias', 'encoder_atom.atom_embedding_list.17.weight', 'local_gnn.convs.1.nn.norms.0.running_mean', 'bn_linear.num_batches_tracked', 'local_gnn.convs.1.nn.norms.0.running_var', 'encoder_atom.atom_embedding_list.16.weight', 'local_gnn.convs.0.nn.norms.0.weight', 'local_gnn.jk_linear.bias', 'encoder_atom.atom_embedding_list.7.weight', 'encoder_atom.atom_embedding_list.2.weight', 'bn_linear.running_var', 'encoder_atom.atom_embedding_list.15.weight', 'local_gnn.convs.0.nn.norms.1.running_var', 'linear_out.0.weight', 'local_gnn.convs.0.nn.linears.0.bias', 'local_gnn.convs.0.nn.norms.0.running_var', 'local_gnn.convs.1.eps', 'bn_linear.weight', 'local_gnn.convs.0.nn.linears.0.weight', 'local_gnn.convs.1.nn.norms.1.running_var', 'local_gnn.convs.1.nn.linears.0.bias', 'local_gnn.convs.0.nn.linears.1.weight', 'local_gnn.convs.0.nn.norms.0.bias', 'encoder_atom.atom_embedding_list.21.weight', 'local_gnn.convs.1.nn.norms.0.weight', 'local_gnn.convs.1.nn.norms.1.running_mean', 'local_gnn.convs.0.nn.norms.0.running_mean', 'local_gnn.convs.1.nn.linears.1.weight', 'local_gnn.jk_linear.weight', 'local_gnn.convs.1.nn.norms.1.num_batches_tracked', 'local_gnn.convs.0.nn.norms.1.running_mean', 'encoder.bias', 'encoder.weight', 'local_gnn.convs.0.nn.linears.1.bias', 'encoder_atom.atom_embedding_list.13.weight', 'encoder_atom.atom_embedding_list.5.weight', 'local_gnn.convs.1.nn.linears.0.weight', 'local_gnn.convs.1.nn.norms.1.bias', 'encoder_atom.atom_embedding_list.3.weight', 'encoder_atom.atom_embedding_list.11.weight', 'encoder_atom.atom_embedding_list.1.weight', 'local_gnn.convs.0.nn.norms.1.weight', 'linear_out.0.bias', 'local_gnn.convs.0.nn.norms.1.num_batches_tracked', 'local_gnn.convs.1.nn.norms.0.num_batches_tracked', 'local_gnn.convs.1.nn.norms.1.weight', 'encoder_atom.atom_embedding_list.4.weight', 'local_gnn.convs.0.nn.norms.0.num_batches_tracked', 'encoder_atom.atom_embedding_list.19.weight', 'encoder_atom.atom_embedding_list.14.weight', 'local_gnn.convs.1.nn.norms.0.bias', 'encoder_atom.atom_embedding_list.8.weight'}.
# 2022-10-25 18:28:45,448 (trainer:344)INFO: After register default hooks,
# 	the hooks_in_train is:
# 	{
# 	  "on_fit_start": [
# 	    "_hook_on_fit_start_init",
# 	    "_hook_on_fit_start_calculate_model_size"
# 	  ],
# 	  "on_epoch_start": [
# 	    "_hook_on_epoch_start"
# 	  ],
# 	  "on_batch_start": [
# 	    "_hook_on_batch_start_init"
# 	  ],
# 	  "on_batch_forward": [
# 	    "_hook_on_batch_forward",
# 	    "_hook_on_batch_forward_regularizer",
# 	    "_hook_on_batch_forward_flop_count"
# 	  ],
# 	  "on_batch_backward": [
# 	    "_hook_on_batch_backward"
# 	  ],
# 	  "on_batch_end": [
# 	    "_hook_on_batch_end"
# 	  ],
# 	  "on_fit_end": [
# 	    "_hook_on_fit_end"
# 	  ]
# 	};
# 	the hooks_in_eval is:
#             t{
# 	  "on_fit_start": [
# 	    "_hook_on_fit_start_init"
# 	  ],
# 	  "on_epoch_start": [
# 	    "_hook_on_epoch_start"
# 	  ],
# 	  "on_batch_start": [
# 	    "_hook_on_batch_start_init"
# 	  ],
# 	  "on_batch_forward": [
# 	    "_hook_on_batch_forward"
# 	  ],
# 	  "on_batch_end": [
# 	    "_hook_on_batch_end"
# 	  ],
# 	  "on_fit_end": [
# 	    "_hook_on_fit_end"
# 	  ]
# 	}
# 2022-10-25 18:28:45,454 (server:628)INFO: ----------- Starting training (Round #0) -------------
# 2022-10-25 18:30:12,168 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #7', 'Round': 0, 'Results_raw': {'train_imp_ratio': 18.242321, 'train_loss': 11799.883514, 'train_total': 22280, 'train_avg_loss': 0.529618}}
# 2022-10-25 18:31:38,440 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #3', 'Round': 0, 'Results_raw': {'train_imp_ratio': -7.983162, 'train_loss': 14446.236986, 'train_total': 22190, 'train_avg_loss': 0.651025}}
# 2022-10-25 18:31:44,419 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #2', 'Round': 0, 'Results_raw': {'train_imp_ratio': -42.691786, 'train_loss': 1239.504501, 'train_total': 1810, 'train_avg_loss': 0.684809}}
# 2022-10-25 18:32:07,128 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #8', 'Round': 0, 'Results_raw': {'train_imp_ratio': -286.274389, 'train_loss': nan, 'train_total': 7770, 'train_avg_loss': nan}}
# 2022-10-25 18:32:10,319 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #4', 'Round': 0, 'Results_raw': {'train_imp_ratio': -82.342809, 'train_loss': 637.115741, 'train_total': 1010, 'train_avg_loss': 0.630808}}
# 2022-10-25 18:32:48,177 (laplacian_with_domain_separation_with_autoenc_client:121)INFO: {'Role': 'Client #1', 'Round': 0, 'Results_raw': {'train_imp_ratio': -46.871152, 'train_loss': nan, 'train_total': 12490, 'train_avg_loss': nan}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 6
#       1 Fed_runner = FedRunner(data=data,
#       2                        server_class=LaplacianServer,
#       3                        client_class=LaplacianDomainSeparationReconClient,
#       4                        config=cfg.clone(),
#       5                        client_config=client_cfg)
# ----> 6 Fed_runner.run()
#
# File ~/Projects/CKIM_Competition/federatedscope/core/fed_runner.py:186, in FedRunner.run(self)
#     184     while len(self.shared_comm_queue) > 0:
#     185         msg = self.shared_comm_queue.popleft()
# --> 186         self._handle_msg(msg)
#     188 self.server._monitor.finish_fed_runner(fl_mode=self.mode)
#     190 return self.server.best_results
#
# File ~/Projects/CKIM_Competition/federatedscope/core/fed_runner.py:325, in FedRunner._handle_msg(self, msg, rcv)
#     323     self.server._monitor.track_download_bytes(download_bytes)
#     324 else:
# --> 325     self.client[each_receiver].msg_handlers[msg.msg_type](msg)
#     326     self.client[each_receiver]._monitor.track_download_bytes(
#     327         download_bytes)
#
# File ~/Projects/CKIM_Competition/federatedscope/contrib/workers/laplacian_with_domain_separation_with_autoenc_client.py:112, in LaplacianDomainSeparationReconClient.callback_funcs_for_model_para(self, message)
#     107     logger.info(
#     108         f"[Normal FL Mode] Client #{self.ID} has been locally "
#     109         f"early stopped. "
#     110         f"The next FL update may result in negative effect")
#     111     self._monitor.local_converged()
# --> 112 sample_size, model_para_all, omega_set, results = self.trainer.train(self.state)
#     113 if self._cfg.federate.share_local_model and not \
#     114         self._cfg.federate.online_aggr:
#     115     model_para_all = copy.deepcopy(model_para_all)
#
# File ~/Projects/CKIM_Competition/federatedscope/core/auxiliaries/decorators.py:28, in use_diff_laplacian.<locals>.wrapper(self, *args, **kwargs)
#      24 if self.cfg.federate.use_diff:
#      25     # TODO: any issue for subclasses?
#      26     before_metric = self.evaluate(target_data_split_name='val')
# ---> 28 num_samples_train, model_para, omega, result_metric = func(
#      29     self, *args, **kwargs)
#      31 if self.cfg.federate.use_diff:
#      32     # TODO: any issue for subclasses?
#      33     after_metric = self.evaluate(target_data_split_name='val')
#
# File ~/Projects/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_with_autoenc_separation.py:182, in LaplacianDomainSeparationReconTrainer.train(self, state, target_data_split_name, hooks_set)
#     178 hooks_set = hooks_set or self.hooks_in_train
#     180 self.ctx.check_data_split(target_data_split_name)
# --> 182 self._run_routine(MODE.TRAIN, hooks_set, target_data_split_name)
#     184 return self.ctx.num_samples_train, self.get_model_para(
#     185 ), self.get_omega_para(), self.ctx.eval_metrics
#
# File ~/Projects/CKIM_Competition/federatedscope/core/trainers/trainer.py:279, in Trainer._run_routine(self, mode, hooks_set, dataset_name)
#     277 if self.ctx.cur_mode == 'train':
#     278     for hook in hooks_set["on_batch_backward"]:
# --> 279         hook(self.ctx)
#     280 for hook in hooks_set["on_batch_end"]:
#     281     hook(self.ctx)
#
# File ~/Projects/CKIM_Competition/federatedscope/contrib/trainer/laplacian_trainer_with_domain_with_autoenc_separation.py:167, in LaplacianDomainSeparationReconTrainer._hook_on_batch_backward(self, ctx)
#     164 loss = ctx.loss_batch_ce + self.config.params.csd_importance * ctx.loss_batch_csd + \
#     165        self.config.params.diff_importance * ctx.diff_loss + self.config.params.recon_importance * ctx.recon_loss
#     166 #print(f"loss: {loss}")
# --> 167 loss.backward(loss)
#     169 if ctx.grad_clip > 0:
#     170     torch.nn.utils.clip_grad_norm_(ctx.model.parameters(),
#     171                                    ctx.grad_clip)
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/Projects/CKIM_other/CIKM22_FL_Competition/venv/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# Difference train_avg_loss: 125 -> 174
# 1: 0.539109 -> 0.540
# 2: 0.614181 -> 0.60414
# 3: 0.680621 -> 0.675371
# 4: 0.466614 -> 0.405735
# 5: 0.64907 -> 0.648837
# 6: 0.479263 -> 0.470293
# 7: 0.668663 -> 0.662036
# 8: 0.438008 -> 0.433998
# 9: 0.107733 -> 0.118945
# 10: 0.009074 -> 0.009043
# 11: 1.128238 -> 1.126667
# 12: 2.657362 -> 2.661828
# 13: -> 0.007134

# %%
data

# %%
import os

# %% [markdown]
# After 10 rounds:
#
# diff: 0, csd: 0:
# server: -8
# c1 t/val: 0.375 /0.37
# c2 t/val: 0.678 /0.606
# c3 t/val: 0.699 /0.608
# c4 t/val: 0.599 /0.537
#
# diff: 0, csd: 0:
# server: -4.5
# c1 t/val: 0.372879 /0.328
# c2 t/val: 0.678992 /0.605809
# c3 t/val: 0.70166 /0.608609
# c4 t/val: 0.597455 /0.534253
#
#
#
# diff: 10, csd: 0:
# server: -35
# c1 t/val: 0.482/0.52
# c2 t/val: 0.694/0.65
# c3 t/val: 0.724/0.65
# c4 t/val: 0.674/0.575
#
# diff: 1, csd: 0:
# server: -9.6
# c1 t/val: 0.378194/0.319349
# c2 t/val: 0.67461/0.609163
# c3 t/val: 0.705559/0.615019
# c4 t/val: 0.605581/0.572086
#
# diff: 0, csd: 1e4:
# server: -18
# c1 t/val: 0.280962/0.23074
# c2 t/val: 0.682652/0.603175
# c3 t/val: 0.699094/0.67027
# c4 t/val: 0.594985/0.609611
#
# diff: 0 csd: 1e8
# server: -18
# c1 t/val: 0.2606/0.348(0.197)
# c2 t/val: 0.653/0.0.602
# c3 t/val: 0.691/0.597
# c4 t/val: 0.581/0.629
#
# diff: 0 csd: 1e8
# server: -12.7
# c1 t/val: 0.262647/0.249875
# c2 t/val: 0.649273/0.0.600435
# c3 t/val: 0.696132/0.615158
# c4 t/val: 0.586597/0.656992
#
#
# diff: 0.1 csd: 0
# server: -11
# c1 t/val: 0.2606/0.332837
# c2 t/val: 0.678326/0.0.610099
# c3 t/val: 0.704083/0.616179
# c4 t/val: 0.604177/0.559658

# %%
os.environ['CUBLAS_WORKSPACE_CONFIG']
